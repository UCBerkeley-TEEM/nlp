# %%
from nltk.corpus import brown
from nltk.corpus import treebank
from nltk import *
import nltk, re, pprint
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
sent_tokenizer=nltk.data.load('tokenizers/punkt/english.pickle')

# %%
def read_and_clean_file():
    with open('115039_12-16-08.txt', 'r',encoding='ISO-8859-1') as f:
        raw = f.read()
    start = (raw.find("REPORT OF ACTION TAKEN IN CLOSED SESSION")) +85
    end = (raw.rfind('Certified Shorthand Reporter'))-10
    raw = raw[start:end]
    return raw

def tokenize_and_further_cleanse(raw):
    pattern = r'''(?x) # set flag to allow verbose regexps
    (?:[A-Z]\.)+ # abbreviations, e.g. U.S.A.
    | \w+(?:-\w+)* # words with optional internal hyphens
    | \d{1,2}:\d{2} # time as one token
    | \$?\d+(?:\.\d+)?%? # currency and percentages, e.g. $12.40, 82%
    | \.\.\. # ellipsis
    | [][.,;"'?():-_`] # these are separate tokens; includes ], [
    '''
    tokenized_raw_text = nltk.regexp_tokenize(raw, pattern)
    tokenized_raw_text_new = [w.lower() for w in tokenized_raw_text if w.isalpha()]
    tokenized_raw_text_wo_stopwords = [x for x in tokenized_raw_text_new if x not in stopwords.words('english')]
    return tokenized_raw_text_wo_stopwords

def most_freq_unigrams():
    raw = read_and_clean_file()
    tokenized_raw_text_wo_stopwords = tokenize_and_further_cleanse(raw)
    mp_freqdist = FreqDist(tokenized_raw_text_wo_stopwords)  # compute the frequency distribution
    x=len(tokenized_raw_text_wo_stopwords)
    sum=0
    for words in mp_freqdist.most_common(20):
        #print(words[0])# show the top 100 Unigrams
        sum=sum +(len(words[0]))
    print("Total Number of Character",sum)
    return tokenized_raw_text_wo_stopwords

# %%
print("The most frequent unigrams:", most_freq_unigrams())
# Out:
# Total Number of Character 112
# The most frequent unigrams: ['sup', 'knabe', 'chair', 'call', 'meeting', 'order', 'please', 'everyone', 'would', 'please', 'rise', 'led', 'invocation', 'morning', 'father', 'mauricio', 'goloron', 'st', 'martha', 'church', 'la', 'puente', 'pledge', 'led', 'victor', 'aprea', 'member', 'post', 'west', 'covina', 'american', 'legion', 'father', 'fr', 'mauricio', 'goloron', 'god', 'called', 'us', 'darkness', 'wonderful', 'light', 'may', 'god', 'light', 'guide', 'us', 'protect', 'us', 'community', 'may', 'god', 'wisdom', 'direct', 'board', 'work', 'decisions', 'today', 'every', 'day', 'may', 'god', 'love', 'strengthen', 'work', 'county', 'make', 'god', 'peace', 'make', 'us', 'one', 'help', 'us', 'always', 'strive', 'common', 'good', 'neighbors', 'repeats', 'prayer', 'spanish', 'repeats', 'prayer', 'tagalog', 'amen', 'victor', 'aprea', 'please', 'face', 'flag', 'placing', 'right', 'land', 'heart', 'joining', 'pledge', 'allegiance', 'pledge', 'allegiance', 'recited', 'thank', 'supervisor', 'molina', 'sup', 'molina', 'thank', 'mr', 'chairman', 'honor', 'morning', 'present', 'certificate', 'appreciation', 'father', 'mauricio', 'goloron', 'father', 'goloron', 'born', 'raised', 'southern', 'philippines', 'entered', 'seminary', 'age', 'educated', 'society', 'jesus', 'became', 'ordained', 'priest', 'father', 'goloron', 'came', 'united', 'states', 'served', 'immaculate', 'heart', 'mary', 'church', 'hollywood', 'st', 'catherine', 'laborne', 'church', 'torrens', 'currently', 'heads', 'robust', 'congregation', 'st', 'martha', 'church', 'velinda', 'st', 'martha', 'situated', 'thriving', 'community', 'many', 'compassionate', 'parishioners', 'devoted', 'good', 'works', 'community', 'service', 'offering', 'food', 'banks', 'donating', 'clothing', 'bank', 'needy', 'want', 'extend', 'heartfelt', 'thanks', 'father', 'goloron', 'want', 'present', 'certificate', 'appreciation', 'leading', 'us', 'invocation', 'thank', 'father', 'applause', 'supervisor', 'antonovich', 'sup', 'antonovich', 'want', 'welcome', 'victor', 'aprea', 'covina', 'came', 'today', 'member', 'west', 'covina', 'post', 'american', 'legion', 'retired', 'administrative', 'assistant', 'city', 'los', 'angeles', 'transportation', 'department', 'graduate', 'washington', 'generals', 'high', 'school', 'los', 'angeles', 'university', 'southern', 'california', 'thank', 'coming', 'applause', 'sup', 'knabe', 'chair', 'okay', 'proceed', 'reading', 'agenda', 'clerk', 'sachi', 'hamai', 'good', 'morning', 'mr', 'chairman', 'members', 'board', 'begin', 'today', 'agenda', 'page', 'agenda', 'meeting', 'community', 'development', 'commission', 'items', 'sup', 'knabe', 'chair', 'moved', 'supervisor', 'yaroslavsky', 'seconded', 'antonovich', 'without', 'objection', 'ordered', 'clerk', 'sachi', 'hamai', 'agenda', 'meeting', 'housing', 'authority', 'item', 'sup', 'knabe', 'chair', 'clerk', 'sachi', 'hamai', 'item', 'agenda', 'housing', 'authority', 'sup', 'knabe', 'chair', 'moved', 'yaroslavsky', 'seconded', 'molina', 'without', 'objection', 'ordered', 'clerk', 'sachi', 'hamai', 'page', 'agenda', 'meeting', 'regional', 'park', 'open', 'space', 'district', 'item', 'sup', 'knabe', 'chair', 'moved', 'supervisor', 'molina', 'seconded', 'supervisor', 'antonovich', 'without', 'objection', 'ordered', 'clerk', 'sachi', 'hamai', 'board', 'supervisors', 'items', 'item', 'number', 'request', 'member', 'public', 'hold', 'item', 'remaining', 'items', 'sup', 'knabe', 'chair', 'hold', 'item', 'clerk', 'sachi', 'hamai', 'yes', 'sup', 'knabe', 'chair', 'okay', 'remainder', 'moved', 'supervisor', 'seconded', 'chair', 'without', 'objection', 'ordered', 'clerk', 'sachi', 'hamai', 'items', 'item', 'number', 'posted', 'agenda', 'chief', 'executive', 'officer', 'requests', 'item', 'referred', 'back', 'office', 'sup', 'knabe', 'chair', 'remainder', 'us', 'clerk', 'sachi', 'hamai', 'item', 'sup', 'knabe', 'chair', 'ordered', 'clerk', 'sachi', 'hamai', 'item', 'supervisor', 'antonovich', 'requests', 'item', 'held', 'item', 'number', 'sup ...

# %%
with open('115039_12-16-08.txt', 'r',encoding='ISO-8859-1') as f:
    raw = f.read()
#Finding Start and End of the Actual Text -- eliminating content, preface, and  bibliographies at the end    
start = (raw.find("REPORT OF ACTION TAKEN IN CLOSED SESSION")) +85
end = (raw.rfind('Certified Shorthand Reporter'))-10
raw = raw[start:end]

raw_tokenized_sent = sent_tokenizer.tokenize(raw)
print(raw_tokenized_sent[1])
# Out:
# KNABE, CHAIR: CALL THE MEETING TO ORDER, PLEASE, IF EVERYONE WOULD PLEASE RISE.

# %%
raw= raw.replace("-\n","")
pattern = r'''(?x) # set flag to allow verbose regexps
(?:[A-Z]\.)+ # abbreviations, e.g. U.S.A.
| \w+(?:-\w+)* # words with optional internal hyphens
| \d{1,2}:\d{2} # time as one token
| \$?\d+(?:\.\d+)?%? # currency and percentages, e.g. $12.40, 82%
| \.\.\. # ellipsis
| [][.,;"'?():-_`] # these are separate tokens; includes ], [
'''
tokenized_raw_text = nltk.regexp_tokenize(raw, pattern)
print(tokenized_raw_text[:30])
# Out:
# ['SUP', '.', 'KNABE', ',', 'CHAIR', ':', 'CALL', 'THE', 'MEETING', 'TO', 'ORDER', ',', 'PLEASE', ',', 'IF', 'EVERYONE', 'WOULD', 'PLEASE', 'RISE', '.', 'WE', 'WILL', 'BE', 'LED', 'IN', 'THE', 'INVOCATION', 'THIS', 'MORNING', 'BY']

# %%
len(tokenized_raw_text)
# Out:
# 41114

# %%
tokenized_raw_text_new = [w for w in tokenized_raw_text if w.isalpha()]

# %%
tokenized_raw_text_wo_stopwords = [x.lower() for x in tokenized_raw_text_new if x.lower() not in stopwords.words('english')]

# %%
fd_wo_stopwords = FreqDist(tokenized_raw_text_wo_stopwords)  # compute the frequency distribution
fd_top_20 =fd_wo_stopwords.most_common(20)

# %%
fd_top_20
# Out:
# [('sup', 370),
#  ('chair', 177),
#  ('knabe', 164),
#  ('would', 162),
#  ('county', 133),
#  ('going', 125),
#  ('board', 119),
#  ('thank', 114),
#  ('number', 113),
#  ('item', 113),
#  ('sheriff', 94),
#  ('yaroslavsky', 94),
#  ('us', 93),
#  ('think', 92),
#  ('antonovich', 90),
#  ('one', 89),
#  ('supervisor', 79),
#  ('also', 78),
#  ('larry', 75),
#  ('waldie', 72)]

# %%
date_pattern = r'''(?x) # set flag to allow verbose regexps
(mon|tues|wednes|thurs|fri|satur|sun)day #days of the week
|(jan(uary)?|feb(ruary)?|mar(ch)?|apr(il)?|may|jun(e)?|jul(y)?|aug(ust)?|sep(tember)?|oct(ober)?|nov(ember)?|dec(ember)?)\s+\d{1,2},\s+\d{4}
|(january|february|march|april|june|july|august|september|october|november|december) #months
|^(19|20)\d{2}$ #years between 1900-2099
'''
# |(january|february|march|april|may|june|july|august|september|october|november|december) #months
# |^(19|20)\d{2}$ #years between 1900-2099

# %%
import re
sentences_with_dates=[]
for i in range(len(raw_tokenized_sent)):
    if len(re.findall(date_pattern, raw_tokenized_sent[i].strip().lower()))!=0:
        sentences_with_dates.append((raw_tokenized_sent[i-1]+raw_tokenized_sent[i]).strip().lower())

# %%
for sentence in sentences_with_dates:
    print(sentence+'\n')
# Out:
# on item number 12, supervisor knabe requests that this item be held.on item number 13, the chief executive officer requests that this item be continued to january 13th, 2009.
#
# on item 51, there's a request from a member of the public to hold this item.and on item number 60, the interim director of health services requests that the corrective action plan be continued to january 6th, 2009, but the settlement be approved today.
#
# public hearings, item 71 we will hold for a public hearing.on item 72, as indicated on the supplemental agenda, supervisor ridley-thomas requests that this item be continued without discussion to january 27th, 2009.
#
# knabe, chair: so ordered.clerk sachi hamai: on item 73, as indicated on the supplemental agenda, supervisor ridley-thomas requests that this item be continued without discussion to february 24th, 2009.
#
# he owns an 803 to 655 win-loss record for 551 winning percentage with the angels.he reached the 800 win plateau on september 22nd with a 2-1 victory over seattle.
#
# under his leadership, they have won 90 or more in five of the last seven seasons.the numerous community events include he's co chair of the angels care 65 roses golf tournament, the chairman of the heart association heart and soul walk, supports local little leagues throughout the mike scioscia youth baseball clinic make-a-wish foundation, and also, through his leadership, the monrovia boys and girls club raise about 75 percent of their budget each january/february when they do their annual dinner and mike does a phenomenal job as the auctioneer.
#
# and so let me just say that we are indeed pleased to have them with us this morning.you will want to know that they will be featured on the holiday celebration national show on december 17th and december the 24th at 10 p.m. on p.b.s.
#
# make sure that you don't miss it.in addition, they are performing at the 49th annual holiday celebration at the dorothy chandler pavilion on december the 24th.
#
# for the first year they are doing highlights of the version of the 2007 show.and it will air for the first time tomorrow night, december 17th, at 10 p.m. on k.c.e.t.
#
# we have with us danelle prado, james klefley, jennifer weinstein luc robitaille, los angeles kings hockey club, and trish ploehn, of the director of our department of the children and family services.we are going to recognize their hard work, leadership and dedication to partnering with our department of children and family services to promote positive outcomes for our children in foster care and to help find permanent and loving families through the support of the freddie mack foundation's wednesday child program and fox 11 news, the heart gallery los angeles, and the department's adoption matching events and awareness campaigns.
#
# thank you very much.for many years, the l.a. kings has been a proud sponsor of the freddie mack foundation's wednesday's child program.
#
# and we support the endeavors of the l.a. county department of children and family services in the collective quest to find permanent and loving homes in hundreds of the l.a. county's foster children.special thanks to supervisor antonovich and the other members of the board and welcoming to new supervisor mike ridley- thomas and trish ploehn and d.c.f, and of course, christine devine, and of course, the fox wednesday's child team.
#
# obviously taking deputies off the streets, particularly in unincorporated areas.i know some of the others have questions, but i think it might be appropriate, at least what has changed from last tuesday, where it was a million dollars cost, to today where obviously you have a letter saying no costs?
#
# molina: and then one of the constituents wrote me that she felt that she should go along in order to take pictures of them partying out there.but as i understand, they travel on sunday.
#
# but as i understand, they travel on sunday.they train on monday.
#
# they train on monday.they work on tuesday all day, 16 hours, as i understand.
#
# they work on tuesday all day, 16 hours, as i understand.and they return on wednesday.
#
# you make certain assumptions, mr. waldie.you make certain assumptions about how many people are going to be sick during the course of the year, how many are going to be on vacation during the year, this is january.
#
# you make certain assumptions about how many people are going to be sick during the course of the year, how many are going to be on vacation during the year, this is january.the number of employees sick rises in january, as you well know.
#
# sup.molina: i can also assure you that on sunday you have to find some other flight to go there.
#
# molina: i can also assure you that on sunday you have to find some other flight to go there.there are no flights available to d.c. on sunday.
#
# it's for a report.hopefully back at our january 6th meeting.
#
# i therefore move the board of supervisors direct the c.e.o.along with the assistance of the departments, our legislative advocates and board offices to report back at the board meeting on january 6th with a final list of major projects and initiatives that are most likely to qualify for funding by the federal economic recovery legislation and a legislative strategy to maximize funding for the los angeles county projects."
#
# sup.ridley-thomas: i ask that we adjourn in memory of earl portlock office of father of city attorney staff member, zna houston, who recently passed on november 10 at the age of 82.
#
# yaroslavsky: okay.and the issue for me, i hope it's for the rest of the board, too, is that we ought to make every effort to determine whether this is in our best interest and not forgo the opportunity to apply for this money and the deadline is january 6th, which is the day we come back after the first of the year.
#
# and i'm here to give you an update, a status report regarding the sexual assault kit issue.i appeared before the board on november 12th.
#
# and phase three was to determine the status of those kits so that we could prioritize them for testing.as of the november 12th meeting we had finished phase one, which was to count the kits.
#
# as of the november 12th meeting we had finished phase one, which was to count the kits.we have now, since november 12th, finished phase 2, which was to determine how many untested kits there were, and that is in the letter that was provided to you, that's 4,727 and we are now in the midst of phase three, which is, what we did was we took all the untested kits, we divided those cases up by whose cases they were, sent them out to all the units in the sheriff's department that those cases belonged to and to special victims' bureau, and also to all the independent agencies along with a questionnaire.
#
# cases that have suspect's name that are unadjudicated, cases that were declined for filing, and cases that are adjudicated.what we're also doing with those is since we are looking at a timeframe of completing this study in mid-january-- we have the holidays coming up, some issues there-- but we're looking at this completely done by mid-january.
#
# and we have also sent a letter out to all independent police agencies advising them of the sheriff's new policy in the handling and processing of kits.and i am also going to be attending the january 15th meeting of the los angeles county chiefs of police association where i will again be explaining the new policy to them and answering questions that they have.
#
# when will you complete that survey?earl shields: like i said, we're looking at completing phase three, which is what we're talking about here, middle part of january.
#
# yaroslavsky: i'm not going to take any more time.can we get a status report, say in the fourth meeting of january, whatever date that is?
#
# that would give you more than six weeks.january 13th or the 20th was canceled today.
#
# sup.yaroslavsky: so i move we can put this over to january 27th.
#
# first of all, that we adjourn in memory of officer joseph sanders, the california highway patrol officer who was killed yesterday morning attending to a traffic accident on the eastbound 60 in hacienda heights.officer sanders was a marine veteran who fought in iraq, returned from duty in july 2006, was with c.h.p.
#
# also adjourn in memory of the honorable thomas mayfeld, supervisor and he was chairman of the board of the stanislaus county board of supervisors.he passed away on december 9th after a long illness.
#
# also adjourn in memory of victor evers, a long time resident of lakewood and long beach area, the father of c.e.o.employee vickie evers, who passed away on december 8th at the age of 84.
#
# he is survived by wife, soraya, three children, father and stepmother, three siblings and their spouses.also that we adjourn in memory of julianna huerta, who passed away on december 6th after a five-year battle with breast cancer.
#
# she's survived by her husband of 44 years, james, children christina, james and their spouses.also that we adjourn in memory of john lawrence, fire captain of the city of los angeles who passed away very suddenly on december 14th.
#
# he is survived survived by his sons james and randall, five grandchildren, seven great grandchildren.his wife preceded him in death this past august.
#
# that's just for the extension.if they don't meet the requirements to have all regulatory approvals and permits by 2010, within 15 days, by july 15th, they owe another $250,000.
#
# i am the case planner for hearing item number 71.on december 13th, 2006, the regional planning commission approved a coastal development permit, parking permit and variance to authorize the demolition of an existing 202-unit apartment complex and subsequent construction of a 544-unit complex in the residential five category of the marina del rey specific plan.
#
# on december 13th, 2006, the regional planning commission approved a coastal development permit, parking permit and variance to authorize the demolition of an existing 202-unit apartment complex and subsequent construction of a 544-unit complex in the residential five category of the marina del rey specific plan.the marina strand colony 2 homeowners' association appealed the regional planning commission's decision to your board and on march 27th, 2007 your board denied this appeal.
#
# for off-site transport of cut material.the draft additional environmental analysis was made available to the public on october 4th, 2008.
#
# the final additional environmental analysis addresses the relevant comments made in these letters.an additional letter was received via email on december 11th from rose zoya, counsel to the homeowners' association that originally filed suit against the county.
#
# speaker: i do feel that it would be fair for us to request a continuance.i do have a statement today, but the shores was given from november 25th to december 16th to respond to us.
#
# for the combined public hearing on the reapproval of the shores apartment project r-2005-00234 located at 4201 via marina, marina del rey, i therefore move that the board, one, close the public hearing and certify that the final additional environmental analysis, final additional environmental analysis prepared for the shores project number r-2005-00234 is in compliance with the c.e.q.a.and with the june 2008 written mandate issued by the los angeles county superior court.
#
# and the variance number 2005-00004.and, five, instruct county counsel to prepare the final findings and conditions necessary for these approvals to bring them back on january 27th, 2009 for this board's consideration.
#
# i think the c.e.o.wanted that continued to january 6th, is that correct?
#
# knabe, chair: item number 20, we're going to continue this.but i just want to make a brief comment because i'm asking for it to be continued till the end of january for a couple reasons.
#
# also, i understand first five was approached to increase their funding commitment and they declined.however, i would like to follow-up on this in january when i become chair of first five and explore the issue with them.
#
# however, i would like to follow-up on this in january when i become chair of first five and explore the issue with them.so i would like to just put that on the record but continue this item until the end of january, last meeting in january.
#
# so ordered.continued to the last meeting in january.
#
# yaroslavsky: that's correct.in fact, we should scheduled it before the middle of january, 13th, the last meeting before the inauguration, so we have an opportunity to discuss it and do whatever you want to do with it.
#
# metro board suspends-- 1998 metro board suspends construction of metro red line to east l.a. studies begin to determine a more cost efficient project.in the year 2000, a major investment study considered 47 alternatives to the metro red line to east l.a. not one study, though, because as of january, they're looking for maintenance facilities-- so not one study of the gold line, the east side extension, included any kind of permanent facilities for the gold line.
#
# so the question is you have these tax sites in 1980 and 1990.and according to an article in from the l.a. times from october 30th, each of those raised $686 million in 2007.
#
# thank you.report of action taken in closed
# session tuesday, december 16, 2008
#
#
#
# agenda item cs-4 was continued to monday, december 22, 2008 at 9:00 a.m.

# %%
def create_data_sets(sentences):
    size = int(len(sentences) * 0.9)
    train_sents = sentences[:size]
    test_sents = sentences[size:]
    return train_sents, test_sents

def build_backoff_tagger (train_sents):
    t0 = nltk.DefaultTagger('NN')
    t1 = nltk.UnigramTagger(train_sents, backoff=t0)
    t2 = nltk.BigramTagger(train_sents, backoff=t1)
    return t2 

def train_tagger(already_tagged_sents):
    train_sents, test_sents = create_data_sets(already_tagged_sents)
    ngram_tagger = build_backoff_tagger(train_sents)
    print ("%0.3f pos accuracy on test set" % ngram_tagger.evaluate(test_sents))
    return ngram_tagger

# %%
def train_tagger_on_brown():
    brown_tagged_sents = treebank.tagged_sents()
    return train_tagger(brown_tagged_sents)

# %%
brown_tagger = train_tagger_on_brown()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-af70fd43849f> in <module>()
# ----> 1 brown_tagger = train_tagger_on_brown()
#
# <ipython-input-19-4a117f9efdf5> in train_tagger_on_brown()
#       1 def train_tagger_on_brown():
# ----> 2     brown_tagged_sents = treebank.tagged_sents()
#       3     return train_tagger(brown_tagged_sents)
#
# AttributeError: module 'nltk.tokenize.treebank' has no attribute 'tagged_sents'

# %%
def tokenize_text(corpus):
    sent_tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
    raw_sents = sent_tokenizer.tokenize(corpus) # Split text into sentences    
    return [nltk.word_tokenize(word.lower()) for word in raw_sents]

def create_corpus(f): 
    with open(f, 'r',encoding='ISO-8859-1') as text_file: 
        new_corpus = text_file.read()
        start = (new_corpus.find("REPORT OF ACTION TAKEN IN CLOSED SESSION")) +85
        end = (new_corpus.rfind('Certified Shorthand Reporter'))-10
        new_corpus = new_corpus[start:end]
        new_corpus= new_corpus.replace("- \n","")
    return new_corpus

# %%
mybook_file = '115039_12-16-08.txt'
mybook_sents = tokenize_text(create_corpus(mybook_file))
mybook_sents
# Out:
# [['sup', '.'],
#  ['knabe',
#   ',',
#   'chair',
#   ':',
#   'call',
#   'the',
#   'meeting',
#   'to',
#   'order',
#   ',',
#   'please',
#   ',',
#   'if',
#   'everyone',
#   'would',
#   'please',
#   'rise',
#   '.'],
#  ['we',
#   'will',
#   'be',
#   'led',
#   'in',
#   'the',
#   'invocation',
#   'this',
#   'morning',
#   'by',
#   'father',
#   'mauricio',
#   'goloron',
#   'from',
#   'st.',
#   'martha',
#   "'s",
#   'church',
#   'in',
#   'la',
#   'puente',
#   'and',
#   'the',
#   'pledge',
#   'led',
#   'by',
#   'victor',
#   'aprea',
#   ',',
#   'member',
#   'post',
#   '790',
#   ',',
#   'west',
#   'covina',
#   ',',
#   'the',
#   'american',
#   'legion',
#   '.'],
#  ['father', '?'],
#  ['fr', '.'],
#  ['mauricio',
#   'goloron',
#   ':',
#   'god',
#   ',',
#   'who',
#   'called',
#   'us',
#   'out',
#   'of',
#   'darkness',
#   'into',
#   'his',
#   'wonderful',
#   'light',
#   '.'],
#  ['may',
#   'god',
#   "'s",
#   'light',
#   'guide',
#   'us',
#   'and',
#   'protect',
#   'us',
#   'as',
#   'a',
#   'community',
#   '.'],
#  ['may',
#   'god',
#   "'s",
#   'wisdom',
#   'direct',
#   'this',
#   'board',
#   'in',
#   'its',
#   'work',
#   'and',
#   'decisions',
#   'today',
#   'and',
#   'every',
#   'day',
#   '.'],
#  ['may',
#   'god',
#   "'s",
#   'love',
#   'strengthen',
#   'all',
#   'those',
#   'who',
#   'work',
#   'for',
#   'our',
#   'county',
#   'and',
#   'make',
#   'god',
#   "'s",
#   'peace',
#   ',',
#   'make',
#   'us',
#   'one',
#   ',',
#   'and',
#   'help',
#   'us',
#   'to',
#   'always',
#   'strive',
#   'for',
#   'the',
#   'common',
#   'good',
#   'of',
#   'all',
#   'our',
#   'neighbors',
#   '.'],
#  ['(', 'repeats', 'prayer', 'in', 'spanish', '.', ')'],
#  ['(', 'repeats', 'prayer', 'in', 'tagalog', '.', ')'],
#  ['amen',
#   'victor',
#   'aprea',
#   ':',
#   'please',
#   'face',
#   'the',
#   'flag',
#   ',',
#   'placing',
#   'your',
#   'right',
#   'land',
#   'over',
#   'your',
#   'heart',
#   'and',
#   'joining',
#   'me',
#   'in',
#   'the',
#   'pledge',
#   'of',
#   'allegiance',
#   '.'],
#  ['[', 'pledge', 'of', 'allegiance', 'recited', '.', ']'],
#  ['thank', 'you', '.'],
#  ['supervisor', 'molina', '?'],
#  ['sup', '.'],
#  ['molina', ':', 'thank', 'you', ',', 'mr.', 'chairman', '.'],
#  ['it',
#   "'s",
#   'my',
#   'honor',
#   'this',
#   'morning',
#   'to',
#   'present',
#   'a',
#   'certificate',
#   'of',
#   'appreciation',
#   'to',
#   'father',
#   'mauricio',
#   'goloron',
#   '.'],
#  ['father',
#   'goloron',
#   'was',
#   'born',
#   'and',
#   'raised',
#   'in',
#   'the',
#   'southern',
#   'philippines',
#   '.'],
#  ['he',
#   'entered',
#   'the',
#   'seminary',
#   'at',
#   'the',
#   'age',
#   'of',
#   '12',
#   'and',
#   'educated',
#   'by',
#   'the',
#   'society',
#   'of',
#   'jesus',
#   'and',
#   'became',
#   'an',
#   'ordained',
#   'priest',
#   'in',
#   '1984',
#   '.'],
#  ['in',
#   '1998',
#   ',',
#   'father',
#   'goloron',
#   'came',
#   'to',
#   'united',
#   'states',
#   '.'],
#  ['he',
#   'served',
#   'at',
#   'the',
#   'immaculate',
#   'heart',
#   'of',
#   'mary',
#   'church',
#   'in',
#   'hollywood',
#   ',',
#   'st.',
#   'catherine',
#   'laborne',
#   'church',
#   'in',
#   'torrens',
#   'and',
#   'currently',
#   'heads',
#   'up',
#   'the',
#   'robust',
#   'congregation',
#   'at',
#   'st.',
#   'martha',
#   "'s",
#   'church',
#   'in',
#   'velinda',
#   '.'],
#  ['st.',
#   'martha',
#   "'s",
#   'is',
#   'situated',
#   'in',
#   'a',
#   'thriving',
#   'community',
#   'and',
#   'their',
#   'many',
#   'compassionate',
#   'parishioners',
#   'are',
#   'devoted',
#   'to',
#   'good',
#   'works',
#   'and',
#   'community',
#   'service',
#   ',',
#   'such',
#   'as',
#   'offering',
#   'food',
#   'banks',
#   'and',
#   'donating',
#   'clothing',
#   'bank',
#   'for',
#   'the',
#   'needy',
#   '.'],
#  ['we',
#   'want',
#   'to',
#   'extend',
#   'our',
#   'heartfelt',
#   'thanks',
#   'to',
#   'father',
#   'goloron',
#   'and',
#   'we',
#   'want',
#   'to',
#   'present',
#   'him',
#   'a',
#   'certificate',
#   'of',
#   'appreciation',
#   'for',
#   'leading',
#   'us',
#   'in',
#   'our',
#   'invocation',
#   '.'],
#  ['thank', 'you', ',', 'father', '.'],
#  ['[', 'applause', '.', ']'],
#  ['supervisor', 'antonovich', '?'],
#  ['sup', '.'],
#  ['antonovich',
#   ':',
#   'once',
#   'again',
#   'we',
#   'want',
#   'to',
#   'welcome',
#   'victor',
#   'aprea',
#   'from',
#   'covina',
#   'who',
#   'came',
#   'down',
#   'today',
#   'as',
#   'a',
#   'member',
#   'of',
#   'the',
#   'west',
#   'covina',
#   'post',
#   'of',
#   'the',
#   '790',
#   'of',
#   'the',
#   'american',
#   'legion',
#   '.'],
#  ['he',
#   'retired',
#   'as',
#   'administrative',
#   'assistant',
#   'for',
#   'the',
#   'city',
#   'of',
#   'los',
#   'angeles',
#   'transportation',
#   'department',
#   '.'],
#  ['graduate',
#   'of',
#   'washington',
#   'generals',
#   'high',
#   'school',
#   'in',
#   'los',
#   'angeles',
#   'and',
#   'university',
#   'of',
#   'southern',
#   'california',
#   '.'],
#  ['thank', 'you', 'for', 'coming', 'down', '.'],
#  ['[', 'applause', '.', ']'],
#  ['sup', '.'],
#  ['knabe', ',', 'chair', ':', 'okay', '.'],
#  ['we',
#   'will',
#   'proceed',
#   'with',
#   'the',
#   'reading',
#   'of',
#   'the',
#   'agenda',
#   '.'],
#  ['clerk',
#   'sachi',
#   'hamai',
#   ':',
#   'good',
#   'morning',
#   ',',
#   'mr.',
#   'chairman',
#   ',',
#   'members',
#   'of',
#   'the',
#   'board',
#   '.'],
#  ['we',
#   'will',
#   'begin',
#   'today',
#   "'s",
#   'agenda',
#   'on',
#   'page',
#   '3',
#   ',',
#   'agenda',
#   'for',
#   'the',
#   'meeting',
#   'of',
#   'the',
#   'community',
#   'development',
#   'commission',
#   '.'],
#  ['items', '1-d', 'through', '4-d.', 'sup', '.'],
#  ['knabe',
#   ',',
#   'chair',
#   ':',
#   'moved',
#   'by',
#   'supervisor',
#   'yaroslavsky',
#   ',',
#   'seconded',
#   'by',
#   'antonovich',
#   '.'],
#  ['without', 'objection', ',', 'so', 'ordered', '.'],
#  ['clerk',
#   'sachi',
#   'hamai',
#   ':',
#   'agenda',
#   'for',
#   'the',
#   'meeting',
#   'of',
#   'the',
#   'housing',
#   'authority',
#   ',',
#   'item',
#   '1-h.',
#   'sup',
#   '.'],
#  ['knabe', ',', 'chair', ':', 'which', '?'],
#  ['clerk',
#   'sachi',
#   'hamai',
#   ':',
#   'item',
#   '1-h',
#   ',',
#   'agenda',
#   'for',
#   'the',
#   'housing',
#   'authority',
#   '.'],
#  ['sup', '.'],
#  ['knabe', ',', 'chair', ':', 'moved', 'by', 'yaroslavsky', '.'],
#  ['seconded', 'by', 'molina', '.'],
#  ['without', 'objection', ',', 'so', 'ordered', '.'],
#  ['clerk',
#   'sachi',
#   'hamai',
#   ':',
#   'page',
#   '6',
#   ',',
#   'agenda',
#   'for',
#   'the',
#   'meeting',
#   'of',
#   'the',
#   'regional',
#   'park',
#   'and',
#   'open',
#   'space',
#   'district',
#   ',',
#   'item',
#   '1-p.',
#   'sup',
#   '.'],
#  ['knabe', ',', 'chair', ':', 'moved', 'by', 'supervisor', 'molina', '.'],
#  ['seconded',
#   'by',
#   'supervisor',
#   'antonovich',
#   ',',
#   'without',
#   'objection',
#   ',',
#   'so',
#   'ordered',
#   '.'],
#  ['clerk',
#   'sachi',
#   'hamai',
#   ':',
#   'board',
#   'of',
#   'supervisors',
#   'items',
#   '1',
#   'through',
#   '7',
#   '.'],
#  ['on',
#   'item',
#   'number',
#   '7',
#   ',',
#   'there',
#   'is',
#   'a',
#   'request',
#   'from',
#   'a',
#   'member',
#   'of',
#   'the',
#   'public',
#   'to',
#   'hold',
#   'this',
#   'item',
#   '.'],
#  ['the', 'remaining', 'items', 'are', 'before', 'you', '.'],
#  ['sup', '.'],
#  ['knabe', ',', 'chair', ':', 'hold', 'item', '7', '?'],
#  ['clerk', 'sachi', 'hamai', ':', 'yes', '.'],
#  ['sup', '.'],
#  ['knabe', ',', 'chair', ':', 'okay', '.'],
#  ['on',
#   'the',
#   'remainder',
#   ',',
#   'moved',
#   'by',
#   'supervisor',
#   'ridley-thomas',
#   ',',
#   'seconded',
#   'by',
#   'the',
#   'chair',
#   '.'],
#  ['without', 'objection', ',', 'so', 'ordered', '.'],
#  ['clerk',
#   'sachi',
#   'hamai',
#   ':',
#   'on',
#   'items',
#   '8',
#   'through',
#   '66',
#   ',',
#   'on',
#   'item',
#   'number',
#   '8',
#   ',',
#   'as',
#   'posted',
#   'on',
#   'the',
#   'agenda',
#   ',',
#   'the',
#   'chief',
#   'executive',
#   'officer',
#   'requests',
#   'that',
#   'this',
#   'item',
#   'be',
#   'referred',
#   'back',
#   'to',
#   'his',
#   'office',
#   '.'],
#  ['sup', '.'],
#  ['knabe', ',', 'chair', ':', 'the', 'remainder', 'are', 'before', 'us', '?'],
#  ['clerk', 'sachi', 'hamai', ':', 'no', ',', 'on', 'item', '8', '.'],
#  ['sup', '.'],
#  ['knabe', ',', 'chair', ':', 'so', 'ordered', '.'],
#  ['clerk',
#   'sachi',
#   'hamai',
#   ':',
#   'on',
#   'item',
#   '10',
#   ',',
#   'supervisor',
#   'antonovich',
#   'requests',
#   'that',
#   'this',
#   'item',
#   'be',
#   'held',
#   '.'],
#  ['on',
#   'item',
#   'number',
#   '12',
#   ',',
#   'supervisor',
#   'knabe',
#   'requests',
#   'that',
#   'this',
#   'item',
#   'be',
#   'held',
#   '.'],
#  ['on',
#   'item',
#   'number',
#   '13',
#   ',',
#   'the',
#   'chief',
#   'executive',
#   'officer',
#   'requests',
#   'that',
#   'this',
#   'item',
#   'be',
#   'continued',
#   'to',
#   'january',
#   '13th',
#   ',',
#   '2009',
#   '.'],
#  ['sup', '.'],
#  ['knabe', ',', 'chair', ':', 'so', 'ordered', '.'],
#  ['clerk',
#   'sachi',
#   'hamai',
#   ':',
#   'on',
#   'item',
#   'number',
#   '20',
#   ',',
#   'supervisor',
#   'knabe',
#   'requests',
#   'that',
#   'this',
#   'item',
#   'be',
#   'held',
#   '.'],
#  ['on',
#   'item',
#   'number',
#   '23',
#   ',',
#   'supervisor',
#   'knabe',
#   'and',
#   'a',
#   'member',
#   'of',
#   'the',
#   'public',
#   'request',
#   'that',
#   'this',
#   'item',
#   'be',
#   'held',
#   '.'],
#  ['23', '?'],
#  ['on',
#   'item',
#   'number',
#   '28',
#   ',',
#   'there',
#   "'s",
#   'a',
#   'request',
#   'from',
#   'a',
#   'member',
#   'of',
#   'the',
#   'public',
#   'to',
#   'hold',
#   'this',
#   'item',
#   '.'],
#  ['28', '?'],
#  ['on',
#   'item',
#   'number',
#   '33',
#   ',',
#   'there',
#   "'s",
#   'a',
#   'request',
#   'from',
#   'a',
#   'member',
#   'of',
#   'the',
#   'public',
#   'to',
#   'hold',
#   'this',
#   'item',
#   '.'],
#  ['on',
#   'item',
#   'number',
#   '36',
#   ',',
#   'there',
#   "'s",
#   'a',
#   'request',
#   'from',
#   'a',
#   'member',
#   'of',
#   'the',
#   'public',
#   'to',
#   'hold',
#   'this',
#   'item',
#   '.'],
#  ['on',
#   'item',
#   'number',
#   '47',
#   ',',
#   'there',
#   "'s",
#   'a',
#   'request',
#   'from',
#   'a',
#   'member',
#   'of',
#   'the',
#   'public',
#   'to',
#   'hold',
#   'this',
#   'item',
#   '.'],
#  ['on',
#   'item',
#   '51',
#   ',',
#   'there',
#   "'s",
#   'a',
#   'request',
#   'from',
#   'a',
#   'member',
#   'of',
#   'the',
#   'public',
#   'to',
#   'hold',
#   'this',
#   'item',
#   '.'],
#  ['and',
#   'on',
#   'item',
#   'number',
#   '60',
#   ',',
#   'the',
#   'interim',
#   'director',
#   'of',
#   'health',
#   'services',
#   'requests',
#   'that',
#   'the',
#   'corrective',
#   'action',
#   'plan',
#   'be',
#   'continued',
#   'to',
#   'january',
#   '6th',
#   ',',
#   '2009',
#   ',',
#   'but',
#   'the',
#   'settlement',
#   'be',
#   'approved',
#   'today',
#   '.'],
#  ['and', 'the', 'remaining', 'items', 'are', 'before', 'you', '.'],
#  ['sup', '.'],
#  ['knabe',
#   ',',
#   'chair',
#   ':',
#   'on',
#   'the',
#   'remaining',
#   'items',
#   ',',
#   'moved',
#   'by',
#   'supervisor',
#   'ridley-thomas',
#   '.'],
#  ['seconded', 'by', 'supervisor', 'yaroslavsky', '.'],
#  ['without', 'objection', ',', 'so', 'ordered', '.'],
#  ['recognizing', 'those', 'holds', 'and', 'continuances', '.'],
#  ['clerk', 'sachi', 'hamai', ':', 'thank', 'you', '.'],
#  ['on', 'page', '32', ',', 'ordinance', 'for', 'introduction', '.'],
#  ['and',
#   'on',
#   'item',
#   'number',
#   '67',
#   ',',
#   'as',
#   'indicated',
#   'on',
#   'the',
#   'posted',
#   'agenda',
#   ',',
#   'the',
#   'chief',
#   'executive',
#   'officer',
#   'requests',
#   'that',
#   'this',
#   'item',
#   'be',
#   'referred',
#   'back',
#   'to',
#   'his',
#   'office',
#   '.'],
#  ['sup', '.'],
#  ['knabe', ',', 'chair', ':', 'so', 'ordered', '.'],
#  ['clerk', 'sachi', 'hamai', ':', 'discussion', 'items', '.'],
#  ['items',
#   '67',
#   'through',
#   '73',
#   ',',
#   'on',
#   'item',
#   '68',
#   'we',
#   'will',
#   'hold',
#   'for',
#   'a',
#   'discussion',
#   '.'],
#  ['on',
#   'item',
#   '69',
#   ',',
#   'as',
#   'indicated',
#   'on',
#   'the',
#   'supplemental',
#   'agenda',
#   ',',
#   'this',
#   'recommendation',
#   'was',
#   'revised',
#   'and',
#   'we',
#   'will',
#   'also',
#   'hold',
#   'this',
#   'for',
#   'a',
#   'discussion',
#   '.'],
#  ['item', '70', 'we', 'will', 'hold', 'for', 'discussion', '.'],
#  ['public',
#   'hearings',
#   ',',
#   'item',
#   '71',
#   'we',
#   'will',
#   'hold',
#   'for',
#   'a',
#   'public',
#   'hearing',
#   '.'],
#  ['on',
#   'item',
#   '72',
#   ',',
#   'as',
#   'indicated',
#   'on',
#   'the',
#   'supplemental',
#   'agenda',
#   ',',
#   'supervisor',
#   'ridley-thomas',
#   'requests',
#   'that',
#   'this',
#   'item',
#   'be',
#   'continued',
#   'without',
#   'discussion',
#   'to',
#   'january',
#   '27th',
#   ',',
#   '2009',
#   '.'],
#  ['sup', '.'],
#  ['knabe', ',', 'chair', ':', 'so', 'ordered', '.'],
#  ['clerk',
#   'sachi',
#   'hamai',
#   ':',
#   'on',
#   'item',
#   '73',
#   ',',
#   'as',
#   'indicated',
#   'on',
#   'the',
#   'supplemental',
#   'agenda',
#   ',',
#   'supervisor',
#   'ridley-thomas',
#   'requests',
#   'that',
#   'this',
#   'item',
#   'be',
#   'continued',
#   'without',
#   'discussion',
#   'to',
#   'february',
#   '24th',
#   ',',
#   '2009',
#   '.'],
#  ['sup', '.'],
#  ['knabe', ',', 'chair', ':', 'so', 'ordered', '.'],
#  ['clerk',
#   'sachi',
#   'hamai',
#   ':',
#   'page',
#   '35',
#   ',',
#   'miscellaneous',
#   'additions',
#   'to',
#   'the',
#   'agenda',
#   'which',
#   'were',
#   'posted',
#   'more',
#   'than',
#   '72',
#   'hours',
#   'in',
#   'an',
#   'advance',
#   'of',
#   'the',
#   'meeting',
#   'as',
#   'indicated',
#   'on',
#   'the',
#   'supplemental',
#   'agenda',
#   '.'],
#  ['on',
#   '74-a',
#   ',',
#   'there',
#   'is',
#   'a',
#   'request',
#   'from',
#   'a',
#   'member',
#   'of',
#   'the',
#   'public',
#   'to',
#   'hold',
#   'this',
#   'item',
#   '.'],
#  ['on',
#   '74-b',
#   ',',
#   'pursuant',
#   'to',
#   'government',
#   'code',
#   'section',
#   '54957',
#   ',',
#   'the',
#   'chief',
#   'executive',
#   'officer',
#   'requests',
#   'that',
#   'this',
#   'be',
#   'referred',
#   'to',
#   'closed',
#   'session',
#   '.'],
#  ['sup', '.'],
#  ['knabe', ',', 'chair', ':', 'so', 'ordered', '.'],
#  ['clerk',
#   'sachi',
#   'hamai',
#   ':',
#   'that',
#   'completes',
#   'the',
#   'reading',
#   'of',
#   'the',
#   'agenda',
#   '.'],
#  ['supervisorial',
#   'items',
#   'begin',
#   'with',
#   'supervisorial',
#   'district',
#   'number',
#   '1',
#   '.'],
#  ['sup', '.'],
#  ['knabe',
#   ',',
#   'chair',
#   ':',
#   'we',
#   'have',
#   'a',
#   'number',
#   'of',
#   'special',
#   'presentations',
#   '.'],
#  ['i',
#   'will',
#   'call',
#   'on',
#   'supervisor',
#   'antonovich',
#   'and',
#   'then',
#   'supervisor',
#   'ridley-thomas',
#   '.'],
#  ['sup', '.'],
#  ['antonovich',
#   ':',
#   'well',
#   ',',
#   'it',
#   "'s",
#   'a',
#   'real',
#   'great',
#   'pleasure',
#   'to',
#   'introduce',
#   'one',
#   'of',
#   'the',
#   'great',
#   'role',
#   'models',
#   ',',
#   'michael',
#   'scioscia',
#   ',',
#   'the',
#   'former',
#   'manager',
#   'of',
#   'the',
#   'los',
#   'angeles',
#   'angels',
#   'at',
#   'anaheim',
#   ',',
#   'formerly',
#   'the',
#   'california',
#   'angels',
#   ',',
#   'and',
#   'formerly',
#   'the',
#   'los',
#   'angeles',
#   'angels',
#   ',',
#   'and',
#   'now',
#   'the',
#   'los',
#   'angeles',
#   'angels',
#   'at',
#   'anaheim',
#   ',',
#   'and',
#   'they',
#   'often',
#   'play',
#   'the',
#   'los',
#   'angeles',
#   'dodgers',
#   'at',
#   'chinatown',
#   'from',
#   'time',
#   'to',
#   'time',
#   '.'],
#  ['[', 'laughter', '.', ']'],
#  ['in',
#   'recognition',
#   'of',
#   'their',
#   'hard',
#   'work',
#   'and',
#   'leadership',
#   'and',
#   'dedication',
#   'towards',
#   'guiding',
#   'the',
#   'angels',
#   'of',
#   'anaheim',
#   'to',
#   'the',
#   '2008',
#   'american',
#   'league',
#   'western',
#   'division',
#   'championship',
#   'for',
#   'the',
#   'second',
#   'consecutive',
#   'year',
#   'and',
#   'posting',
#   'over',
#   '100',
#   'wins',
#   'in',
#   'a',
#   'single',
#   'system',
#   'for',
#   'the',
#   'first',
#   'time',
#   'in',
#   'their',
#   'franchise',
#   'history',
#   ',',
#   'the',
#   '2008',
#   'angels',
#   ',',
#   'it',
#   'was',
#   'the',
#   '48th',
#   'season',
#   'for',
#   'the',
#   'franchise',
#   '.'],
#  ['the',
#   'regular',
#   'season',
#   'ended',
#   'with',
#   'the',
#   'angels',
#   'winning',
#   'their',
#   'seventh',
#   'american',
#   'west',
#   'division',
#   'title',
#   'and',
#   'setting',
#   'a',
#   'franchise',
#   'record',
#   'for',
#   'the',
#   'single',
#   'season',
#   'wins',
#   '.'],
#  ['mike',
#   'scioscia',
#   ',',
#   'former',
#   'catcher',
#   'for',
#   'the',
#   'los',
#   'angeles',
#   'dodgers',
#   ',',
#   'marked',
#   'his',
#   'ninth',
#   'season',
#   'as',
#   'manager',
#   'of',
#   'the',
#   'angels',
#   '.'],
#  ['he',
#   'owns',
#   'an',
#   '803',
#   'to',
#   '655',
#   'win-loss',
#   'record',
#   'for',
#   '551',
#   'winning',
#   'percentage',
#   'with',
#   'the',
#   'angels',
#   '.'],
#  ['he',
#   'reached',
#   'the',
#   '800',
#   'win',
#   'plateau',
#   'on',
#   'september',
#   '22nd',
#   'with',
#   'a',
#   '2-1',
#   'victory',
#   'over',
#   'seattle',
#   '.'],
#  ['presently',
#   ',',
#   'michael',
#   'is',
#   'the',
#   'longest-tenured',
#   'manager',
#   'in',
#   'american',
#   'league',
#   'baseball',
#   '.'],
#  ['he', "'s", 'the', '16th', 'manager', 'in', 'angel', 'history', '.'],
#  ['and',
#   'he',
#   "'s",
#   'guided',
#   'the',
#   'angels',
#   'to',
#   'the',
#   'post',
#   'season',
#   'in',
#   'four',
#   'of',
#   'the',
#   'last',
#   'five',
#   'seasons',
#   '.'],
#  ['he',
#   "'s",
#   'the',
#   'only',
#   'angels',
#   'manager',
#   'to',
#   'win',
#   'american',
#   'league',
#   "'s",
#   'western',
#   'division',
#   'championship',
#   ',',
#   'surpassing',
#   'gene',
#   'mock',
#   '.'],
#  ['and',
#   'he',
#   "'s",
#   'led',
#   'the',
#   'angels',
#   'to',
#   'five',
#   'straight',
#   'winning',
#   'seasons',
#   ',',
#   '2004',
#   'through',
#   '2008',
#   '.'],
#  ['under',
#   'his',
#   'leadership',
#   ',',
#   'they',
#   'have',
#   'won',
#   '90',
#   'or',
#   'more',
#   'in',
#   'five',
#   'of',
#   'the',
#   'last',
#   'seven',
#   'seasons',
#   '.'],
#  ['the',
#   'numerous',
#   'community',
#   'events',
#   'include',
#   'he',
#   "'s",
#   'co',
#   'chair',
#   'of',
#   'the',
#   'angels',
#   'care',
#   '65',
#   'roses',
#   'golf',
#   'tournament',
#   ',',
#   'the',
#   'chairman',
#   'of',
#   'the',
#   'heart',
#   'association',
#   'heart',
#   'and',
#   'soul',
#   'walk',
#   ',',
#   'supports',
#   'local',
#   'little',
#   'leagues',
#   'throughout',
#   'the',
#   'mike',
#   'scioscia',
#   'youth',
#   'baseball',
#   'clinic',
#   'make-a-wish',
#   'foundation',
#   ',',
#   'and',
#   'also',
#   ',',
#   'through',
#   'his',
#   'leadership',
#   ',',
#   'the',
#   'monrovia',
#   'boys',
#   'and',
#   'girls',
#   'club',
#   'raise',
#   'about',
#   '75',
#   'percent',
#   'of',
#   'their',
#   'budget',
#   'each',
#   'january/february',
#   'when',
#   'they',
#   'do',
#   'their',
#   'annual',
#   'dinner',
#   'and',
#   'mike',
#   'does',
#   'a',
#   'phenomenal',
#   'job',
#   'as',
#   'the',
#   'auctioneer',
#   '.'],
#  ['and',
#   'they',
#   'raise',
#   'that',
#   'amount',
#   'of',
#   'money',
#   'for',
#   'the',
#   'entire',
#   'year',
#   '.'],
#  ['it',
#   'helps',
#   'the',
#   'young',
#   'boys',
#   'and',
#   'girls',
#   'in',
#   'the',
#   'san',
#   'gabriel',
#   'valley',
#   'in',
#   'monrovia',
#   '.'],
#  ['he',
#   'was',
#   'inducted',
#   'into',
#   'the',
#   'italian',
#   'american',
#   'hall',
#   'of',
#   'fame',
#   'in',
#   '2007',
#   'and',
#   'major',
#   'league',
#   'baseball',
#   "'s",
#   'arizona',
#   'fall',
#   'league',
#   'of',
#   'fame',
#   '.'],
#  ['we',
#   'are',
#   'also',
#   'honoring',
#   'los',
#   'angeles',
#   'angels',
#   'for',
#   'inviting',
#   'los',
#   'angeles',
#   'county',
#   "'s",
#   'boys',
#   'and',
#   'girls',
#   'to',
#   'attend',
#   'their',
#   'annual',
#   'children',
#   "'s",
#   'holiday',
#   'celebration',
#   ',',
#   'which',
#   'takes',
#   'place',
#   'today',
#   ',',
#   'this',
#   'afternoon',
#   ',',
#   'at',
#   'angels',
#   'stadium',
#   '.'],
#  ['tony',
#   'riggins',
#   ',',
#   'the',
#   'general',
#   'manager',
#   ',',
#   'and',
#   'michael',
#   'will',
#   'be',
#   'reading',
#   'to',
#   'the',
#   'children',
#   '.'],
#  ['the',
#   'children',
#   'will',
#   'also',
#   'get',
#   'the',
#   'opportunity',
#   'to',
#   'sing',
#   'the',
#   'holiday',
#   'songs',
#   'and',
#   'make',
#   'specially',
#   'designed',
#   'angel',
#   'christmas',
#   'tree',
#   'ornaments',
#   '.'],
#  ['they',
#   "'re",
#   'also',
#   'treated',
#   'to',
#   'a',
#   'traditional',
#   'baseball',
#   'meal',
#   'and',
#   'are',
#   'allowed',
#   'to',
#   'select',
#   'their',
#   'own',
#   'christmas',
#   'gift',
#   '.'],
#  ['this',
#   'summer',
#   ',',
#   'as',
#   'part',
#   'of',
#   'a',
#   'national',
#   'summer',
#   'mental',
#   'health',
#   'awareness',
#   'program',
#   ',',
#   'i',
#   'teamed',
#   'up',
#   'with',
#   'the',
#   'angels',
#   "'",
#   'general',
#   'manager',
#   'tony',
#   'riggins',
#   'and',
#   'left',
#   'hand',
#   'pitcher',
#   'darren',
#   'oliver',
#   'in',
#   'hosting',
#   'a',
#   'prevention',
#   'and',
#   'early',
#   'intervention',
#   'event',
#   'encouraging',
#   'the',
#   'children',
#   'to',
#   'eat',
#   'the',
#   'proper',
#   'foods',
#   'that',
#   'would',
#   'turn',
#   'and',
#   'help',
#   'promote',
#   'a',
#   'positive',
#   'mental',
#   'health',
#   'and',
#   'wellness',
#   'attitude',
#   '.'],
#  ['more',
#   'than',
#   '200',
#   'students',
#   'from',
#   'frank',
#   'telamo',
#   'elementary',
#   'school',
#   'in',
#   'los',
#   'angeles',
#   ',',
#   'located',
#   'near',
#   'korea',
#   'town',
#   ',',
#   'where',
#   'nine',
#   'different',
#   'languages',
#   'are',
#   'spoken',
#   'on',
#   'campus',
#   ',',
#   'participated',
#   'in',
#   'this',
#   'very',
#   'exciting',
#   'event',
#   '.'],
#  ['so',
#   ',',
#   'michael',
#   ',',
#   'we',
#   'want',
#   'to',
#   'give',
#   'you',
#   ',',
#   'as',
#   'manager',
#   'of',
#   'the',
#   'year',
#   ',',
#   'this',
#   'plaque',
#   'from',
#   'the',
#   'county',
#   'of',
#   'los',
#   'angeles',
#   '.'],
#  ['and',
#   'we',
#   'wish',
#   'you',
#   'many',
#   ',',
#   'many',
#   'more',
#   'successful',
#   'seasons',
#   '.'],
#  ['and',
#   'i',
#   'had',
#   'the',
#   'opportunity',
#   'of',
#   'being',
#   'there',
#   'when',
#   'they',
#   'won',
#   'the',
#   'world',
#   'series',
#   'a',
#   'couple',
#   'years',
#   'ago',
#   ',',
#   'and',
#   'that',
#   'was',
#   'a',
#   'very',
#   'great',
#   'feeling',
#   '.'],
#  ['a',
#   'little',
#   'different',
#   'than',
#   'when',
#   'i',
#   'was',
#   'a',
#   'little',
#   'boy',
#   'at',
#   'wrigley',
#   'field',
#   'watching',
#   'the',
#   'los',
#   'angeles',
#   'angels',
#   'lose',
#   'under',
#   'bill',
#   'kelly',
#   'who',
#   'was',
#   'the',
#   'manager',
#   'then',
#   '.'],
#  ['anyway', ',', 'congratulations', 'and', 'god', 'bless', 'you', '.'],
#  ['[', 'applause', '.', ']'],
#  ['and',
#   'this',
#   'is',
#   'for',
#   'the',
#   'los',
#   'angeles',
#   'angels',
#   "'",
#   'western',
#   'division',
#   'championship',
#   '.'],
#  ['good', 'champions', '.'],
#  ['[', 'applause', '.', ']'],
#  ['mike',
#   'scioscia',
#   ':',
#   'supervisor',
#   'antonovich',
#   'and',
#   'all',
#   'the',
#   'board',
#   'of',
#   'supervisors',
#   ',',
#   'i',
#   'want',
#   'to',
#   'thank',
#   'you',
#   'ver',
#   'much',
#   'for',
#   'this',
#   'presentation',
#   ',',
#   'this',
#   'honor',
#   '.'],
#  ['the',
#   'amount',
#   'of',
#   'support',
#   'we',
#   'get',
#   'through',
#   'southern',
#   'california',
#   'is',
#   'incredible',
#   '.'],
#  ['almost',
#   '3.5',
#   'million',
#   'fans',
#   'came',
#   'to',
#   'see',
#   'us',
#   'down',
#   'at',
#   'angels',
#   "'",
#   'stadium',
#   '.'],
#  ['we', 'had', 'a', 'great', 'regular', 'season', '.'],
#  ['and',
#   'as',
#   'we',
#   'prepare',
#   'for',
#   'this',
#   'next',
#   'season',
#   ',',
#   '2009',
#   ',',
#   'supervisor',
#   ',',
#   'we',
#   "'re",
#   'going',
#   'to',
#   'do',
#   'a',
#   'little',
#   'better',
#   'in',
#   'the',
#   'playoffs',
#   '.'],
#  ['i',
#   'know',
#   'as',
#   'disappointed',
#   'as',
#   'you',
#   'were',
#   ',',
#   'we',
#   'were',
#   'more',
#   'disappointed',
#   '.'],
#  ['and', 'it', "'s", 'a', 'great', 'regular', 'season', 'we', 'had', '.'],
#  ['i',
#   'thank',
#   'you',
#   'for',
#   'this',
#   'plaque',
#   'and',
#   'this',
#   'ceremony',
#   '.'],
#  ['but',
#   'we',
#   'are',
#   'going',
#   'to',
#   'do',
#   'better',
#   'in',
#   'the',
#   'playoffs',
#   ',',
#   'supervisor',
#   ',',
#   'i',
#   'promise',
#   'you',
#   'that',
#   '.'],
#  ['thank', 'you', 'very', 'much', '.'],
#  ['god', 'bless', 'you', '.'],
#  ['[', 'applause', '.', ']'],
#  ['sup', '.'],
#  ['knabe', ',', 'chair', ':', 'all', 'right', '.'],
#  ['mark', '?'],
#  ['i',
#   'understand',
#   'you',
#   'have',
#   'a',
#   'very',
#   'special',
#   'presentation',
#   'for',
#   'us',
#   ',',
#   'as',
#   'well',
#   ',',
#   'too',
#   ',',
#   'huh',
#   '?'],
#  ['sup', '.'],
#  ['ridley-thomas',
#   ':',
#   'thank',
#   'you',
#   'very',
#   'much',
#   ',',
#   'mr.',
#   'chairman',
#   ',',
#   'members',
#   '.'],
#  ['i',
#   "'m",
#   'pleased',
#   'to',
#   'ask',
#   'that',
#   'we',
#   'be',
#   'joined',
#   'by',
#   'the',
#   'los',
#   'angeles',
#   'county',
#   'arts',
#   'commission',
#   'director',
#   '.'],
#  ['you',
#   'know',
#   'her',
#   'as',
#   'laura',
#   'zucker',
#   ',',
#   'and',
#   'those',
#   'representing',
#   'the',
#   'united',
#   'children',
#   "'s",
#   'chorus',
#   '.'],
#  ['the',
#   'directors',
#   'are',
#   'willie',
#   'norwood',
#   ',',
#   'sr.',
#   'and',
#   'ravaline',
#   'harold',
#   '.'],
#  ['and',
#   'members',
#   'of',
#   'that',
#   'chorus',
#   'you',
#   'will',
#   'hear',
#   'from',
#   'soon',
#   '.'],
#  ['i', "'d", 'like', 'for', 'you', 'to', 'know', 'that', 'the', 'u.c.c', '.'],
#  ['was',
#   'formed',
#   'in',
#   'the',
#   'summer',
#   'of',
#   '1993',
#   'during',
#   'what',
#   'is',
#   'known',
#   'as',
#   'the',
#   'crusade',
#   'for',
#   'christ',
#   'campaign',
#   'held',
#   'here',
#   'in',
#   'the',
#   'county',
#   'of',
#   'los',
#   'angeles',
#   '.'],
#  ['young',
#   'men',
#   'and',
#   'women',
#   'from',
#   'various',
#   'churches',
#   'of',
#   'christ',
#   'throughout',
#   'the',
#   'los',
#   'angeles',
#   'and',
#   'surrounding',
#   'counties',
#   'came',
#   'together',
#   'to',
#   'perform',
#   'what',
#   'is',
#   'known',
#   'as',
#   'this',
#   'tremendous',
#   'event',
#   '.'],
#  ['and',
#   'with',
#   'such',
#   'rave',
#   'reviews',
#   'following',
#   'that',
#   'event',
#   ',',
#   'it',
#   'was',
#   'requested',
#   'that',
#   'the',
#   'group',
#   'remain',
#   'together',
#   '.'],
#  ['you',
#   'will',
#   'want',
#   'to',
#   'know',
#   'that',
#   'this',
#   'group',
#   ',',
#   'ranging',
#   'in',
#   'ages',
#   '3',
#   'to',
#   'those',
#   'in',
#   'their',
#   'late',
#   '20s',
#   ',',
#   'enlighten',
#   'audiences',
#   'with',
#   'their',
#   'extraordinary',
#   'gifts',
#   'in',
#   'entertaining',
#   'us',
#   'in',
#   'that',
#   'which',
#   'we',
#   'know',
#   'as',
#   'a',
#   'capello',
#   'singing',
#   '.'],
#  ['the',
#   'chorus',
#   'director',
#   ',',
#   'willie',
#   'norwood',
#   'sr.',
#   ',',
#   'has',
#   'been',
#   'directing',
#   'the',
#   'u.c.c',
#   '.'],
#  ['for', 'the', 'last', '14', 'years', '.'],
#  ['he',
#   'is',
#   'the',
#   'minister',
#   'of',
#   'music',
#   'at',
#   'the',
#   'woodland',
#   'hills',
#   'church',
#   'of',
#   'christ',
#   'and',
#   'the',
#   'father',
#   'of',
#   'singer',
#   'actress',
#   'brandy',
#   'norwood',
#   'and',
#   'singer',
#   'actor',
#   'willie',
#   '``',
#   'ray',
#   'jay',
#   "''",
#   'norwood',
#   ',',
#   'who',
#   'also',
#   'sang',
#   'in',
#   'the',
#   'chorus',
#   '.'],
#  ['he',
#   "'s",
#   'vocally',
#   'talented',
#   ',',
#   'as',
#   'you',
#   'will',
#   'soon',
#   'see',
#   '.'],
#  ['and',
#   'those',
#   'who',
#   'are',
#   'part',
#   'of',
#   'his',
#   'family',
#   'are',
#   'six-year-old',
#   'granddaughter',
#   'has',
#   'also',
#   'joined',
#   'the',
#   'chorus',
#   '.'],
#  ['and',
#   'so',
#   'we',
#   'are',
#   'tremendously',
#   'honored',
#   'to',
#   'have',
#   'them',
#   'here',
#   'with',
#   'us',
#   'today',
#   ',',
#   'mr.',
#   'chairman',
#   'and',
#   'colleagues',
#   '.'],
#  ['you',
#   "'ll",
#   'want',
#   'to',
#   'note',
#   'the',
#   'figueroa',
#   'church',
#   'of',
#   'christ',
#   'has',
#   'that',
#   'which',
#   'we',
#   'know',
#   'as',
#   'the',
#   'little',
#   'angels',
#   "'",
#   'chorus',
#   ',',
#   'one',
#   'of',
#   'the',
#   'first',
#   'to',
#   'be',
#   'invited',
#   'here',
#   'to',
#   'sing',
#   'in',
#   'the',
#   'late',
#   "'60s",
#   '.'],
#  ['and',
#   'then',
#   'on',
#   'from',
#   'there',
#   'to',
#   'accomplish',
#   'many',
#   ',',
#   'many',
#   'great',
#   'things',
#   '.'],
#  ['and',
#   'so',
#   'let',
#   'me',
#   'just',
#   'say',
#   'that',
#   'we',
#   'are',
#   'indeed',
#   'pleased',
#   'to',
#   'have',
#   'them',
#   'with',
#   'us',
#   'this',
#   'morning',
#   '.'],
#  ['you',
#   'will',
#   'want',
#   'to',
#   'know',
#   'that',
#   'they',
#   'will',
#   'be',
#   'featured',
#   'on',
#   'the',
#   'holiday',
#   'celebration',
#   'national',
#   'show',
#   'on',
#   'december',
#   '17th',
#   'and',
#   'december',
#   'the',
#   '24th',
#   'at',
#   '10',
#   'p.m.',
#   'on',
#   'p.b.s',
#   '.'],
#  ['nationwide', '.'],
#  ['make', 'sure', 'that', 'you', 'do', "n't", 'miss', 'it', '.'],
#  ['in',
#   'addition',
#   ',',
#   'they',
#   'are',
#   'performing',
#   'at',
#   'the',
#   '49th',
#   'annual',
#   'holiday',
#   'celebration',
#   'at',
#   'the',
#   'dorothy',
#   'chandler',
#   'pavilion',
#   'on',
#   'december',
#   'the',
#   '24th',
#   '.'],
#  ['and',
#   'so',
#   'may',
#   'i',
#   'take',
#   'this',
#   'opportunity',
#   'to',
#   'present',
#   'this',
#   'presentation',
#   'to',
#   'you',
#   'and',
#   'thank',
#   'you',
#   'for',
#   'your',
#   'contributions',
#   '.'],
#  ['and',
#   'we',
#   'will',
#   'be',
#   'delighted',
#   'to',
#   'hear',
#   'from',
#   'you',
#   'immediately',
#   'following',
#   '.'],
#  ['so',
#   'please',
#   'join',
#   'me',
#   'in',
#   'welcoming',
#   'and',
#   'congratulating',
#   'united',
#   'children',
#   "'s",
#   'chorus',
#   '.'],
#  ['[', 'applause', '.', ']'],
#  ['we',
#   "'ll",
#   'hear',
#   'from',
#   'ravaline',
#   'and',
#   'then',
#   'we',
#   "'ll",
#   'hear',
#   'from',
#   'the',
#   'chorus',
#   '.'],
#  ['ravaline',
#   'harold',
#   ':',
#   'to',
#   'the',
#   'honorable',
#   'mark',
#   'ridley-thomas',
#   ',',
#   'our',
#   'supervisor',
#   'of',
#   'the',
#   'second',
#   'district',
#   'in',
#   'which',
#   'we',
#   'proudly',
#   'represent',
#   'and',
#   'to',
#   'the',
#   'other',
#   'supervisors',
#   'who',
#   'also',
#   'serve',
#   'this',
#   'great',
#   'city',
#   'of',
#   'los',
#   'angeles',
#   '.'],
#  ['to',
#   'laura',
#   'zucker',
#   'and',
#   'adam',
#   'davis',
#   'and',
#   'heather',
#   'rigby',
#   'of',
#   'the',
#   'los',
#   'angeles',
#   'county',
#   'arts',
#   'commission',
#   'for',
#   'your',
#   'recommendation',
#   'of',
#   'the',
#   'united',
#   'children',
#   "'s",
#   'chorus',
#   'for',
#   'this',
#   'great',
#   'honor',
#   '.'],
#  ['mr.',
#   'norwood',
#   'and',
#   'i',
#   'and',
#   'the',
#   'united',
#   'children',
#   "'s",
#   'chorus',
#   'and',
#   'their',
#   'parents',
#   'feel',
#   'very',
#   'privileged',
#   'today',
#   'to',
#   'accept',
#   'this',
#   'role',
#   ',',
#   'honoring',
#   'our',
#   'achievements',
#   'for',
#   'the',
#   'last',
#   '13',
#   'years',
#   '.'],
#  ['we',
#   'are',
#   'also',
#   'very',
#   'happy',
#   'once',
#   'again',
#   'to',
#   'perform',
#   'this',
#   'year',
#   'in',
#   'the',
#   '49th',
#   'annual',
#   'holiday',
#   'celebration',
#   ',',
#   'which',
#   'for',
#   'me',
#   'has',
#   'been',
#   'significant',
#   ',',
#   'dating',
#   'back',
#   'to',
#   'the',
#   'early',
#   "'60s",
#   'when',
#   'i',
#   'performed',
#   'when',
#   'i',
#   'was',
#   '12',
#   'years',
#   'old',
#   'with',
#   'supervisor',
#   'kenneth',
#   'hahn',
#   '.'],
#  ['so',
#   '49',
#   'years',
#   'later',
#   'now',
#   ',',
#   'i',
#   "'m",
#   'still',
#   'as',
#   'excited',
#   'to',
#   'be',
#   'working',
#   'with',
#   'this',
#   'magnificent',
#   'group',
#   'of',
#   'young',
#   'people',
#   ',',
#   'ages',
#   '4',
#   'through',
#   '20',
#   'as',
#   'was',
#   'mentioned',
#   '.'],
#  ['we',
#   'will',
#   'be',
#   'featured',
#   'on',
#   'the',
#   'one-hour',
#   'celebration',
#   'tomorrow',
#   'night',
#   '.'],
#  ['for',
#   'the',
#   'first',
#   'year',
#   'they',
#   'are',
#   'doing',
#   'highlights',
#   'of',
#   'the',
#   'version',
#   'of',
#   'the',
#   '2007',
#   'show',
#   '.'],
#  ['and',
#   'it',
#   'will',
#   'air',
#   'for',
#   'the',
#   'first',
#   'time',
#   'tomorrow',
#   'night',
#   ',',
#   'december',
#   '17th',
#   ',',
#   'at',
#   '10',
#   'p.m.',
#   'on',
#   'k.c.e.t',
#   '.'],
#  ['on',
#   'stations',
#   'across',
#   'the',
#   'country',
#   'and',
#   'again',
#   'on',
#   'christmas',
#   'eve',
#   '.'],
#  ['we',
#   'also',
#   'invite',
#   'you',
#   'down',
#   ',',
#   'as',
#   'supervisor',
#   'ridley-thomas',
#   'said',
#   ',',
#   'it',
#   "'s",
#   'free',
#   '.'],
#  ['it', "'s", 'free', 'parking', '.'],
#  ['so', 'invite', 'your', 'friends', '.'],
#  ['and', 'we', 'hope', 'to', 'see', 'you', 'all', 'there', '.'],
#  ['again',
#   ',',
#   'mr.',
#   'norwood',
#   ',',
#   'u.c.c.',
#   ',',
#   'the',
#   'parents',
#   'and',
#   'i',
#   ',',
#   'thank',
#   'you',
#   'for',
#   'this',
#   'wonderful',
#   'honor',
#   '.'],
#  ['and',
#   'we',
#   'hope',
#   'to',
#   'continue',
#   'working',
#   'and',
#   'serving',
#   'in',
#   'our',
#   'community',
#   'for',
#   'many',
#   'years',
#   'to',
#   'come',
#   '.'],
#  ['thank', 'you', 'again', '.'],
#  ['[', 'applause', '.', ']'],
#  ['i', 'believe', 'we', 'are', 'now', 'going', 'to', 'perform', '.'],
#  ['and',
#   'we',
#   'will',
#   'be',
#   'performing',
#   'the',
#   'song',
#   'we',
#   "'ll",
#   'be',
#   'singing',
#   'on',
#   'the',
#   'national',
#   'show',
#   'tomorrow',
#   'night',
#   ',',
#   '``',
#   'jesus',
#   ',',
#   'oh',
#   'what',
#   'a',
#   'wonderful',
#   'child',
#   '.',
#   "''"],
#  ['u.c.c', '.'],
#  ['choir',
#   ':',
#   '(',
#   'singing',
#   ')',
#   'jesus',
#   ',',
#   'oh',
#   ',',
#   'what',
#   'a',
#   'wonderful',
#   'child',
#   '.'],
#  ['jesus',
#   ',',
#   'jesus',
#   ',',
#   'so',
#   'lowly',
#   ',',
#   'meek',
#   'and',
#   'mild',
#   'new',
#   'life',
#   ',',
#   'new',
#   'hope',
#   ',',
#   'new',
#   'joy',
#   'he',
#   'brings',
#   ',',
#   'wo',
#   "n't",
#   'you',
#   'listen',
#   'to',
#   'the',
#   'angels',
#   'sing',
#   ',',
#   'glory',
#   ',',
#   'glory',
#   ',',
#   'glory',
#   'to',
#   'the',
#   'newborn',
#   'king',
#   '.'],
#  ['jesus',
#   ',',
#   'jesus',
#   ',',
#   'jesus',
#   ',',
#   'oh',
#   'what',
#   'a',
#   'wonderful',
#   'child',
#   '.'],
#  ['jesus',
#   ',',
#   'jesus',
#   ',',
#   'jesus',
#   ',',
#   'so',
#   'lowly',
#   ',',
#   'meek',
#   'and',
#   'mild',
#   '.'],
#  ['new',
#   'life',
#   ',',
#   'new',
#   'hope',
#   ',',
#   'new',
#   'joy',
#   'he',
#   'brings',
#   ',',
#   'wo',
#   "n't",
#   'you',
#   'listen',
#   'to',
#   'the',
#   'angels',
#   'sing',
#   '?'],
#  ['glory', ',', 'glory', ',', 'glory', 'to', 'the', 'newborn', 'king', '.'],
#  ['he',
#   'was',
#   'heralded',
#   'by',
#   'the',
#   'angels',
#   ',',
#   'born',
#   'in',
#   'a',
#   'lowly',
#   'manger',
#   '.'],
#  ['the',
#   'virgin',
#   'mary',
#   'was',
#   'his',
#   'mother',
#   ',',
#   'and',
#   'joseph',
#   'was',
#   'his',
#   'earthly',
#   'father',
#   '.'],
#  ['three',
#   'wise',
#   'men',
#   'came',
#   'from',
#   'afar',
#   ',',
#   'they',
#   'were',
#   'guided',
#   'by',
#   'a',
#   'shining',
#   'star',
#   'to',
#   'see',
#   'king',
#   'jesus',
#   'where',
#   'he',
#   'lay',
#   'in',
#   'a',
#   'manger',
#   'filled',
#   'with',
#   'hay',
#   '.'],
#  ['jesus',
#   ',',
#   'jesus',
#   ',',
#   'jesus',
#   ',',
#   'oh',
#   'what',
#   'a',
#   'wonderful',
#   'child',
#   '.'],
#  ['jesus',
#   ',',
#   'jesus',
#   ',',
#   'jesus',
#   ',',
#   'so',
#   'lowly',
#   ',',
#   'meek',
#   'and',
#   'mild',
#   'new',
#   'life',
#   ',',
#   'new',
#   'hope',
#   ',',
#   'new',
#   'joy',
#   'he',
#   'brings',
#   ',',
#   'wo',
#   "n't",
#   'you',
#   'listen',
#   'to',
#   'the',
#   'angels',
#   'sing',
#   '?'],
#  ['glory', ',', 'glory', ',', 'glory', 'to', 'the', 'newborn', 'king', '.'],
#  ['he', 'was', 'heralded', 'by', 'the', 'angels', '.'],
#  ['he', 'was', 'he', 'was', 'born', 'in', 'a', 'lowly', 'manger', '.'],
#  ['the',
#   'virgin',
#   'mary',
#   'was',
#   'his',
#   'mother',
#   ',',
#   'and',
#   'you',
#   'know',
#   'joseph',
#   'was',
#   'his',
#   'earthly',
#   'father',
#   '.'],
#  ['three',
#   'wise',
#   'men',
#   'traveling',
#   'from',
#   'afar',
#   ',',
#   'they',
#   'were',
#   'guided',
#   'by',
#   'a',
#   'shining',
#   'star',
#   '.'],
#  ['they',
#   'wanted',
#   'to',
#   'see',
#   'king',
#   'jesus',
#   'where',
#   'he',
#   'lay',
#   'in',
#   'a',
#   'manger',
#   ',',
#   'filled',
#   'with',
#   'hay',
#   '.'],
#  ['jesus',
#   ',',
#   'jesus',
#   ',',
#   'jesus',
#   ',',
#   'oh',
#   'what',
#   'a',
#   'wonderful',
#   'child',
#   '.'],
#  ['jesus',
#   ',',
#   'jesus',
#   ',',
#   'jesus',
#   ',',
#   'so',
#   'lowly',
#   ',',
#   'meek',
#   'and',
#   'mild',
#   '.'],
#  ['new',
#   'life',
#   ',',
#   'new',
#   'hope',
#   ',',
#   'wo',
#   "n't",
#   'you',
#   'listen',
#   'to',
#   'the',
#   'angels',
#   'sing',
#   '?'],
#  ['glory', ',', 'glory', ',', 'glory', 'to', 'the', 'newborn', 'king', '.'],
#  ['yeah', ',', 'jesus', '.'],
#  ['glory', 'to', 'the', 'newborn', 'king', '.'],
#  ['glory',
#   ',',
#   'glory',
#   'to',
#   'the',
#   'newborn',
#   'heavenly',
#   'king',
#   'of',
#   'peace',
#   '.'],
#  ['[', 'applause', '.', ']'],
#  ['sup', '.'],
#  ['ridley-thomas', ':', 'we', 'thank', 'you', 'very', 'much', '.'],
#  ['and',
#   'we',
#   'appreciate',
#   'you',
#   'and',
#   'we',
#   'look',
#   'forward',
#   'to',
#   'seeing',
#   'you',
#   'on',
#   'p.b.s',
#   '.'],
#  ['tomorrow', 'evening', '.'],
#  ['and', 'then', 'on', 'the', '24th', '.'],
#  ['and',
#   'again',
#   'we',
#   'extend',
#   'a',
#   'warm',
#   'invitation',
#   'to',
#   'those',
#   'who',
#   'can',
#   'make',
#   'it',
#   'to',
#   'the',
#   'dorothy',
#   'chandler',
#   'pavilion',
#   '.'],
#  ['mr.',
#   'chairman',
#   ',',
#   'let',
#   "'s",
#   'give',
#   'them',
#   'another',
#   'big',
#   'round',
#   'of',
#   'applause',
#   '.'],
#  ['[', 'applause', '.', ']'],
#  ['sup', '.'],
#  ['knabe',
#   ',',
#   'chair',
#   ':',
#   'what',
#   'a',
#   'great',
#   'way',
#   'to',
#   'start',
#   'our',
#   'last',
#   'meeting',
#   'of',
#   'the',
#   'year',
#   '.'],
#  ['thank', 'you', 'all', 'very', 'much', '.'],
#  ['and',
#   'now',
#   'i',
#   "'m",
#   'going',
#   'to',
#   'ask',
#   'dr.',
#   'john',
#   'schunoff',
#   'and',
#   'kathy',
#   'cheister',
#   '[',
#   'ph',
#   '?',
#   ']'],
#  ['director',
#   'of',
#   'our',
#   'county',
#   "'s",
#   'emergency',
#   'medical',
#   'services',
#   'agency',
#   'to',
#   'join',
#   'me',
#   ',',
#   'along',
#   'with',
#   'representatives',
#   'from',
#   'the',
#   'county',
#   "'s",
#   '13',
#   'trauma',
#   'centers',
#   '.'],
#  ['it',
#   'is',
#   'my',
#   'pleasure',
#   'to',
#   'join',
#   'with',
#   'my',
#   'colleagues',
#   'today',
#   ',',
#   'and',
#   'they',
#   "'re",
#   'going',
#   'to',
#   'recognize',
#   'the',
#   'various',
#   'trauma',
#   'centers',
#   'in',
#   'their',
#   'districts',
#   ',',
#   'recognizing',
#   'our',
#   'los',
#   'angeles',
#   'county',
#   'trauma',
#   'system',
#   "'s",
#   '25th',
#   'anniversary',
#   '.'],
#  ['the',
#   'hospitals',
#   'that',
#   'we',
#   'honor',
#   'today',
#   'provide',
#   'county',
#   'residents',
#   'with',
#   'the',
#   'highest',
#   'level',
#   'of',
#   'life-saving',
#   'surgical',
#   'interventions',
#   'for',
#   'those',
#   'suffering',
#   'a',
#   'major',
#   'loss',
#   'or',
#   'shock',
#   'resulting',
#   'from',
#   'vehicular',
#   'crashes',
#   ',',
#   'gunshot',
#   'or',
#   'knife',
#   'wounds',
#   ',',
#   'falls',
#   'or',
#   'other',
#   'violent',
#   'accidents',
#   '.'],
#  ['trauma',
#   'is',
#   'the',
#   'leading',
#   'cause',
#   'of',
#   'death',
#   'for',
#   'people',
#   'between',
#   'the',
#   'ages',
#   'of',
#   '1',
#   'and',
#   '44',
#   '.'],
#  ['there',
#   'are',
#   'approximately',
#   '19,000',
#   'patients',
#   'treated',
#   'at',
#   'los',
#   'angeles',
#   'county',
#   'trauma',
#   'centers',
#   'per',
#   'year',
#   '.'],
#  ['that', "'s", 'roughly', '53', 'patients', 'a', 'day', '.'],
#  ['and',
#   'it',
#   "'s",
#   'since',
#   '1983',
#   ',',
#   'nearly',
#   '400,000',
#   'critically',
#   'injured',
#   'trauma',
#   'patients',
#   'have',
#   'been',
#   'treated',
#   'in',
#   'our',
#   'local',
#   'trauma',
#   'centers',
#   '.'],
#  ['before',
#   'i',
#   'make',
#   'the',
#   'presentation',
#   'to',
#   'my',
#   'two',
#   'hospitals',
#   ',',
#   'i',
#   'said',
#   'to',
#   'these',
#   'folks',
#   'upstairs',
#   'this',
#   'morning',
#   ',',
#   'i',
#   'said',
#   ',',
#   '``',
#   'i',
#   'guess',
#   'i',
#   'know',
#   'i',
#   "'ve",
#   'been',
#   'around',
#   'here',
#   'long',
#   'enough',
#   'because',
#   'i',
#   'remember',
#   'years',
#   'ago',
#   'when',
#   'everybody',
#   'walked',
#   'the',
#   'hauls',
#   'of',
#   'the',
#   'eighth',
#   'floor',
#   'to',
#   'ask',
#   'to',
#   'be',
#   'involved',
#   'in',
#   'trauma',
#   'service',
#   '.',
#   "''"],
#  ['we',
#   'created',
#   'a',
#   'level',
#   '1',
#   ',',
#   'and',
#   'then',
#   'we',
#   'created',
#   'a',
#   'level',
#   '2',
#   'and',
#   'level',
#   '3',
#   '.'],
#  ['and',
#   'i',
#   'said',
#   '``',
#   'ladies',
#   'and',
#   'gentlemen',
#   ',',
#   'these',
#   'are',
#   'the',
#   'survivors',
#   '.',
#   "''"],
#  ['so',
#   'let',
#   "'s",
#   'give',
#   'them',
#   'a',
#   'big',
#   'round',
#   'of',
#   'applause',
#   '.'],
#  ['[', 'applause', '.', ']'],
#  ['and',
#   'i',
#   "'m",
#   'going',
#   'to',
#   'ask',
#   'liz',
#   'ragenold',
#   'from',
#   'long',
#   'beach',
#   'memorial',
#   'medical',
#   'center',
#   'to',
#   'join',
#   'me',
#   '.'],
#  ['and',
#   'we',
#   'want',
#   'to',
#   'thank',
#   'long',
#   'beach',
#   'memorial',
#   'for',
#   'their',
#   'ongoing',
#   'efforts',
#   'in',
#   'the',
#   'service',
#   'of',
#   'trauma',
#   'care',
#   '.'],
#  ['thank', 'you', '.'],
#  ['and',
#   'then',
#   'dr.',
#   'james',
#   'murray',
#   'from',
#   'the',
#   'medical',
#   'center',
#   ',',
#   'as',
#   'well',
#   '.'],
#  ['appreciate', 'it', '.'],
#  ['the', 'city', 'of', 'long', 'beach', 'is', 'very', 'fortunate', '.'],
#  ['supervisor', 'molina', ',', 'you', 'have', 'some', 'presentations', '?'],
#  ['sup', '.'],
#  ['molina', ':', 'thank', 'you', ',', 'mr.', 'chairman', '.'],
#  ['you',
#   'know',
#   ',',
#   'we',
#   'ca',
#   "n't",
#   'say',
#   'enough',
#   'about',
#   'the',
#   'wonderful',
#   'partnership',
#   'we',
#   'have',
#   'in',
#   'the',
#   'whole',
#   'area',
#   'of',
#   'trauma',
#   '.'],
#  ['as',
#   'supervisor',
#   'knabe',
#   'said',
#   ',',
#   'years',
#   'ago',
#   ',',
#   'everybody',
#   'was',
#   'rushing',
#   'to',
#   'the',
#   'front',
#   'trying',
#   'to',
#   'figure',
#   'out',
#   'how',
#   'to',
#   'get',
#   'part',
#   'of',
#   'the',
#   'action',
#   '.'],
#  ['but',
#   'very',
#   ',',
#   'frankly',
#   ',',
#   'at',
#   'the',
#   'end',
#   'of',
#   'the',
#   'day',
#   ',',
#   'everybody',
#   'knows',
#   'it',
#   'is',
#   'the',
#   'hardest',
#   'service',
#   'delivery',
#   'model',
#   'there',
#   'is',
#   ',',
#   'and',
#   'yet',
#   'the',
#   'most',
#   'significant',
#   '.'],
#  ['each',
#   'of',
#   'us',
#   'hope',
#   'we',
#   'will',
#   'never',
#   'have',
#   'to',
#   'end',
#   'up',
#   'in',
#   'a',
#   'trauma',
#   'ward',
#   ',',
#   'but',
#   'the',
#   'reality',
#   'is',
#   'we',
#   'all',
#   'want',
#   'to',
#   'make',
#   'sure',
#   'there',
#   "'s",
#   'one',
#   'there',
#   'available',
#   'for',
#   'us',
#   'should',
#   'we',
#   'ever',
#   'need',
#   'it',
#   '.'],
#  ['so',
#   'we',
#   "'re",
#   'always',
#   'impressed',
#   'with',
#   'the',
#   'quality',
#   'of',
#   'the',
#   'work',
#   'and',
#   'the',
#   'delivery',
#   'of',
#   'patient',
#   'care',
#   'in',
#   'our',
#   'trauma',
#   'facilities',
#   '.'],
#  ['i',
#   'want',
#   'to',
#   'begin',
#   'by',
#   'honoring',
#   ',',
#   'of',
#   'course',
#   ',',
#   'one',
#   'of',
#   'our',
#   'very',
#   'own',
#   ',',
#   'l.a.',
#   'county',
#   'u.s.c.',
#   ',',
#   'one',
#   'of',
#   'our',
#   'superstars',
#   '.'],
#  ['i',
#   "'ve",
#   'always',
#   'been',
#   'impressed',
#   'with',
#   'l.a.',
#   'county',
#   'u.s.c',
#   '.'],
#  ['it',
#   'is',
#   'the',
#   'hospital',
#   'that',
#   'sees',
#   'more',
#   'trauma',
#   'patients',
#   '.'],
#  ['it',
#   'treats',
#   'over',
#   '22',
#   'percent',
#   'of',
#   'all',
#   'trauma',
#   'patients',
#   'in',
#   'the',
#   'county',
#   ',',
#   'about',
#   '4,000',
#   'people',
#   'a',
#   'year',
#   '.'],
#  ['our',
#   'new',
#   'facility',
#   'today',
#   'has',
#   'a',
#   'helicopter',
#   'pad',
#   'on',
#   'the',
#   'roof',
#   ',',
#   'which',
#   'is',
#   'going',
#   'to',
#   'be',
#   'resulting',
#   'in',
#   'much',
#   'more',
#   'care',
#   'and',
#   'of',
#   'course',
#   'much',
#   'more',
#   'rapid',
#   'response',
#   'to',
#   'our',
#   'patients',
#   '.'],
#  ['so',
#   'i',
#   'am',
#   'very',
#   'honored',
#   'today',
#   'to',
#   'make',
#   'a',
#   'presentation',
#   'to',
#   'administrator',
#   'pete',
#   'delgado',
#   'and',
#   'also',
#   'shirley',
#   'nemoto',
#   'who',
#   'is',
#   'joining',
#   'us',
#   'and',
#   'we',
#   'want',
#   'to',
#   'congratulate',
#   'them',
#   'because',
#   'they',
#   'do',
#   'such',
#   'an',
#   'outstanding',
#   'job',
#   '.'],
#  ['congratulations', '.'],
#  ['[', 'applause', '.', ']'],
#  ['well',
#   ',',
#   'we',
#   'also',
#   'have',
#   'another',
#   'superstar',
#   'in',
#   'the',
#   'first',
#   'district',
#   'which',
#   'i',
#   "'m",
#   'very',
#   'proud',
#   'of',
#   ',',
#   'that',
#   "'s",
#   'california',
#   'hospital',
#   '.'],
#  ['i',
#   "'m",
#   'going',
#   'to',
#   'ask',
#   'diana',
#   'torres',
#   'and',
#   'gladys',
#   'guerrero',
#   'to',
#   'come',
#   'up',
#   'and',
#   'join',
#   'us',
#   '.'],
#  ['california',
#   'hospital',
#   'is',
#   'the',
#   'third',
#   'busiest',
#   'trauma',
#   'hospital',
#   'in',
#   'the',
#   'county',
#   ',',
#   'seeing',
#   '11',
#   'percent',
#   'of',
#   'the',
#   'county',
#   "'s",
#   'trauma',
#   'patients',
#   '.'],
#  ['over', '2,000', 'trauma', 'patients', 'every', 'year', '.'],
#  ['we', 'really', 'appreciate', 'their', 'partnership', 'with', 'us', '.'],
#  ['they',
#   'have',
#   'been',
#   'sticking',
#   'with',
#   'it',
#   'for',
#   'the',
#   'longest',
#   'time',
#   '.'],
#  ['and',
#   'they',
#   'were',
#   'a',
#   'very',
#   ',',
#   'very',
#   'vital',
#   'partner',
#   'to',
#   'our',
#   'healthcare',
#   'and',
#   'safety',
#   'net',
#   'throughout',
#   'l.a.',
#   'county',
#   '.'],
#  ['so',
#   'i',
#   'want',
#   'to',
#   'congratulate',
#   'california',
#   'hospital',
#   'medical',
#   'center',
#   '.'],
#  ['congratulations', '.'],
#  ['[', 'applause', '.', ']'],
#  ['sup', '.'],
#  ['knabe', ',', 'chair', ':', 'thank', 'you', '.'],
#  ['supervisor', 'ridley-thomas', '?'],
#  ['sup', '.'],
#  ['ridley-thomas',
#   ':',
#   'thank',
#   'you',
#   'very',
#   'much',
#   ',',
#   'mr.',
#   'chairman',
#   'and',
#   'colleagues',
#   '.'],
#  ['i',
#   "'m",
#   'very',
#   'pleased',
#   'to',
#   'be',
#   'able',
#   'to',
#   'make',
#   'this',
#   'presentation',
#   'to',
#   'two',
#   'of',
#   'the',
#   'stellar',
#   'trauma',
#   'centers',
#   'in',
#   'the',
#   'county',
#   "'s",
#   'network',
#   '.'],
#  ['you',
#   'should',
#   'know',
#   'that',
#   'i',
#   'had',
#   'the',
#   'opportunity',
#   'to',
#   'relate',
#   'to',
#   'these',
#   'institutions',
#   'in',
#   'my',
#   'capacity',
#   'of',
#   'chair',
#   'of',
#   'select',
#   'committee',
#   'on',
#   'the',
#   'healthcare',
#   'crisis',
#   'in',
#   'the',
#   'county',
#   'of',
#   'los',
#   'angeles',
#   ',',
#   'both',
#   'in',
#   'the',
#   'assembly',
#   'and',
#   'the',
#   'senate',
#   ',',
#   'and',
#   'delighted',
#   'to',
#   'be',
#   'able',
#   'to',
#   'acknowledge',
#   'them',
#   'in',
#   'the',
#   'context',
#   'of',
#   'this',
#   'ceremony',
#   '.'],
#  ['it',
#   'should',
#   'be',
#   'known',
#   'that',
#   'these',
#   'healthcare',
#   'providers',
#   'are',
#   'among',
#   'the',
#   'top',
#   'tier',
#   'in',
#   'many',
#   'respects',
#   'for',
#   'the',
#   'specialists',
#   'that',
#   'are',
#   'on',
#   'their',
#   'respective',
#   'staffs',
#   '.'],
#  ['and',
#   'we',
#   'take',
#   'note',
#   'of',
#   'the',
#   'fact',
#   'that',
#   'they',
#   'continue',
#   'to',
#   'work',
#   'hard',
#   'each',
#   'and',
#   'every',
#   'day',
#   '.'],
#  ['and',
#   'so',
#   'may',
#   'i',
#   'ask',
#   'both',
#   'the',
#   'program',
#   'manager',
#   ',',
#   'laura',
#   'schneider',
#   ',',
#   'and',
#   'the',
#   'director',
#   ',',
#   'dr.',
#   'brant',
#   'putnam',
#   'from',
#   'harbor',
#   'u.c.l.a',
#   '.'],
#  ['medical',
#   'center',
#   'to',
#   'come',
#   'forward',
#   'so',
#   'that',
#   'we',
#   'can',
#   'make',
#   'this',
#   'presentation',
#   'to',
#   'them',
#   '.'],
#  ['with',
#   'great',
#   'appreciation',
#   'and',
#   'admiration',
#   'for',
#   'the',
#   'work',
#   'you',
#   'have',
#   'done',
#   ',',
#   'the',
#   'work',
#   'you',
#   'are',
#   'doing',
#   'and',
#   'that',
#   'which',
#   'you',
#   'will',
#   'continue',
#   'to',
#   'do',
#   'on',
#   'behalf',
#   'of',
#   'the',
#   'county',
#   'board',
#   'of',
#   'supervisors',
#   ',',
#   'we',
#   'present',
#   'this',
#   'to',
#   'you',
#   'with',
#   'great',
#   'appreciation',
#   '.'],
#  ['[', 'applause', '.', ']'],
#  ['and',
#   'may',
#   'i',
#   'ask',
#   'then',
#   'the',
#   'program',
#   'manager',
#   'and',
#   'director',
#   'renee',
#   'gray',
#   'and',
#   'dr.',
#   'takachi',
#   'shepherd',
#   'from',
#   'the',
#   'st.',
#   'francis',
#   'medical',
#   'center',
#   'to',
#   'come',
#   'forward',
#   'so',
#   'that',
#   'we',
#   'can',
#   'present',
#   'them',
#   'with',
#   'their',
#   'resolution',
#   'and',
#   'commendation',
#   'for',
#   'the',
#   'work',
#   'that',
#   'they',
#   'have',
#   'done',
#   'in',
#   'the',
#   'county',
#   'of',
#   'los',
#   'angeles',
#   ',',
#   'particularly',
#   'the',
#   'southeast',
#   'portion',
#   'of',
#   'the',
#   'county',
#   'of',
#   'los',
#   'angeles',
#   '.'],
#  ['and',
#   'they',
#   'continue',
#   'to',
#   'distinguish',
#   'themselves',
#   'even',
#   'under',
#   'very',
#   'challenging',
#   'circumstances',
#   'by',
#   'being',
#   'most',
#   'severely',
#   'impacted',
#   'in',
#   'recent',
#   'years',
#   '.'],
#  ['but',
#   'they',
#   'have',
#   'continued',
#   'to',
#   'distinguish',
#   'the',
#   'work',
#   'that',
#   'they',
#   'do',
#   'throughout',
#   'the',
#   'hospital',
#   'but',
#   'most',
#   'specifically',
#   'in',
#   'terms',
#   'of',
#   'the',
#   'trauma',
#   'center',
#   'itself',
#   '.'],
#  ['and',
#   'for',
#   'that',
#   ',',
#   'we',
#   'wish',
#   'for',
#   'you',
#   'to',
#   'know',
#   'that',
#   'the',
#   'county',
#   'of',
#   'los',
#   'angeles',
#   'in',
#   'its',
#   'entirety',
#   ',',
#   'particularly',
#   'those',
#   'who',
#   'are',
#   'the',
#   'patients',
#   'that',
#   'have',
#   'to',
#   'visit',
#   'the',
#   'st.',
#   'francis',
#   'medical',
#   'center',
#   ',',
#   'are',
#   'appreciative',
#   'of',
#   'the',
#   'work',
#   'that',
#   'you',
#   'have',
#   'done',
#   ',',
#   'which',
#   'you',
#   'are',
#   'doing',
#   'and',
#   'we',
#   'partner',
#   'with',
#   'you',
#   'in',
#   'work',
#   'that',
#   'needs',
#   'to',
#   'be',
#   'done',
#   'in',
#   'the',
#   'future',
#   '.'],
#  ['so', 'thank', 'you', 'very', 'much', '.'],
#  ['[', 'applause', '.', ']'],
#  ['thank', 'you', ',', 'mr.', 'chairman', '.'],
#  ['sup', '.'],
#  ['knabe', ',', 'chair', ':', 'thank', 'you', '.'],
#  ['mr.', 'yaroslavsky', '?'],
#  ['sup', '.'],
#  ['yaroslavsky', ':', 'i', 'have', 'several', ',', 'mr.', 'chairman', '.'],
#  ['first',
#   'of',
#   'all',
#   ',',
#   'the',
#   'third',
#   'district',
#   ',',
#   'probably',
#   'largely',
#   'because',
#   'it',
#   "'s",
#   'the',
#   'centrally',
#   'located',
#   'district',
#   'in',
#   'the',
#   'county',
#   'and',
#   'straddles',
#   'the',
#   'hollywood',
#   'hills',
#   ',',
#   'santa',
#   'monica',
#   'mountains',
#   '.'],
#  ['we',
#   'have',
#   'five',
# ...
#   'on',
#   'administrative',
#   'or',
#   'sign',
#   'up',
#   ',',
#   'they',
#   'go',
#   'there',
#   '.'],
#  ['there',
#   'is',
#   'no',
#   'overtime',
#   'going',
#   'to',
#   'be',
#   'used',
#   'for',
#   'this',
#   'as',
#   'planned',
#   '.'],
#  ['sup', '.'],
#  ['antonovich', ':', 'as', 'planned', '.'],
#  ['but', 'that', "'s", 'a', 'very', 'ambiguous', 'question', '.'],
#  ['and',
#   'again',
#   ',',
#   'using',
#   'retired',
#   'personnel',
#   ',',
#   'bringing',
#   'them',
#   'back',
#   'for',
#   'the',
#   '120',
#   'days',
#   'would',
#   'not',
#   'disrupt',
#   'the',
#   'ongoing',
#   'patrols',
#   'that',
#   'we',
#   'have',
#   '.'],
#  ['and',
#   'it',
#   "'s",
#   'a',
#   'procedure',
#   'that',
#   'we',
#   'use',
#   'all',
#   'the',
#   'time',
#   '.'],
#  ['using',
#   'those',
#   'personnel',
#   'would',
#   'give',
#   'you',
#   'the',
#   'numbers',
#   'that',
#   'you',
#   'may',
#   'feel',
#   'comfortable',
#   'with',
#   'and',
#   'would',
#   'also',
#   'not',
#   'shortchange',
#   'our',
#   'communities',
#   'that',
#   'rely',
#   'upon',
#   'a',
#   'presence',
#   'in',
#   'the',
#   'community',
#   'and',
#   'able',
#   'to',
#   'respond',
#   'immediately',
#   'if',
#   'any',
#   'crisis',
#   'would',
#   'occur',
#   '.'],
#  ['under',
#   'sheriff',
#   'larry',
#   'waldie',
#   ':',
#   'mr.',
#   'antonovich',
#   ',',
#   'you',
#   'have',
#   'to',
#   'do',
#   'background',
#   'for',
#   'each',
#   'one',
#   'of',
#   'them',
#   'and',
#   'physicals',
#   'for',
#   'each',
#   'one',
#   'of',
#   'them',
#   '.'],
#  ['it', 'could', 'not', 'be', 'done', 'in', 'this', 'timeframe', '.'],
#  ['it', 'takes', 'for', 'background', 'alone', 'six', 'weeks', '.'],
#  ['sup', '.'],
#  ['antonovich',
#   ':',
#   'you',
#   'just',
#   'retired',
#   'a',
#   'person',
#   'you',
#   'have',
#   'to',
#   'check',
#   'their',
#   'background',
#   '?'],
#  ['under',
#   'sheriff',
#   'larry',
#   'waldie',
#   ':',
#   'yes',
#   ',',
#   'it',
#   "'s",
#   'mandatory',
#   'for',
#   'a',
#   '128-day',
#   'contract',
#   '.'],
#  ['sup', '.'],
#  ['antonovich',
#   ':',
#   'if',
#   'you',
#   'retired',
#   'tomorrow',
#   ',',
#   'we',
#   'have',
#   'to',
#   'do',
#   'another',
#   'background',
#   'on',
#   'you',
#   '?'],
#  ['under', 'sheriff', 'larry', 'waldie', ':', 'yes', ',', 'sir', '.'],
#  ['sup', '.'],
#  ['antonovich',
#   ':',
#   'and',
#   'we',
#   'find',
#   'out',
#   'we',
#   'made',
#   'a',
#   'mistake',
#   'in',
#   'the',
#   'first',
#   'place',
#   '?'],
#  ['[', 'laughter', '.', ']'],
#  ['under', 'sheriff', 'larry', 'waldie', ':', 'let', "'s", 'hope', 'not', '.'],
#  ['sup', '.'],
#  ['antonovich',
#   ':',
#   'i',
#   'think',
#   'we',
#   "'re",
#   'using',
#   'a',
#   'lot',
#   'of',
#   'bureaucratic',
#   'red',
#   'tape',
#   'to',
#   'delay',
#   'getting',
#   'retired',
#   'personnel',
#   ',',
#   'who',
#   'are',
#   'qualified',
#   ',',
#   'who',
#   'have',
#   'been',
#   'recognized',
#   'for',
#   'being',
#   'competent',
#   'and',
#   'have',
#   'retired',
#   'with',
#   'recognition',
#   'from',
#   'the',
#   'department',
#   'for',
#   'a',
#   'great',
#   'job',
#   ',',
#   'giving',
#   'them',
#   'that',
#   'opportunity',
#   'is',
#   'not',
#   'going',
#   'to',
#   'shortchange',
#   'our',
#   'county',
#   'or',
#   'shortchange',
#   'those',
#   'people',
#   'that',
#   'they',
#   "'re",
#   'going',
#   'to',
#   'be',
#   'in',
#   'charge',
#   'of',
#   'when',
#   'they',
#   'go',
#   'to',
#   'washington',
#   ',',
#   'd.c',
#   '.'],
#  ['i', 'mean', 'you', "'re", 'getting', 'a', 'competent', 'person', '.'],
#  ['we',
#   "'re",
#   'not',
#   'talking',
#   'about',
#   'getting',
#   'someone',
#   'who',
#   "'s",
#   'been',
#   'retired',
#   '50',
#   'years',
#   'and',
#   'bringing',
#   'them',
#   'out',
#   'of',
#   'mothballs',
#   '.'],
#  ['sup', '.'],
#  ['knabe',
#   ',',
#   'chair',
#   ':',
#   'supervisor',
#   'molina',
#   ',',
#   'in',
#   'response',
#   'to',
#   ',',
#   'as',
#   'i',
#   'understand',
#   'it',
#   ',',
#   'we',
#   "'re",
#   'sending',
#   'three',
#   'full',
#   'platoons',
#   ',',
#   'correct',
#   '?'],
#  ['under',
#   'sheriff',
#   'larry',
#   'waldie',
#   ':',
#   'basically',
#   'the',
#   'quantity',
#   'is',
#   'six',
#   'i',
#   'believe',
#   '.'],
#  ['a',
#   'captain',
#   ',',
#   'each',
#   'one',
#   'with',
#   'a',
#   '56-man',
#   'platoon',
#   ',',
#   'three',
#   'of',
#   'them',
#   'on',
#   'each',
#   'side',
#   ',',
#   'yes',
#   '.'],
#  ['sup', '.'],
#  ['yaroslavsky', ':', 'how', 'many', 'is', 'in', 'a', 'platoon', '?'],
#  ['about', '50', ',', '55', '?'],
#  ['under',
#   'sheriff',
#   'larry',
#   'waldie',
#   ':',
#   '56',
#   'in',
#   'a',
#   'platoon',
#   ',',
#   'yes',
#   '.'],
#  ['sup', '.'],
#  ['knabe',
#   ',',
#   'chair',
#   ':',
#   'to',
#   'maybe',
#   'that',
#   'number',
#   'might',
#   'be',
#   'one',
#   'or',
#   'two',
#   'platoon',
#   'ifs',
#   'they',
#   'could',
#   'negotiate',
#   'that',
#   'or',
#   'something',
#   '.'],
#  ['sup', '.'],
#  ['molina',
#   ':',
#   'but',
#   'let',
#   "'s",
#   'say',
#   'now',
#   'what',
#   'it',
#   'is',
#   ',',
#   'otherwise-',
#   'sup',
#   '.'],
#  ['knabe', ',', 'chair', ':', 'i', 'understand', '.'],
#  ['i', 'do', "n't", 'have', 'a', 'problem', '.'],
#  ['if', 'you', "'re", 'talking', '356', ',', 'right', '?'],
#  ['under', 'sheriff', 'larry', 'waldie', ':', '347', '.'],
#  ['sup', '.'],
#  ['molina', ':', 'so', 'do', 'you', 'want', '300', '?'],
#  ['sup', '.'],
#  ['knabe',
#   ',',
#   'chair',
#   ':',
#   'there',
#   'is',
#   'not',
#   'three',
#   'votes',
#   'here',
#   'for',
#   '346',
#   '.'],
#  ['sup', '.'],
#  ['molina', ':', 'what', "'s", 'the', 'vote', 'number', 'for', 'then', '?'],
#  ['i',
#   "'m",
#   'just',
#   'trying',
#   'to',
#   'understand',
#   ',',
#   'otherwise',
#   'there',
#   "'s",
#   'no',
#   'votes',
#   'and',
#   'let',
#   "'s",
#   'not',
#   'go',
#   'through',
#   'this',
#   'exercise',
#   '.'],
#  ['so', 'what', "'s", 'the', 'number', '?'],
#  ['sup', '.'],
#  ['knabe', ',', 'chair', ':', 'supervisor', 'ridley-thomas', '?'],
#  ['sup', '.'],
#  ['ridley-thomas',
#   ':',
#   'mr.',
#   'chairman',
#   ',',
#   'did',
#   'i',
#   'not',
#   'hear',
#   'that',
#   'if',
#   'the',
#   'number',
#   'falls',
#   'below',
#   'the',
#   'requested',
#   'amount',
#   ',',
#   'the',
#   'proposed',
#   'amount',
#   'falls',
#   'below',
#   'a',
#   'certain',
#   'number',
#   ',',
#   'it',
#   'becomes',
#   'impractical',
#   'to',
#   'do',
#   'in',
#   'terms',
#   'of',
#   'the',
#   'costs',
#   'that',
#   'might',
#   'be',
#   'triggered',
#   'or',
#   'otherwise',
#   'borne',
#   ',',
#   'did',
#   'i',
#   'hear',
#   'that',
#   '?'],
#  ['under',
#   'sheriff',
#   'larry',
#   'waldie',
#   ':',
#   'well',
#   ',',
#   'it',
#   'could',
#   'impact',
#   'the',
#   'hotel',
#   'they',
#   'have',
#   'taken',
#   'for',
#   'us',
#   '.'],
#  ['it',
#   'could',
#   'impact',
#   'the',
#   'flight',
#   'that',
#   'has',
#   'been',
#   'chartered',
#   'for',
#   'a',
#   'specific',
#   'number',
#   '.'],
#  ['yes',
#   ',',
#   'it',
#   'could',
#   'impact',
#   'those',
#   'two',
#   'costs',
#   'particularly',
#   '.'],
#  ['sup', '.'],
#  ['ridley-thomas',
#   ':',
#   'so',
#   'it',
#   'seems',
#   'to',
#   'me',
#   'that',
#   'whatever',
#   'number',
#   'we',
#   'ultimately',
#   'arrive',
#   'at',
#   'should',
#   'be',
#   'informed',
#   'by',
#   'what',
#   'adverse',
#   'effect',
#   'it',
#   'might',
#   'have',
#   'on',
#   'the',
#   'management',
#   'of',
#   'other',
#   'costs',
#   'that',
#   'could',
#   'be',
#   'triggered',
#   'and/or-',
#   'sup',
#   '.'],
#  ['knabe',
#   ',',
#   'chair',
#   ':',
#   'that',
#   'would',
#   'impact',
#   'the',
#   'people',
#   'in',
#   'washington',
#   ',',
#   'not',
#   'us',
#   '.'],
#  ['that', 'would', 'reduce', 'their', 'costs', '.'],
#  ['sup', '.'],
#  ['ridley-thomas', ':', 'no', '.'],
#  ['sup', '.'],
#  ['antonovich',
#   ':',
#   'and',
#   'a',
#   'smaller',
#   'number',
#   ',',
#   'you',
#   'can',
#   'use',
#   'commercial',
#   'flight',
#   '.'],
#  ['you', 'do', "n't", 'have', 'charter', 'a', 'plane', '.'],
#  ['sup', '.'],
#  ['ridley-thomas',
#   ':',
#   'i',
#   'think',
#   'we',
#   'need',
#   'to',
#   'know',
#   'that',
#   ',',
#   'rather',
#   'than',
#   'assume',
#   'that',
#   'is',
#   'really',
#   'what',
#   'i',
#   "'m",
#   'trying',
#   'to',
#   'push',
#   'for',
#   'clarification',
#   '.'],
#  ['sup', '.'],
#  ['molina',
#   ':',
#   'i',
#   'can',
#   'also',
#   'assure',
#   'you',
#   'that',
#   'on',
#   'sunday',
#   'you',
#   'have',
#   'to',
#   'find',
#   'some',
#   'other',
#   'flight',
#   'to',
#   'go',
#   'there',
#   '.'],
#  ['there',
#   'are',
#   'no',
#   'flights',
#   'available',
#   'to',
#   'd.c.',
#   'on',
#   'sunday',
#   '.'],
#  ['under',
#   'sheriff',
#   'larry',
#   'waldie',
#   ':',
#   'we',
#   'could',
#   'not',
#   'go',
#   'commercially',
#   '.'],
#  ['it', 'would', 'be', 'an', 'impossible', 'task', '.'],
#  ['sup', '.'],
#  ['ridley-thomas',
#   ':',
#   'so',
#   'whatever',
#   'we',
#   'suggest',
#   ',',
#   'if',
#   'i',
#   'may',
#   ',',
#   'mr',
#   '.'],
#  ['chair', '.'],
#  ['sup', '.'],
#  ['molina',
#   ':',
#   'give',
#   'up',
#   'your',
#   'ticket',
#   'and',
#   'send',
#   'it',
#   'a',
#   'cop',
#   '?'],
#  ['sup', '.'],
#  ['yaroslavsky',
#   ':',
#   'you',
#   'could',
#   'sublease',
#   'the',
#   'hotel',
#   'rooms',
#   'and',
#   'make',
#   'some',
#   'money',
#   '.'],
#  ['sup', '.'],
#  ['molina', ':', 'you', 'could', 'make', 'some', 'money', 'on', 'it', '.'],
#  ['sup', '.'],
#  ['ridley-thomas',
#   ':',
#   'what',
#   'i',
#   'would',
#   'not',
#   'want',
#   'to',
#   'do',
#   'is',
#   'suggest',
#   'a',
#   'number',
#   'that',
#   'makes',
#   'it',
#   'impractical',
#   'to',
#   'accomplish',
#   '.'],
#  ['so',
#   'what',
#   'seems',
#   'to',
#   'me',
#   'the',
#   'variables',
#   'that',
#   'we',
#   'are',
#   'obliged',
#   'to',
#   'consider',
#   'have',
#   'to',
#   'be',
#   'in',
#   'the',
#   'interest',
#   'of',
#   'doing',
#   'it',
#   'or',
#   'not',
#   '.'],
#  ['and', 'as', 'you', "'ve", 'gleaned', 'or', 'inferred', ',', 'mr', '.'],
#  ['chair',
#   ',',
#   'i',
#   "'m",
#   'inclined',
#   'to',
#   'move',
#   'forward',
#   'with',
#   'the',
#   'number',
#   'that',
#   'makes',
#   'sense',
#   '.'],
#  ['it',
#   'has',
#   'been',
#   'suggested',
#   'that',
#   'the',
#   'proposed',
#   'and/or',
#   'requested',
#   'number',
#   'is',
#   'not',
#   'supportable',
#   '.'],
#  ['supervisor',
#   'molina',
#   'has',
#   'asked',
#   'what',
#   'is',
#   'so',
#   'we',
#   'can',
#   'move',
#   '.'],
#  ['is', 'the', 'number', '300', 'that', 'works', '?'],
#  ['what', 'is', 'it', '?'],
#  ['under',
#   'sheriff',
#   'larry',
#   'waldie',
#   ':',
#   'well',
#   ',',
#   'they',
#   'requested',
#   'they',
#   'needed',
#   '5',
#   '.'],
#  ['we', 'could', "n't", 'do', 'it', '.'],
#  ['347', '.'],
#  ['there',
#   "'s",
#   'an',
#   'issue',
#   'here',
#   'beside',
#   'the',
#   'number',
#   'we',
#   'throw',
#   'out',
#   'to',
#   'them',
#   '.'],
#  ['it',
#   "'s",
#   'what',
#   'they',
#   'need',
#   'and',
#   'what',
#   'they',
#   'can',
#   'do',
#   'to',
#   'get',
#   'the',
#   'job',
#   'done',
#   '.'],
#  ['that', "'s", 'what', 'they', "'ve", 'asked', 'for', '.'],
#  ['now',
#   ',',
#   'when',
#   'we',
#   'say',
#   'okay',
#   ',',
#   'we',
#   "'re",
#   'only',
#   'going',
#   'to',
#   'send',
#   'you',
#   '200',
#   'or',
#   '250',
#   ',',
#   'it',
#   "'s",
#   'a',
#   'burden',
#   'on',
#   'them',
#   'at',
#   'this',
#   'late',
#   'time',
#   'also',
#   ',',
#   'then',
#   ',',
#   'to',
#   'get',
#   'other',
#   'agencies',
#   'who',
#   'have',
#   'not',
#   'responded',
#   '.'],
#  ['and',
#   'here',
#   'we',
#   "'re",
#   'dealing',
#   'with',
#   'the',
#   'protection',
#   'for',
#   'the',
#   'president-elect',
#   '.'],
#  ['there',
#   'is',
#   'an',
#   'issue',
#   'of',
#   'the',
#   'ability',
#   'to',
#   'get',
#   'the',
#   'help',
#   'that',
#   'they',
#   'thought',
#   'they',
#   'were',
#   'going',
#   'to',
#   'get',
#   'from',
#   'us',
#   '.'],
#  ['so', 'it', "'s", 'a', 'real', 'issue', '.'],
#  ['sup', '.'],
#  ['molina', ':', 'all', 'right', '.'],
#  ['sup', '.'],
#  ['antonovich',
#   ':',
#   'i',
#   'would',
#   'move',
#   'that',
#   'we',
#   'authorize',
#   '67',
#   'which',
#   'was',
#   'the',
#   'number',
#   'we',
#   'used',
#   'at',
#   'the',
#   '2004',
#   '.'],
#  ['sup', '.'],
#  ['ridley-thomas',
#   ':',
#   'yeah',
#   ',',
#   'that',
#   'does',
#   "n't",
#   'work',
#   'for',
#   'me',
#   '.'],
#  ['sup', '.'],
#  ['molina',
#   ':',
#   'i',
#   "'m",
#   'going',
#   'to',
#   'ask',
#   'if',
#   'we',
#   'could',
#   'lay',
#   'this',
#   'on',
#   'the',
#   'table',
#   'for',
#   'about',
#   '10',
#   'minutes',
#   'and',
#   'go',
#   'on',
#   'to',
#   'another',
#   'item',
#   'and',
#   'then',
#   'come',
#   'back',
#   'to',
#   'it',
#   '.'],
#  ['i', "'m", 'going', 'to', 'ask', 'a', 'couple', 'of', 'questions', '.'],
#  ['so', 'next', 'item', 'is', 'item', 'number', '68', '.'],
#  ['sup', '.'],
#  ['knabe',
#   ',',
#   'chair',
#   ':',
#   'mr.',
#   'sachs',
#   ',',
#   'we',
#   'did',
#   "n't",
#   'forget',
#   'about',
#   'you',
#   ',',
#   'but',
#   'we',
#   'still',
#   'have',
#   'the',
#   'item',
#   'on',
#   'the',
#   'table',
#   '.'],
#  ['sup', '.'],
#  ['molina',
#   ':',
#   'why',
#   'do',
#   "n't",
#   'we',
#   'do',
#   'the',
#   'public',
#   ',',
#   'the',
#   'ones',
#   'he',
#   "'s",
#   'held',
#   '.'],
#  ['if',
#   'i',
#   'could',
#   'call',
#   'item',
#   'number',
#   '7',
#   'and',
#   '28',
#   'and',
#   '33',
#   '.'],
#  ['sup', '.'],
#  ['knabe',
#   ',',
#   'chair',
#   ':',
#   'and',
#   '69',
#   'while',
#   'you',
#   "'re",
#   'at',
#   'it',
#   '.'],
#  ['sup', '.'],
#  ['yaroslavksy', ':', 'what', 'were', 'the', 'others', '?'],
#  ['sup', '.'],
#  ['knabe',
#   ',',
#   'chair',
#   ':',
#   '7',
#   ',',
#   '28',
#   ',',
#   '33',
#   ',',
#   '36',
#   ',',
#   '47',
#   ',',
#   '51',
#   ',',
#   'and',
#   '69',
#   '.'],
#  ['arnold',
#   'sachs',
#   ':',
#   'good',
#   'morning',
#   ',',
#   'county',
#   'board',
#   'of',
#   'supervisors',
#   '.'],
#  ['item',
#   '7',
#   'i',
#   'was',
#   'concerned',
#   'about',
#   'one',
#   'of',
#   'the',
#   'items',
#   'in',
#   'item',
#   '7',
#   ',',
#   'the',
#   'transportation',
#   'school',
#   '.'],
#  ['in',
#   'the',
#   'south',
#   'bay',
#   'where',
#   'i',
#   'reside',
#   ',',
#   'hermosa',
#   'beach',
#   ',',
#   'they',
#   'have',
#   'a',
#   'program',
#   'for',
#   'transporting',
#   'disabled',
#   'children',
#   '.'],
#  ['hermosa',
#   'beach',
#   'is',
#   '2',
#   '1/2',
#   'miles',
#   'long',
#   ',',
#   'maybe',
#   'a',
#   'mile',
#   'wide',
#   '.'],
#  ['and',
#   'that',
#   'program',
#   'although',
#   'it',
#   "'s",
#   'open',
#   'and',
#   'transparent',
#   ',',
#   'the',
#   'company',
#   'collects',
#   '$',
#   '100',
#   'for',
#   'each',
#   'student',
#   'that',
#   "'s",
#   'transported',
#   'plus',
#   'expenses',
#   '.'],
#  ['each',
#   'medical',
#   'student',
#   ',',
#   'they',
#   'use',
#   'it',
#   'for',
#   'medical',
#   ',',
#   'for',
#   'children',
#   'with',
#   'medical',
#   'needs',
#   '.'],
#  ['that',
#   "'s",
#   'an',
#   'awful',
#   'lot',
#   'of',
#   'money',
#   'to',
#   'travel',
#   '2',
#   '1/2',
#   'miles',
#   '.'],
#  ['so',
#   'although',
#   'the',
#   'contracts',
#   'may',
#   'look',
#   'transparent',
#   ',',
#   'although',
#   'there',
#   'may',
#   'not',
#   'be',
#   'a',
#   'conflict',
#   'of',
#   'interest',
#   ',',
#   'it',
#   'would',
#   'be',
#   'really',
#   'nice',
#   'to',
#   'make',
#   'sure',
#   'that',
#   'they',
#   "'re",
#   'open',
#   'and',
#   'competitive',
#   'in',
#   'their',
#   'bidding',
#   'process',
#   '.'],
#  ['item', 'number', '7', '.'],
#  ['sup', '.'],
#  ['knabe', ',', 'chair', ':', 'okay', '.'],
#  ['the', 'item', 'is', 'now', 'before', 'us', '.'],
#  ['moved', 'by', 'supervisor', 'antonovich', '.'],
#  ['the', 'chair', 'will', 'second', '.'],
#  ['without', 'objection', ',', 'so', 'ordered', '.'],
#  ['i', 'would', 'add', 'most', 'of', 'that', 'process', 'is', 'bid', '.'],
#  ['and',
#   'there',
#   'were',
#   'very',
#   'few',
#   'providers',
#   'of',
#   'that',
#   'service',
#   '.'],
#  ['so', 'it', 'is', 'a', 'good', 'service', '.'],
#  ['although', 'totally', 'unrelated', 'to', 'this', 'item', '.'],
#  ['but', 'that', "'s", 'okay', '.'],
#  ['arnold', 'sachs', ':', 'well', ',', 'it', "'s", 'disability', '.'],
#  ['sup', '.'],
#  ['knabe', ',', 'chair', ':', 'a.d.a.', ',', 'right', '.'],
#  ['arnold', 'sachs', ':', 'next', 'item', ',', 'sir', '?'],
#  ['sup', '.'],
#  ['knabe',
#   ',',
#   'chair',
#   ':',
#   'next',
#   'item',
#   'would',
#   'be',
#   'item',
#   '28',
#   '.'],
#  ['arnold', 'sachs', ':', 'item', '28', '.'],
#  ['another', 'big', 'pot', '.'],
#  ['is',
#   'this',
#   'any',
#   'kind',
#   'of',
#   'relationship',
#   'to',
#   'any',
#   'of',
#   'the',
#   'other',
#   'transportation',
#   'funding',
#   'that',
#   'is',
#   'now',
#   'coming',
#   'up',
#   'prop',
#   '1-h',
#   ',',
#   'prop',
#   'a',
#   ',',
#   'prop',
#   'c',
#   '?'],
#  ['i',
#   'know',
#   'it',
#   "'s",
#   'not',
#   'prop',
#   'r',
#   ',',
#   'but',
#   'there',
#   'just',
#   'seems',
#   'to',
#   'be',
#   'more',
#   'and',
#   'more',
#   'pots',
#   'all',
#   'of',
#   'a',
#   'sudden',
#   'opening',
#   'up',
#   'for',
#   'funding',
#   'for',
#   'transportation',
#   'issues',
#   '.'],
#  ['and',
#   'who',
#   "'s",
#   'overseeing',
#   'and',
#   'who',
#   "'s",
#   'looking',
#   'out',
#   'for',
#   'the',
#   'general',
#   'public',
#   "'s",
#   'welfare',
#   'on',
#   'how',
#   'this',
#   'money',
#   'is',
#   'being',
#   'spent',
#   '?'],
#  ...]

# %%
def get_mybook(sents, tagger):
    return [tagger.tag(sent) for sent in sents]

# %%
mybook_tags = get_mybook(mybook_sents, brown_tagger)

# %%
mybook_tags
# Out:
# [[('sup', 'VB'), ('.', '.')],
#  [('knabe', 'NN'),
#   (',', ','),
#   ('chair', 'NN'),
#   (':', ':'),
#   ('call', 'VB'),
#   ('the', 'AT'),
#   ('meeting', 'NN'),
#   ('to', 'IN'),
#   ('order', 'NN'),
#   (',', ','),
#   ('please', 'VB'),
#   (',', ','),
#   ('if', 'CS'),
#   ('everyone', 'PN'),
#   ('would', 'MD'),
#   ('please', 'VB'),
#   ('rise', 'NN'),
#   ('.', '.')],
#  [('we', 'PPSS'),
#   ('will', 'MD'),
#   ('be', 'BE'),
#   ('led', 'VBN'),
#   ('in', 'IN'),
#   ('the', 'AT'),
#   ('invocation', 'NN'),
#   ('this', 'DT'),
#   ('morning', 'NN'),
#   ('by', 'IN'),
#   ('father', 'NN'),
#   ('mauricio', 'NN'),
#   ('goloron', 'NN'),
#   ('from', 'IN'),
#   ('st.', 'NN'),
#   ('martha', 'NN'),
#   ("'s", 'NN'),
#   ('church', 'NN'),
#   ('in', 'IN'),
#   ('la', 'FW-AT'),
#   ('puente', 'NN'),
#   ('and', 'CC'),
#   ('the', 'AT'),
#   ('pledge', 'NN'),
#   ('led', 'VBD'),
#   ('by', 'IN'),
#   ('victor', 'NN'),
#   ('aprea', 'NN'),
#   (',', ','),
#   ('member', 'NN'),
#   ('post', 'NN'),
#   ('790', 'CD'),
#   (',', ','),
#   ('west', 'NR'),
#   ('covina', 'NN'),
#   (',', ','),
#   ('the', 'AT'),
#   ('american', 'NN'),
#   ('legion', 'NN'),
#   ('.', '.')],
#  [('father', 'NN'), ('?', '.')],
#  [('fr', 'NN'), ('.', '.')],
#  [('mauricio', 'NN'),
#   ('goloron', 'NN'),
#   (':', ':'),
#   ('god', 'NN'),
#   (',', ','),
#   ('who', 'WPS'),
#   ('called', 'VBD'),
#   ('us', 'PPO'),
#   ('out', 'RP'),
#   ('of', 'IN'),
#   ('darkness', 'NN'),
#   ('into', 'IN'),
#   ('his', 'PP$'),
#   ('wonderful', 'JJ'),
#   ('light', 'NN'),
#   ('.', '.')],
#  [('may', 'MD'),
#   ('god', 'NN'),
#   ("'s", 'NN'),
#   ('light', 'NN'),
#   ('guide', 'NN'),
#   ('us', 'PPO'),
#   ('and', 'CC'),
#   ('protect', 'VB'),
#   ('us', 'PPO'),
#   ('as', 'CS'),
#   ('a', 'AT'),
#   ('community', 'NN'),
#   ('.', '.')],
#  [('may', 'MD'),
#   ('god', 'NN'),
#   ("'s", 'NN'),
#   ('wisdom', 'NN'),
#   ('direct', 'JJ'),
#   ('this', 'DT'),
#   ('board', 'NN'),
#   ('in', 'IN'),
#   ('its', 'PP$'),
#   ('work', 'NN'),
#   ('and', 'CC'),
#   ('decisions', 'NNS'),
#   ('today', 'NR'),
#   ('and', 'CC'),
#   ('every', 'AT'),
#   ('day', 'NN'),
#   ('.', '.')],
#  [('may', 'MD'),
#   ('god', 'NN'),
#   ("'s", 'NN'),
#   ('love', 'NN'),
#   ('strengthen', 'VB'),
#   ('all', 'ABN'),
#   ('those', 'DTS'),
#   ('who', 'WPS'),
#   ('work', 'VB'),
#   ('for', 'IN'),
#   ('our', 'PP$'),
#   ('county', 'NN'),
#   ('and', 'CC'),
#   ('make', 'VB'),
#   ('god', 'NN'),
#   ("'s", 'NN'),
#   ('peace', 'NN'),
#   (',', ','),
#   ('make', 'VB'),
#   ('us', 'PPO'),
#   ('one', 'CD'),
#   (',', ','),
#   ('and', 'CC'),
#   ('help', 'VB'),
#   ('us', 'PPO'),
#   ('to', 'TO'),
#   ('always', 'RB'),
#   ('strive', 'VB'),
#   ('for', 'IN'),
#   ('the', 'AT'),
#   ('common', 'JJ'),
#   ('good', 'NN'),
#   ('of', 'IN'),
#   ('all', 'ABN'),
#   ('our', 'PP$'),
#   ('neighbors', 'NNS'),
#   ('.', '.')],
#  [('(', '('),
#   ('repeats', 'VBZ'),
#   ('prayer', 'NN'),
#   ('in', 'IN'),
#   ('spanish', 'NN'),
#   ('.', '.'),
#   (')', ')')],
#  [('(', '('),
#   ('repeats', 'VBZ'),
#   ('prayer', 'NN'),
#   ('in', 'IN'),
#   ('tagalog', 'NN'),
#   ('.', '.'),
#   (')', ')')],
#  [('amen', 'UH'),
#   ('victor', 'NN'),
#   ('aprea', 'NN'),
#   (':', ':'),
#   ('please', 'VB'),
#   ('face', 'NN'),
#   ('the', 'AT'),
#   ('flag', 'NN'),
#   (',', ','),
#   ('placing', 'VBG'),
#   ('your', 'PP$'),
#   ('right', 'JJ'),
#   ('land', 'NN'),
#   ('over', 'IN'),
#   ('your', 'PP$'),
#   ('heart', 'NN'),
#   ('and', 'CC'),
#   ('joining', 'VBG'),
#   ('me', 'PPO'),
#   ('in', 'IN'),
#   ('the', 'AT'),
#   ('pledge', 'NN'),
#   ('of', 'IN'),
#   ('allegiance', 'NN'),
#   ('.', '.')],
#  [('[', ','),
#   ('pledge', 'NN'),
#   ('of', 'IN'),
#   ('allegiance', 'NN'),
#   ('recited', 'VBN'),
#   ('.', '.'),
#   (']', ',')],
#  [('thank', 'VB'), ('you', 'PPO'), ('.', '.')],
#  [('supervisor', 'NN'), ('molina', 'NN'), ('?', '.')],
#  [('sup', 'VB'), ('.', '.')],
#  [('molina', 'NN'),
#   (':', ':'),
#   ('thank', 'VB'),
#   ('you', 'PPO'),
#   (',', ','),
#   ('mr.', 'NN'),
#   ('chairman', 'NN'),
#   ('.', '.')],
#  [('it', 'PPS'),
#   ("'s", 'NN'),
#   ('my', 'PP$'),
#   ('honor', 'NN'),
#   ('this', 'DT'),
#   ('morning', 'NN'),
#   ('to', 'IN'),
#   ('present', 'JJ'),
#   ('a', 'AT'),
#   ('certificate', 'NN'),
#   ('of', 'IN'),
#   ('appreciation', 'NN'),
#   ('to', 'IN'),
#   ('father', 'NN'),
#   ('mauricio', 'NN'),
#   ('goloron', 'NN'),
#   ('.', '.')],
#  [('father', 'NN'),
#   ('goloron', 'NN'),
#   ('was', 'BEDZ'),
#   ('born', 'VBN'),
#   ('and', 'CC'),
#   ('raised', 'VBN'),
#   ('in', 'IN'),
#   ('the', 'AT'),
#   ('southern', 'JJ'),
#   ('philippines', 'NN'),
#   ('.', '.')],
#  [('he', 'PPS'),
#   ('entered', 'VBD'),
#   ('the', 'AT'),
#   ('seminary', 'NN'),
#   ('at', 'IN'),
#   ('the', 'AT'),
#   ('age', 'NN'),
#   ('of', 'IN'),
#   ('12', 'CD'),
#   ('and', 'CC'),
#   ('educated', 'VBN'),
#   ('by', 'IN'),
#   ('the', 'AT'),
#   ('society', 'NN'),
#   ('of', 'IN'),
#   ('jesus', 'NN'),
#   ('and', 'CC'),
#   ('became', 'VBD'),
#   ('an', 'AT'),
#   ('ordained', 'VBN'),
#   ('priest', 'NN'),
#   ('in', 'IN'),
#   ('1984', 'CD-TL'),
#   ('.', '.')],
#  [('in', 'IN'),
#   ('1998', 'NN'),
#   (',', ','),
#   ('father', 'NN'),
#   ('goloron', 'NN'),
#   ('came', 'VBD'),
#   ('to', 'TO'),
#   ('united', 'VBN'),
#   ('states', 'NNS'),
#   ('.', '.')],
#  [('he', 'PPS'),
#   ('served', 'VBD'),
#   ('at', 'IN'),
#   ('the', 'AT'),
#   ('immaculate', 'JJ'),
#   ('heart', 'NN'),
#   ('of', 'IN'),
#   ('mary', 'NN'),
#   ('church', 'NN'),
#   ('in', 'IN'),
#   ('hollywood', 'NN'),
#   (',', ','),
#   ('st.', 'NN'),
#   ('catherine', 'NN'),
#   ('laborne', 'NN'),
#   ('church', 'NN'),
#   ('in', 'IN'),
#   ('torrens', 'NN'),
#   ('and', 'CC'),
#   ('currently', 'RB'),
#   ('heads', 'NNS'),
#   ('up', 'RP'),
#   ('the', 'AT'),
#   ('robust', 'NN'),
#   ('congregation', 'NN'),
#   ('at', 'IN'),
#   ('st.', 'NN'),
#   ('martha', 'NN'),
#   ("'s", 'NN'),
#   ('church', 'NN'),
#   ('in', 'IN'),
#   ('velinda', 'NN'),
#   ('.', '.')],
#  [('st.', 'NN'),
#   ('martha', 'NN'),
#   ("'s", 'NN'),
#   ('is', 'BEZ'),
#   ('situated', 'VBN'),
#   ('in', 'IN'),
#   ('a', 'AT'),
#   ('thriving', 'VBG'),
#   ('community', 'NN'),
#   ('and', 'CC'),
#   ('their', 'PP$'),
#   ('many', 'AP'),
#   ('compassionate', 'JJ'),
#   ('parishioners', 'NNS'),
#   ('are', 'BER'),
#   ('devoted', 'VBN'),
#   ('to', 'TO'),
#   ('good', 'JJ'),
#   ('works', 'NNS'),
#   ('and', 'CC'),
#   ('community', 'NN'),
#   ('service', 'NN'),
#   (',', ','),
#   ('such', 'JJ'),
#   ('as', 'CS'),
#   ('offering', 'VBG'),
#   ('food', 'NN'),
#   ('banks', 'NNS'),
#   ('and', 'CC'),
#   ('donating', 'VBG'),
#   ('clothing', 'NN'),
#   ('bank', 'NN'),
#   ('for', 'IN'),
#   ('the', 'AT'),
#   ('needy', 'JJ'),
#   ('.', '.')],
#  [('we', 'PPSS'),
#   ('want', 'VB'),
#   ('to', 'TO'),
#   ('extend', 'VB'),
#   ('our', 'PP$'),
#   ('heartfelt', 'JJ'),
#   ('thanks', 'NNS'),
#   ('to', 'TO'),
#   ('father', 'VB'),
#   ('goloron', 'NN'),
#   ('and', 'CC'),
#   ('we', 'PPSS'),
#   ('want', 'VB'),
#   ('to', 'TO'),
#   ('present', 'VB'),
#   ('him', 'PPO'),
#   ('a', 'AT'),
#   ('certificate', 'NN'),
#   ('of', 'IN'),
#   ('appreciation', 'NN'),
#   ('for', 'IN'),
#   ('leading', 'VBG'),
#   ('us', 'PPO'),
#   ('in', 'IN'),
#   ('our', 'PP$'),
#   ('invocation', 'NN'),
#   ('.', '.')],
#  [('thank', 'VB'), ('you', 'PPO'), (',', ','), ('father', 'NN'), ('.', '.')],
#  [('[', ','), ('applause', 'NN'), ('.', '.'), (']', ',')],
#  [('supervisor', 'NN'), ('antonovich', 'NN'), ('?', '.')],
#  [('sup', 'VB'), ('.', '.')],
#  [('antonovich', 'NN'),
#   (':', ':'),
#   ('once', 'RB'),
#   ('again', 'RB'),
#   ('we', 'PPSS'),
#   ('want', 'VB'),
#   ('to', 'TO'),
#   ('welcome', 'VB'),
#   ('victor', 'NN'),
#   ('aprea', 'NN'),
#   ('from', 'IN'),
#   ('covina', 'NN'),
#   ('who', 'WPS'),
#   ('came', 'VBD'),
#   ('down', 'RP'),
#   ('today', 'NR'),
#   ('as', 'CS'),
#   ('a', 'AT'),
#   ('member', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('west', 'NR'),
#   ('covina', 'NN'),
#   ('post', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('790', 'CD'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('american', 'NN'),
#   ('legion', 'NN'),
#   ('.', '.')],
#  [('he', 'PPS'),
#   ('retired', 'VBD'),
#   ('as', 'CS'),
#   ('administrative', 'JJ'),
#   ('assistant', 'NN'),
#   ('for', 'IN'),
#   ('the', 'AT'),
#   ('city', 'NN'),
#   ('of', 'IN'),
#   ('los', 'NN'),
#   ('angeles', 'NN'),
#   ('transportation', 'NN'),
#   ('department', 'NN'),
#   ('.', '.')],
#  [('graduate', 'NN'),
#   ('of', 'IN'),
#   ('washington', 'NN'),
#   ('generals', 'NNS'),
#   ('high', 'JJ'),
#   ('school', 'NN'),
#   ('in', 'IN'),
#   ('los', 'NN'),
#   ('angeles', 'NN'),
#   ('and', 'CC'),
#   ('university', 'NN'),
#   ('of', 'IN'),
#   ('southern', 'JJ'),
#   ('california', 'NN'),
#   ('.', '.')],
#  [('thank', 'VB'),
#   ('you', 'PPO'),
#   ('for', 'IN'),
#   ('coming', 'VBG'),
#   ('down', 'RP'),
#   ('.', '.')],
#  [('[', ','), ('applause', 'NN'), ('.', '.'), (']', ',')],
#  [('sup', 'VB'), ('.', '.')],
#  [('knabe', 'NN'),
#   (',', ','),
#   ('chair', 'NN'),
#   (':', ':'),
#   ('okay', 'JJ'),
#   ('.', '.')],
#  [('we', 'PPSS'),
#   ('will', 'MD'),
#   ('proceed', 'VB'),
#   ('with', 'IN'),
#   ('the', 'AT'),
#   ('reading', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('agenda', 'NN'),
#   ('.', '.')],
#  [('clerk', 'NN'),
#   ('sachi', 'NN'),
#   ('hamai', 'NN'),
#   (':', ':'),
#   ('good', 'JJ'),
#   ('morning', 'NN'),
#   (',', ','),
#   ('mr.', 'NN'),
#   ('chairman', 'NN'),
#   (',', ','),
#   ('members', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('board', 'NN'),
#   ('.', '.')],
#  [('we', 'PPSS'),
#   ('will', 'MD'),
#   ('begin', 'VB'),
#   ('today', 'NR'),
#   ("'s", 'NN'),
#   ('agenda', 'NN'),
#   ('on', 'IN'),
#   ('page', 'NN'),
#   ('3', 'CD'),
#   (',', ','),
#   ('agenda', 'NN'),
#   ('for', 'IN'),
#   ('the', 'AT'),
#   ('meeting', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('community', 'NN'),
#   ('development', 'NN'),
#   ('commission', 'NN'),
#   ('.', '.')],
#  [('items', 'NNS'),
#   ('1-d', 'NN'),
#   ('through', 'IN'),
#   ('4-d.', 'NN'),
#   ('sup', 'VB'),
#   ('.', '.')],
#  [('knabe', 'NN'),
#   (',', ','),
#   ('chair', 'NN'),
#   (':', ':'),
#   ('moved', 'VBD'),
#   ('by', 'IN'),
#   ('supervisor', 'NN'),
#   ('yaroslavsky', 'NN'),
#   (',', ','),
#   ('seconded', 'NN'),
#   ('by', 'IN'),
#   ('antonovich', 'NN'),
#   ('.', '.')],
#  [('without', 'IN'),
#   ('objection', 'NN'),
#   (',', ','),
#   ('so', 'CS'),
#   ('ordered', 'VBN'),
#   ('.', '.')],
#  [('clerk', 'NN'),
#   ('sachi', 'NN'),
#   ('hamai', 'NN'),
#   (':', ':'),
#   ('agenda', 'NN'),
#   ('for', 'IN'),
#   ('the', 'AT'),
#   ('meeting', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('housing', 'VBG'),
#   ('authority', 'NN'),
#   (',', ','),
#   ('item', 'NN'),
#   ('1-h.', 'NN'),
#   ('sup', 'VB'),
#   ('.', '.')],
#  [('knabe', 'NN'),
#   (',', ','),
#   ('chair', 'NN'),
#   (':', ':'),
#   ('which', 'WDT'),
#   ('?', '.')],
#  [('clerk', 'NN'),
#   ('sachi', 'NN'),
#   ('hamai', 'NN'),
#   (':', ':'),
#   ('item', 'NN'),
#   ('1-h', 'NN'),
#   (',', ','),
#   ('agenda', 'NN'),
#   ('for', 'IN'),
#   ('the', 'AT'),
#   ('housing', 'VBG'),
#   ('authority', 'NN'),
#   ('.', '.')],
#  [('sup', 'VB'), ('.', '.')],
#  [('knabe', 'NN'),
#   (',', ','),
#   ('chair', 'NN'),
#   (':', ':'),
#   ('moved', 'VBD'),
#   ('by', 'IN'),
#   ('yaroslavsky', 'NN'),
#   ('.', '.')],
#  [('seconded', 'NN'), ('by', 'IN'), ('molina', 'NN'), ('.', '.')],
#  [('without', 'IN'),
#   ('objection', 'NN'),
#   (',', ','),
#   ('so', 'CS'),
#   ('ordered', 'VBN'),
#   ('.', '.')],
#  [('clerk', 'NN'),
#   ('sachi', 'NN'),
#   ('hamai', 'NN'),
#   (':', ':'),
#   ('page', 'NN'),
#   ('6', 'CD'),
#   (',', ','),
#   ('agenda', 'NN'),
#   ('for', 'IN'),
#   ('the', 'AT'),
#   ('meeting', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('regional', 'JJ'),
#   ('park', 'NN'),
#   ('and', 'CC'),
#   ('open', 'VB'),
#   ('space', 'NN'),
#   ('district', 'NN'),
#   (',', ','),
#   ('item', 'NN'),
#   ('1-p.', 'NN'),
#   ('sup', 'VB'),
#   ('.', '.')],
#  [('knabe', 'NN'),
#   (',', ','),
#   ('chair', 'NN'),
#   (':', ':'),
#   ('moved', 'VBD'),
#   ('by', 'IN'),
#   ('supervisor', 'NN'),
#   ('molina', 'NN'),
#   ('.', '.')],
#  [('seconded', 'NN'),
#   ('by', 'IN'),
#   ('supervisor', 'NN'),
#   ('antonovich', 'NN'),
#   (',', ','),
#   ('without', 'IN'),
#   ('objection', 'NN'),
#   (',', ','),
#   ('so', 'CS'),
#   ('ordered', 'VBN'),
#   ('.', '.')],
#  [('clerk', 'NN'),
#   ('sachi', 'NN'),
#   ('hamai', 'NN'),
#   (':', ':'),
#   ('board', 'NN'),
#   ('of', 'IN'),
#   ('supervisors', 'NNS'),
#   ('items', 'NNS'),
#   ('1', 'CD'),
#   ('through', 'IN'),
#   ('7', 'CD'),
#   ('.', '.')],
#  [('on', 'IN'),
#   ('item', 'NN'),
#   ('number', 'NN'),
#   ('7', 'CD'),
#   (',', ','),
#   ('there', 'EX'),
#   ('is', 'BEZ'),
#   ('a', 'AT'),
#   ('request', 'NN'),
#   ('from', 'IN'),
#   ('a', 'AT'),
#   ('member', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('public', 'JJ'),
#   ('to', 'TO'),
#   ('hold', 'VB'),
#   ('this', 'DT'),
#   ('item', 'NN'),
#   ('.', '.')],
#  [('the', 'AT'),
#   ('remaining', 'VBG'),
#   ('items', 'NNS'),
#   ('are', 'BER'),
#   ('before', 'CS'),
#   ('you', 'PPSS'),
#   ('.', '.')],
#  [('sup', 'VB'), ('.', '.')],
#  [('knabe', 'NN'),
#   (',', ','),
#   ('chair', 'NN'),
#   (':', ':'),
#   ('hold', 'VB'),
#   ('item', 'NN'),
#   ('7', 'CD'),
#   ('?', '.')],
#  [('clerk', 'NN'),
#   ('sachi', 'NN'),
#   ('hamai', 'NN'),
#   (':', ':'),
#   ('yes', 'RB'),
#   ('.', '.')],
#  [('sup', 'VB'), ('.', '.')],
#  [('knabe', 'NN'),
#   (',', ','),
#   ('chair', 'NN'),
#   (':', ':'),
#   ('okay', 'JJ'),
#   ('.', '.')],
#  [('on', 'IN'),
#   ('the', 'AT'),
#   ('remainder', 'NN'),
#   (',', ','),
#   ('moved', 'VBD'),
#   ('by', 'IN'),
#   ('supervisor', 'NN'),
#   ('ridley-thomas', 'NN'),
#   (',', ','),
#   ('seconded', 'NN'),
#   ('by', 'IN'),
#   ('the', 'AT'),
#   ('chair', 'NN'),
#   ('.', '.')],
#  [('without', 'IN'),
#   ('objection', 'NN'),
#   (',', ','),
#   ('so', 'CS'),
#   ('ordered', 'VBN'),
#   ('.', '.')],
#  [('clerk', 'NN'),
#   ('sachi', 'NN'),
#   ('hamai', 'NN'),
#   (':', ':'),
#   ('on', 'IN'),
#   ('items', 'NNS'),
#   ('8', 'CD'),
#   ('through', 'IN'),
#   ('66', 'CD'),
#   (',', ','),
#   ('on', 'IN'),
#   ('item', 'NN'),
#   ('number', 'NN'),
#   ('8', 'CD'),
#   (',', ','),
#   ('as', 'CS'),
#   ('posted', 'VBN'),
#   ('on', 'IN'),
#   ('the', 'AT'),
#   ('agenda', 'NN'),
#   (',', ','),
#   ('the', 'AT'),
#   ('chief', 'JJS'),
#   ('executive', 'NN'),
#   ('officer', 'NN'),
#   ('requests', 'NNS'),
#   ('that', 'WPS'),
#   ('this', 'DT'),
#   ('item', 'NN'),
#   ('be', 'BE'),
#   ('referred', 'VBN'),
#   ('back', 'RB'),
#   ('to', 'IN'),
#   ('his', 'PP$'),
#   ('office', 'NN'),
#   ('.', '.')],
#  [('sup', 'VB'), ('.', '.')],
#  [('knabe', 'NN'),
#   (',', ','),
#   ('chair', 'NN'),
#   (':', ':'),
#   ('the', 'AT'),
#   ('remainder', 'NN'),
#   ('are', 'BER'),
#   ('before', 'CS'),
#   ('us', 'PPO'),
#   ('?', '.')],
#  [('clerk', 'NN'),
#   ('sachi', 'NN'),
#   ('hamai', 'NN'),
#   (':', ':'),
#   ('no', 'AT'),
#   (',', ','),
#   ('on', 'IN'),
#   ('item', 'NN'),
#   ('8', 'CD'),
#   ('.', '.')],
#  [('sup', 'VB'), ('.', '.')],
#  [('knabe', 'NN'),
#   (',', ','),
#   ('chair', 'NN'),
#   (':', ':'),
#   ('so', 'CS'),
#   ('ordered', 'VBN'),
#   ('.', '.')],
#  [('clerk', 'NN'),
#   ('sachi', 'NN'),
#   ('hamai', 'NN'),
#   (':', ':'),
#   ('on', 'IN'),
#   ('item', 'NN'),
#   ('10', 'CD'),
#   (',', ','),
#   ('supervisor', 'NN'),
#   ('antonovich', 'NN'),
#   ('requests', 'NNS'),
#   ('that', 'WPS'),
#   ('this', 'DT'),
#   ('item', 'NN'),
#   ('be', 'BE'),
#   ('held', 'VBN'),
#   ('.', '.')],
#  [('on', 'IN'),
#   ('item', 'NN'),
#   ('number', 'NN'),
#   ('12', 'CD'),
#   (',', ','),
#   ('supervisor', 'NN'),
#   ('knabe', 'NN'),
#   ('requests', 'NNS'),
#   ('that', 'WPS'),
#   ('this', 'DT'),
#   ('item', 'NN'),
#   ('be', 'BE'),
#   ('held', 'VBN'),
#   ('.', '.')],
#  [('on', 'IN'),
#   ('item', 'NN'),
#   ('number', 'NN'),
#   ('13', 'CD'),
#   (',', ','),
#   ('the', 'AT'),
#   ('chief', 'JJS'),
#   ('executive', 'NN'),
#   ('officer', 'NN'),
#   ('requests', 'NNS'),
#   ('that', 'WPS'),
#   ('this', 'DT'),
#   ('item', 'NN'),
#   ('be', 'BE'),
#   ('continued', 'VBN'),
#   ('to', 'TO'),
#   ('january', 'NN'),
#   ('13th', 'OD'),
#   (',', ','),
#   ('2009', 'NN'),
#   ('.', '.')],
#  [('sup', 'VB'), ('.', '.')],
#  [('knabe', 'NN'),
#   (',', ','),
#   ('chair', 'NN'),
#   (':', ':'),
#   ('so', 'CS'),
#   ('ordered', 'VBN'),
#   ('.', '.')],
#  [('clerk', 'NN'),
#   ('sachi', 'NN'),
#   ('hamai', 'NN'),
#   (':', ':'),
#   ('on', 'IN'),
#   ('item', 'NN'),
#   ('number', 'NN'),
#   ('20', 'CD'),
#   (',', ','),
#   ('supervisor', 'NN'),
#   ('knabe', 'NN'),
#   ('requests', 'NNS'),
#   ('that', 'WPS'),
#   ('this', 'DT'),
#   ('item', 'NN'),
#   ('be', 'BE'),
#   ('held', 'VBN'),
#   ('.', '.')],
#  [('on', 'IN'),
#   ('item', 'NN'),
#   ('number', 'NN'),
#   ('23', 'CD'),
#   (',', ','),
#   ('supervisor', 'NN'),
#   ('knabe', 'NN'),
#   ('and', 'CC'),
#   ('a', 'AT'),
#   ('member', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('public', 'JJ'),
#   ('request', 'NN'),
#   ('that', 'CS'),
#   ('this', 'DT'),
#   ('item', 'NN'),
#   ('be', 'BE'),
#   ('held', 'VBN'),
#   ('.', '.')],
#  [('23', 'CD'), ('?', '.')],
#  [('on', 'IN'),
#   ('item', 'NN'),
#   ('number', 'NN'),
#   ('28', 'CD'),
#   (',', ','),
#   ('there', 'EX'),
#   ("'s", 'NN'),
#   ('a', 'AT'),
#   ('request', 'NN'),
#   ('from', 'IN'),
#   ('a', 'AT'),
#   ('member', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('public', 'JJ'),
#   ('to', 'TO'),
#   ('hold', 'VB'),
#   ('this', 'DT'),
#   ('item', 'NN'),
#   ('.', '.')],
#  [('28', 'CD-HL'), ('?', '.')],
#  [('on', 'IN'),
#   ('item', 'NN'),
#   ('number', 'NN'),
#   ('33', 'CD'),
#   (',', ','),
#   ('there', 'EX'),
#   ("'s", 'NN'),
#   ('a', 'AT'),
#   ('request', 'NN'),
#   ('from', 'IN'),
#   ('a', 'AT'),
#   ('member', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('public', 'JJ'),
#   ('to', 'TO'),
#   ('hold', 'VB'),
#   ('this', 'DT'),
#   ('item', 'NN'),
#   ('.', '.')],
#  [('on', 'IN'),
#   ('item', 'NN'),
#   ('number', 'NN'),
#   ('36', 'CD'),
#   (',', ','),
#   ('there', 'EX'),
#   ("'s", 'NN'),
#   ('a', 'AT'),
#   ('request', 'NN'),
#   ('from', 'IN'),
#   ('a', 'AT'),
#   ('member', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('public', 'JJ'),
#   ('to', 'TO'),
#   ('hold', 'VB'),
#   ('this', 'DT'),
#   ('item', 'NN'),
#   ('.', '.')],
#  [('on', 'IN'),
#   ('item', 'NN'),
#   ('number', 'NN'),
#   ('47', 'CD'),
#   (',', ','),
#   ('there', 'EX'),
#   ("'s", 'NN'),
#   ('a', 'AT'),
#   ('request', 'NN'),
#   ('from', 'IN'),
#   ('a', 'AT'),
#   ('member', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('public', 'JJ'),
#   ('to', 'TO'),
#   ('hold', 'VB'),
#   ('this', 'DT'),
#   ('item', 'NN'),
#   ('.', '.')],
#  [('on', 'IN'),
#   ('item', 'NN'),
#   ('51', 'CD'),
#   (',', ','),
#   ('there', 'EX'),
#   ("'s", 'NN'),
#   ('a', 'AT'),
#   ('request', 'NN'),
#   ('from', 'IN'),
#   ('a', 'AT'),
#   ('member', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('public', 'JJ'),
#   ('to', 'TO'),
#   ('hold', 'VB'),
#   ('this', 'DT'),
#   ('item', 'NN'),
#   ('.', '.')],
#  [('and', 'CC'),
#   ('on', 'IN'),
#   ('item', 'NN'),
#   ('number', 'NN'),
#   ('60', 'CD'),
#   (',', ','),
#   ('the', 'AT'),
#   ('interim', 'NN'),
#   ('director', 'NN'),
#   ('of', 'IN'),
#   ('health', 'NN'),
#   ('services', 'NNS'),
#   ('requests', 'NNS'),
#   ('that', 'WPS'),
#   ('the', 'AT'),
#   ('corrective', 'NN'),
#   ('action', 'NN'),
#   ('plan', 'NN'),
#   ('be', 'BE'),
#   ('continued', 'VBN'),
#   ('to', 'TO'),
#   ('january', 'NN'),
#   ('6th', 'OD'),
#   (',', ','),
#   ('2009', 'NN'),
#   (',', ','),
#   ('but', 'CC'),
#   ('the', 'AT'),
#   ('settlement', 'NN'),
#   ('be', 'BE'),
#   ('approved', 'VBN'),
#   ('today', 'NR'),
#   ('.', '.')],
#  [('and', 'CC'),
#   ('the', 'AT'),
#   ('remaining', 'VBG'),
#   ('items', 'NNS'),
#   ('are', 'BER'),
#   ('before', 'CS'),
#   ('you', 'PPSS'),
#   ('.', '.')],
#  [('sup', 'VB'), ('.', '.')],
#  [('knabe', 'NN'),
#   (',', ','),
#   ('chair', 'NN'),
#   (':', ':'),
#   ('on', 'IN'),
#   ('the', 'AT'),
#   ('remaining', 'VBG'),
#   ('items', 'NNS'),
#   (',', ','),
#   ('moved', 'VBD'),
#   ('by', 'IN'),
#   ('supervisor', 'NN'),
#   ('ridley-thomas', 'NN'),
#   ('.', '.')],
#  [('seconded', 'NN'),
#   ('by', 'IN'),
#   ('supervisor', 'NN'),
#   ('yaroslavsky', 'NN'),
#   ('.', '.')],
#  [('without', 'IN'),
#   ('objection', 'NN'),
#   (',', ','),
#   ('so', 'CS'),
#   ('ordered', 'VBN'),
#   ('.', '.')],
#  [('recognizing', 'VBG'),
#   ('those', 'DTS'),
#   ('holds', 'VBZ'),
#   ('and', 'CC'),
#   ('continuances', 'NN'),
#   ('.', '.')],
#  [('clerk', 'NN'),
#   ('sachi', 'NN'),
#   ('hamai', 'NN'),
#   (':', ':'),
#   ('thank', 'VB'),
#   ('you', 'PPO'),
#   ('.', '.')],
#  [('on', 'IN'),
#   ('page', 'NN'),
#   ('32', 'CD'),
#   (',', ','),
#   ('ordinance', 'NN'),
#   ('for', 'IN'),
#   ('introduction', 'NN'),
#   ('.', '.')],
#  [('and', 'CC'),
#   ('on', 'IN'),
#   ('item', 'NN'),
#   ('number', 'NN'),
#   ('67', 'CD'),
#   (',', ','),
#   ('as', 'CS'),
#   ('indicated', 'VBN'),
#   ('on', 'IN'),
#   ('the', 'AT'),
#   ('posted', 'VBN'),
#   ('agenda', 'NN'),
#   (',', ','),
#   ('the', 'AT'),
#   ('chief', 'JJS'),
#   ('executive', 'NN'),
#   ('officer', 'NN'),
#   ('requests', 'NNS'),
#   ('that', 'WPS'),
#   ('this', 'DT'),
#   ('item', 'NN'),
#   ('be', 'BE'),
#   ('referred', 'VBN'),
#   ('back', 'RB'),
#   ('to', 'IN'),
#   ('his', 'PP$'),
#   ('office', 'NN'),
#   ('.', '.')],
#  [('sup', 'VB'), ('.', '.')],
#  [('knabe', 'NN'),
#   (',', ','),
#   ('chair', 'NN'),
#   (':', ':'),
#   ('so', 'CS'),
#   ('ordered', 'VBN'),
#   ('.', '.')],
#  [('clerk', 'NN'),
#   ('sachi', 'NN'),
#   ('hamai', 'NN'),
#   (':', ':'),
#   ('discussion', 'NN'),
#   ('items', 'NNS'),
#   ('.', '.')],
#  [('items', 'NNS'),
#   ('67', 'CD'),
#   ('through', 'IN'),
#   ('73', 'CD'),
#   (',', ','),
#   ('on', 'IN'),
#   ('item', 'NN'),
#   ('68', 'CD'),
#   ('we', 'PPSS'),
#   ('will', 'MD'),
#   ('hold', 'VB'),
#   ('for', 'IN'),
#   ('a', 'AT'),
#   ('discussion', 'NN'),
#   ('.', '.')],
#  [('on', 'IN'),
#   ('item', 'NN'),
#   ('69', 'CD'),
#   (',', ','),
#   ('as', 'CS'),
#   ('indicated', 'VBN'),
#   ('on', 'IN'),
#   ('the', 'AT'),
#   ('supplemental', 'JJ'),
#   ('agenda', 'NN'),
#   (',', ','),
#   ('this', 'DT'),
#   ('recommendation', 'NN'),
#   ('was', 'BEDZ'),
#   ('revised', 'VBN'),
#   ('and', 'CC'),
#   ('we', 'PPSS'),
#   ('will', 'MD'),
#   ('also', 'RB'),
#   ('hold', 'VB'),
#   ('this', 'DT'),
#   ('for', 'IN'),
#   ('a', 'AT'),
#   ('discussion', 'NN'),
#   ('.', '.')],
#  [('item', 'NN'),
#   ('70', 'CD'),
#   ('we', 'PPSS'),
#   ('will', 'MD'),
#   ('hold', 'VB'),
#   ('for', 'IN'),
#   ('discussion', 'NN'),
#   ('.', '.')],
#  [('public', 'JJ'),
#   ('hearings', 'NNS'),
#   (',', ','),
#   ('item', 'NN'),
#   ('71', 'CD'),
#   ('we', 'PPSS'),
#   ('will', 'MD'),
#   ('hold', 'VB'),
#   ('for', 'IN'),
#   ('a', 'AT'),
#   ('public', 'JJ'),
#   ('hearing', 'NN'),
#   ('.', '.')],
#  [('on', 'IN'),
#   ('item', 'NN'),
#   ('72', 'CD'),
#   (',', ','),
#   ('as', 'CS'),
#   ('indicated', 'VBN'),
#   ('on', 'IN'),
#   ('the', 'AT'),
#   ('supplemental', 'JJ'),
#   ('agenda', 'NN'),
#   (',', ','),
#   ('supervisor', 'NN'),
#   ('ridley-thomas', 'NN'),
#   ('requests', 'NNS'),
#   ('that', 'WPS'),
#   ('this', 'DT'),
#   ('item', 'NN'),
#   ('be', 'BE'),
#   ('continued', 'VBN'),
#   ('without', 'IN'),
#   ('discussion', 'NN'),
#   ('to', 'IN'),
#   ('january', 'NN'),
#   ('27th', 'OD'),
#   (',', ','),
#   ('2009', 'NN'),
#   ('.', '.')],
#  [('sup', 'VB'), ('.', '.')],
#  [('knabe', 'NN'),
#   (',', ','),
#   ('chair', 'NN'),
#   (':', ':'),
#   ('so', 'CS'),
#   ('ordered', 'VBN'),
#   ('.', '.')],
#  [('clerk', 'NN'),
#   ('sachi', 'NN'),
#   ('hamai', 'NN'),
#   (':', ':'),
#   ('on', 'IN'),
#   ('item', 'NN'),
#   ('73', 'CD'),
#   (',', ','),
#   ('as', 'CS'),
#   ('indicated', 'VBN'),
#   ('on', 'IN'),
#   ('the', 'AT'),
#   ('supplemental', 'JJ'),
#   ('agenda', 'NN'),
#   (',', ','),
#   ('supervisor', 'NN'),
#   ('ridley-thomas', 'NN'),
#   ('requests', 'NNS'),
#   ('that', 'WPS'),
#   ('this', 'DT'),
#   ('item', 'NN'),
#   ('be', 'BE'),
#   ('continued', 'VBN'),
#   ('without', 'IN'),
#   ('discussion', 'NN'),
#   ('to', 'IN'),
#   ('february', 'NN'),
#   ('24th', 'OD-TL'),
#   (',', ','),
#   ('2009', 'NN'),
#   ('.', '.')],
#  [('sup', 'VB'), ('.', '.')],
#  [('knabe', 'NN'),
#   (',', ','),
#   ('chair', 'NN'),
#   (':', ':'),
#   ('so', 'CS'),
#   ('ordered', 'VBN'),
#   ('.', '.')],
#  [('clerk', 'NN'),
#   ('sachi', 'NN'),
#   ('hamai', 'NN'),
#   (':', ':'),
#   ('page', 'NN'),
#   ('35', 'CD'),
#   (',', ','),
#   ('miscellaneous', 'JJ'),
#   ('additions', 'NNS'),
#   ('to', 'TO'),
#   ('the', 'AT'),
#   ('agenda', 'NN'),
#   ('which', 'WDT'),
#   ('were', 'BED'),
#   ('posted', 'VBN'),
#   ('more', 'QL'),
#   ('than', 'CS'),
#   ('72', 'CD'),
#   ('hours', 'NNS'),
#   ('in', 'IN'),
#   ('an', 'AT'),
#   ('advance', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('meeting', 'NN'),
#   ('as', 'CS'),
#   ('indicated', 'VBN'),
#   ('on', 'IN'),
#   ('the', 'AT'),
#   ('supplemental', 'JJ'),
#   ('agenda', 'NN'),
#   ('.', '.')],
#  [('on', 'IN'),
#   ('74-a', 'NN'),
#   (',', ','),
#   ('there', 'EX'),
#   ('is', 'BEZ'),
#   ('a', 'AT'),
#   ('request', 'NN'),
#   ('from', 'IN'),
#   ('a', 'AT'),
#   ('member', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('public', 'JJ'),
#   ('to', 'TO'),
#   ('hold', 'VB'),
#   ('this', 'DT'),
#   ('item', 'NN'),
#   ('.', '.')],
#  [('on', 'IN'),
#   ('74-b', 'NN'),
#   (',', ','),
#   ('pursuant', 'IN'),
#   ('to', 'IN'),
#   ('government', 'NN'),
#   ('code', 'NN'),
#   ('section', 'NN'),
#   ('54957', 'NN'),
#   (',', ','),
#   ('the', 'AT'),
#   ('chief', 'JJS'),
#   ('executive', 'NN'),
#   ('officer', 'NN'),
#   ('requests', 'NNS'),
#   ('that', 'WPS'),
#   ('this', 'DT'),
#   ('be', 'BE'),
#   ('referred', 'VBN'),
#   ('to', 'TO'),
#   ('closed', 'VBN'),
#   ('session', 'NN'),
#   ('.', '.')],
#  [('sup', 'VB'), ('.', '.')],
#  [('knabe', 'NN'),
#   (',', ','),
#   ('chair', 'NN'),
#   (':', ':'),
#   ('so', 'CS'),
#   ('ordered', 'VBN'),
#   ('.', '.')],
#  [('clerk', 'NN'),
#   ('sachi', 'NN'),
#   ('hamai', 'NN'),
#   (':', ':'),
#   ('that', 'CS'),
#   ('completes', 'VBZ'),
#   ('the', 'AT'),
#   ('reading', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('agenda', 'NN'),
#   ('.', '.')],
#  [('supervisorial', 'NN'),
#   ('items', 'NNS'),
#   ('begin', 'VB'),
#   ('with', 'IN'),
#   ('supervisorial', 'NN'),
#   ('district', 'NN'),
#   ('number', 'NN'),
#   ('1', 'CD'),
#   ('.', '.')],
#  [('sup', 'VB'), ('.', '.')],
#  [('knabe', 'NN'),
#   (',', ','),
#   ('chair', 'NN'),
#   (':', ':'),
#   ('we', 'PPSS'),
#   ('have', 'HV'),
#   ('a', 'AT'),
#   ('number', 'NN'),
#   ('of', 'IN'),
#   ('special', 'JJ'),
#   ('presentations', 'NNS'),
#   ('.', '.')],
#  [('i', 'NN'),
#   ('will', 'MD'),
#   ('call', 'VB'),
#   ('on', 'IN'),
#   ('supervisor', 'NN'),
#   ('antonovich', 'NN'),
#   ('and', 'CC'),
#   ('then', 'RB'),
#   ('supervisor', 'NN'),
#   ('ridley-thomas', 'NN'),
#   ('.', '.')],
#  [('sup', 'VB'), ('.', '.')],
#  [('antonovich', 'NN'),
#   (':', ':'),
#   ('well', 'RB'),
#   (',', ','),
#   ('it', 'PPS'),
#   ("'s", 'NN'),
#   ('a', 'AT'),
#   ('real', 'JJ'),
#   ('great', 'JJ'),
#   ('pleasure', 'NN'),
#   ('to', 'IN'),
#   ('introduce', 'VB'),
#   ('one', 'CD'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('great', 'JJ'),
#   ('role', 'NN'),
#   ('models', 'NNS'),
#   (',', ','),
#   ('michael', 'NN'),
#   ('scioscia', 'NN'),
#   (',', ','),
#   ('the', 'AT'),
#   ('former', 'AP'),
#   ('manager', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('los', 'NN'),
#   ('angeles', 'NN'),
#   ('angels', 'NNS'),
#   ('at', 'IN'),
#   ('anaheim', 'NN'),
#   (',', ','),
#   ('formerly', 'RB'),
#   ('the', 'AT'),
#   ('california', 'NN'),
#   ('angels', 'NNS'),
#   (',', ','),
#   ('and', 'CC'),
#   ('formerly', 'RB'),
#   ('the', 'AT'),
#   ('los', 'NN'),
#   ('angeles', 'NN'),
#   ('angels', 'NNS'),
#   (',', ','),
#   ('and', 'CC'),
#   ('now', 'RB'),
#   ('the', 'AT'),
#   ('los', 'NN'),
#   ('angeles', 'NN'),
#   ('angels', 'NNS'),
#   ('at', 'IN'),
#   ('anaheim', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('they', 'PPSS'),
#   ('often', 'RB'),
#   ('play', 'VB'),
#   ('the', 'AT'),
#   ('los', 'NN'),
#   ('angeles', 'NN'),
#   ('dodgers', 'NN'),
#   ('at', 'IN'),
#   ('chinatown', 'NN'),
#   ('from', 'IN'),
#   ('time', 'NN'),
#   ('to', 'IN'),
#   ('time', 'NN'),
#   ('.', '.')],
#  [('[', ','), ('laughter', 'NN'), ('.', '.'), (']', ',')],
#  [('in', 'IN'),
#   ('recognition', 'NN'),
#   ('of', 'IN'),
#   ('their', 'PP$'),
#   ('hard', 'JJ'),
#   ('work', 'NN'),
#   ('and', 'CC'),
#   ('leadership', 'NN'),
#   ('and', 'CC'),
#   ('dedication', 'NN'),
#   ('towards', 'IN'),
#   ('guiding', 'VBG'),
#   ('the', 'AT'),
#   ('angels', 'NNS'),
#   ('of', 'IN'),
#   ('anaheim', 'NN'),
#   ('to', 'IN'),
#   ('the', 'AT'),
#   ('2008', 'NN'),
#   ('american', 'NN'),
#   ('league', 'NN'),
#   ('western', 'JJ'),
#   ('division', 'NN'),
#   ('championship', 'NN'),
#   ('for', 'IN'),
#   ('the', 'AT'),
#   ('second', 'OD'),
#   ('consecutive', 'JJ'),
#   ('year', 'NN'),
#   ('and', 'CC'),
#   ('posting', 'NN'),
#   ('over', 'IN'),
#   ('100', 'CD'),
#   ('wins', 'NNS'),
#   ('in', 'IN'),
#   ('a', 'AT'),
#   ('single', 'AP'),
#   ('system', 'NN'),
#   ('for', 'IN'),
#   ('the', 'AT'),
#   ('first', 'OD'),
#   ('time', 'NN'),
#   ('in', 'IN'),
#   ('their', 'PP$'),
#   ('franchise', 'NN'),
#   ('history', 'NN'),
#   (',', ','),
#   ('the', 'AT'),
#   ('2008', 'NN'),
#   ('angels', 'NNS'),
#   (',', ','),
#   ('it', 'PPS'),
#   ('was', 'BEDZ'),
#   ('the', 'AT'),
#   ('48th', 'NN'),
#   ('season', 'NN'),
#   ('for', 'IN'),
#   ('the', 'AT'),
#   ('franchise', 'NN'),
#   ('.', '.')],
#  [('the', 'AT'),
#   ('regular', 'JJ'),
#   ('season', 'NN'),
#   ('ended', 'VBD'),
#   ('with', 'IN'),
#   ('the', 'AT'),
#   ('angels', 'NNS'),
#   ('winning', 'VBG'),
#   ('their', 'PP$'),
#   ('seventh', 'OD'),
#   ('american', 'NN'),
#   ('west', 'NR'),
#   ('division', 'NN'),
#   ('title', 'NN'),
#   ('and', 'CC'),
#   ('setting', 'VBG'),
#   ('a', 'AT'),
#   ('franchise', 'NN'),
#   ('record', 'NN'),
#   ('for', 'IN'),
#   ('the', 'AT'),
#   ('single', 'AP'),
#   ('season', 'NN'),
#   ('wins', 'VBZ'),
#   ('.', '.')],
#  [('mike', 'NN'),
#   ('scioscia', 'NN'),
#   (',', ','),
#   ('former', 'AP'),
#   ('catcher', 'NN'),
#   ('for', 'IN'),
#   ('the', 'AT'),
#   ('los', 'NN'),
#   ('angeles', 'NN'),
#   ('dodgers', 'NN'),
#   (',', ','),
#   ('marked', 'VBN'),
#   ('his', 'PP$'),
#   ('ninth', 'OD'),
#   ('season', 'NN'),
#   ('as', 'CS'),
#   ('manager', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('angels', 'NNS'),
#   ('.', '.')],
#  [('he', 'PPS'),
#   ('owns', 'VBZ'),
#   ('an', 'AT'),
#   ('803', 'NN'),
#   ('to', 'IN'),
#   ('655', 'NN'),
#   ('win-loss', 'NN'),
#   ('record', 'NN'),
#   ('for', 'IN'),
#   ('551', 'NN'),
#   ('winning', 'VBG'),
#   ('percentage', 'NN'),
#   ('with', 'IN'),
#   ('the', 'AT'),
#   ('angels', 'NNS'),
#   ('.', '.')],
#  [('he', 'PPS'),
#   ('reached', 'VBD'),
#   ('the', 'AT'),
#   ('800', 'CD'),
#   ('win', 'VB'),
#   ('plateau', 'NN'),
#   ('on', 'IN'),
#   ('september', 'NN'),
#   ('22nd', 'OD'),
#   ('with', 'IN'),
#   ('a', 'AT'),
#   ('2-1', 'NN'),
#   ('victory', 'NN'),
#   ('over', 'IN'),
#   ('seattle', 'NN'),
#   ('.', '.')],
#  [('presently', 'RB'),
#   (',', ','),
#   ('michael', 'NN'),
#   ('is', 'BEZ'),
#   ('the', 'AT'),
#   ('longest-tenured', 'NN'),
#   ('manager', 'NN'),
#   ('in', 'IN'),
#   ('american', 'NN'),
#   ('league', 'NN'),
#   ('baseball', 'NN'),
#   ('.', '.')],
#  [('he', 'PPS'),
#   ("'s", 'NN'),
#   ('the', 'AT'),
#   ('16th', 'OD'),
#   ('manager', 'NN'),
#   ('in', 'IN'),
#   ('angel', 'NN'),
#   ('history', 'NN'),
#   ('.', '.')],
#  [('and', 'CC'),
#   ('he', 'PPS'),
#   ("'s", 'NN'),
#   ('guided', 'VBN'),
#   ('the', 'AT'),
#   ('angels', 'NNS'),
#   ('to', 'TO'),
#   ('the', 'AT'),
#   ('post', 'NN'),
#   ('season', 'NN'),
#   ('in', 'IN'),
#   ('four', 'CD'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('last', 'AP'),
#   ('five', 'CD'),
#   ('seasons', 'NNS'),
#   ('.', '.')],
#  [('he', 'PPS'),
#   ("'s", 'NN'),
#   ('the', 'AT'),
#   ('only', 'AP'),
#   ('angels', 'NNS'),
#   ('manager', 'NN'),
#   ('to', 'IN'),
#   ('win', 'VB'),
#   ('american', 'NN'),
#   ('league', 'NN'),
#   ("'s", 'NN'),
#   ('western', 'JJ'),
#   ('division', 'NN'),
#   ('championship', 'NN'),
#   (',', ','),
#   ('surpassing', 'NN'),
#   ('gene', 'NN'),
#   ('mock', 'JJ'),
#   ('.', '.')],
#  [('and', 'CC'),
#   ('he', 'PPS'),
#   ("'s", 'NN'),
#   ('led', 'VBD'),
#   ('the', 'AT'),
#   ('angels', 'NNS'),
#   ('to', 'TO'),
#   ('five', 'CD'),
#   ('straight', 'JJ'),
#   ('winning', 'VBG'),
#   ('seasons', 'NNS'),
#   (',', ','),
#   ('2004', 'NN'),
#   ('through', 'IN'),
#   ('2008', 'NN'),
#   ('.', '.')],
#  [('under', 'IN'),
#   ('his', 'PP$'),
#   ('leadership', 'NN'),
#   (',', ','),
#   ('they', 'PPSS'),
#   ('have', 'HV'),
#   ('won', 'VBN'),
#   ('90', 'CD'),
#   ('or', 'CC'),
#   ('more', 'AP'),
#   ('in', 'IN'),
#   ('five', 'CD'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('last', 'AP'),
#   ('seven', 'CD'),
#   ('seasons', 'NNS'),
#   ('.', '.')],
#  [('the', 'AT'),
#   ('numerous', 'JJ'),
#   ('community', 'NN'),
#   ('events', 'NNS'),
#   ('include', 'VB'),
#   ('he', 'PPS'),
#   ("'s", 'NN'),
#   ('co', 'NN'),
#   ('chair', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('angels', 'NNS'),
#   ('care', 'NN'),
#   ('65', 'CD'),
#   ('roses', 'NNS'),
#   ('golf', 'NN'),
#   ('tournament', 'NN'),
#   (',', ','),
#   ('the', 'AT'),
#   ('chairman', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('heart', 'NN'),
#   ('association', 'NN'),
#   ('heart', 'NN'),
#   ('and', 'CC'),
#   ('soul', 'NN'),
#   ('walk', 'NN'),
#   (',', ','),
#   ('supports', 'VBZ'),
#   ('local', 'JJ'),
#   ('little', 'JJ'),
#   ('leagues', 'NNS'),
#   ('throughout', 'IN'),
#   ('the', 'AT'),
#   ('mike', 'NN'),
#   ('scioscia', 'NN'),
#   ('youth', 'NN'),
#   ('baseball', 'NN'),
#   ('clinic', 'NN'),
#   ('make-a-wish', 'NN'),
#   ('foundation', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('also', 'RB'),
#   (',', ','),
#   ('through', 'IN'),
#   ('his', 'PP$'),
#   ('leadership', 'NN'),
#   (',', ','),
#   ('the', 'AT'),
#   ('monrovia', 'NN'),
#   ('boys', 'NNS'),
#   ('and', 'CC'),
#   ('girls', 'NNS'),
#   ('club', 'NN'),
#   ('raise', 'NN'),
#   ('about', 'IN'),
#   ('75', 'CD'),
#   ('percent', 'NN'),
#   ('of', 'IN'),
#   ('their', 'PP$'),
#   ('budget', 'NN'),
#   ('each', 'DT'),
#   ('january/february', 'NN'),
#   ('when', 'WRB'),
#   ('they', 'PPSS'),
#   ('do', 'DO'),
#   ('their', 'PP$'),
#   ('annual', 'JJ'),
#   ('dinner', 'NN'),
#   ('and', 'CC'),
#   ('mike', 'NN'),
#   ('does', 'DOZ'),
#   ('a', 'AT'),
#   ('phenomenal', 'JJ'),
#   ('job', 'NN'),
#   ('as', 'CS'),
#   ('the', 'AT'),
#   ('auctioneer', 'NN'),
#   ('.', '.')],
#  [('and', 'CC'),
#   ('they', 'PPSS'),
#   ('raise', 'VB'),
#   ('that', 'CS'),
#   ('amount', 'NN'),
#   ('of', 'IN'),
#   ('money', 'NN'),
#   ('for', 'IN'),
#   ('the', 'AT'),
#   ('entire', 'JJ'),
#   ('year', 'NN'),
#   ('.', '.')],
#  [('it', 'PPS'),
#   ('helps', 'VBZ'),
#   ('the', 'AT'),
#   ('young', 'JJ'),
#   ('boys', 'NNS'),
#   ('and', 'CC'),
#   ('girls', 'NNS'),
#   ('in', 'IN'),
#   ('the', 'AT'),
#   ('san', 'NN'),
#   ('gabriel', 'NN'),
#   ('valley', 'NN'),
#   ('in', 'IN'),
#   ('monrovia', 'NN'),
#   ('.', '.')],
#  [('he', 'PPS'),
#   ('was', 'BEDZ'),
#   ('inducted', 'VBN'),
#   ('into', 'IN'),
#   ('the', 'AT'),
#   ('italian', 'NN'),
#   ('american', 'NN'),
#   ('hall', 'NN'),
#   ('of', 'IN'),
#   ('fame', 'NN'),
#   ('in', 'IN'),
#   ('2007', 'NN'),
#   ('and', 'CC'),
#   ('major', 'JJ'),
#   ('league', 'NN'),
#   ('baseball', 'NN'),
#   ("'s", 'NN'),
#   ('arizona', 'NN'),
#   ('fall', 'VB'),
#   ('league', 'NN'),
#   ('of', 'IN'),
#   ('fame', 'NN'),
#   ('.', '.')],
#  [('we', 'PPSS'),
#   ('are', 'BER'),
#   ('also', 'RB'),
#   ('honoring', 'VBG'),
#   ('los', 'NN'),
#   ('angeles', 'NN'),
#   ('angels', 'NNS'),
#   ('for', 'IN'),
#   ('inviting', 'VBG'),
#   ('los', 'NN'),
#   ('angeles', 'NN'),
#   ('county', 'NN'),
#   ("'s", 'NN'),
#   ('boys', 'NNS'),
#   ('and', 'CC'),
#   ('girls', 'NNS'),
#   ('to', 'TO'),
#   ('attend', 'VB'),
#   ('their', 'PP$'),
#   ('annual', 'JJ'),
#   ('children', 'NNS'),
#   ("'s", 'NN'),
#   ('holiday', 'NN'),
#   ('celebration', 'NN'),
#   (',', ','),
#   ('which', 'WDT'),
#   ('takes', 'VBZ'),
#   ('place', 'NN'),
#   ('today', 'NR'),
#   (',', ','),
#   ('this', 'DT'),
#   ('afternoon', 'NN'),
#   (',', ','),
#   ('at', 'IN'),
#   ('angels', 'NNS'),
#   ('stadium', 'NN'),
#   ('.', '.')],
#  [('tony', 'NN'),
#   ('riggins', 'NN'),
#   (',', ','),
#   ('the', 'AT'),
#   ('general', 'JJ'),
#   ('manager', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('michael', 'NN'),
#   ('will', 'MD'),
#   ('be', 'BE'),
#   ('reading', 'VBG'),
#   ('to', 'TO'),
#   ('the', 'AT'),
#   ('children', 'NNS'),
#   ('.', '.')],
#  [('the', 'AT'),
#   ('children', 'NNS'),
#   ('will', 'MD'),
#   ('also', 'RB'),
#   ('get', 'VB'),
#   ('the', 'AT'),
#   ('opportunity', 'NN'),
#   ('to', 'IN'),
#   ('sing', 'VB'),
#   ('the', 'AT'),
#   ('holiday', 'NN'),
#   ('songs', 'NNS'),
#   ('and', 'CC'),
#   ('make', 'VB'),
#   ('specially', 'RB'),
#   ('designed', 'VBN'),
#   ('angel', 'NN'),
#   ('christmas', 'NN'),
#   ('tree', 'NN'),
#   ('ornaments', 'NNS'),
#   ('.', '.')],
#  [('they', 'PPSS'),
#   ("'re", 'NN'),
#   ('also', 'RB'),
#   ('treated', 'VBN'),
#   ('to', 'TO'),
#   ('a', 'AT'),
#   ('traditional', 'JJ'),
#   ('baseball', 'NN'),
#   ('meal', 'NN'),
#   ('and', 'CC'),
#   ('are', 'BER'),
#   ('allowed', 'VBN'),
#   ('to', 'TO'),
#   ('select', 'VB'),
#   ('their', 'PP$'),
#   ('own', 'JJ'),
#   ('christmas', 'NN'),
#   ('gift', 'NN'),
#   ('.', '.')],
#  [('this', 'DT'),
#   ('summer', 'NN'),
#   (',', ','),
#   ('as', 'CS'),
#   ('part', 'NN'),
#   ('of', 'IN'),
#   ('a', 'AT'),
#   ('national', 'JJ'),
#   ('summer', 'NN'),
#   ('mental', 'JJ'),
#   ('health', 'NN'),
#   ('awareness', 'NN'),
#   ('program', 'NN'),
#   (',', ','),
#   ('i', 'NN'),
#   ('teamed', 'VBD'),
#   ('up', 'RP'),
#   ('with', 'IN'),
#   ('the', 'AT'),
#   ('angels', 'NNS'),
#   ("'", "'"),
#   ('general', 'JJ'),
#   ('manager', 'NN'),
#   ('tony', 'NN'),
#   ('riggins', 'NN'),
#   ('and', 'CC'),
#   ('left', 'VBD'),
#   ('hand', 'NN'),
#   ('pitcher', 'NN'),
#   ('darren', 'NN'),
#   ('oliver', 'NN'),
#   ('in', 'IN'),
#   ('hosting', 'NN'),
#   ('a', 'AT'),
#   ('prevention', 'NN'),
#   ('and', 'CC'),
#   ('early', 'JJ'),
#   ('intervention', 'NN'),
#   ('event', 'NN'),
#   ('encouraging', 'VBG'),
#   ('the', 'AT'),
#   ('children', 'NNS'),
#   ('to', 'TO'),
#   ('eat', 'VB'),
#   ('the', 'AT'),
#   ('proper', 'JJ'),
#   ('foods', 'NNS'),
#   ('that', 'WPS'),
#   ('would', 'MD'),
#   ('turn', 'VB'),
#   ('and', 'CC'),
#   ('help', 'VB'),
#   ('promote', 'VB'),
#   ('a', 'AT'),
#   ('positive', 'JJ'),
#   ('mental', 'JJ'),
#   ('health', 'NN'),
#   ('and', 'CC'),
#   ('wellness', 'NN'),
#   ('attitude', 'NN'),
#   ('.', '.')],
#  [('more', 'QL'),
#   ('than', 'CS'),
#   ('200', 'CD'),
#   ('students', 'NNS'),
#   ('from', 'IN'),
#   ('frank', 'JJ'),
#   ('telamo', 'NN'),
#   ('elementary', 'JJ'),
#   ('school', 'NN'),
#   ('in', 'IN'),
#   ('los', 'NN'),
#   ('angeles', 'NN'),
#   (',', ','),
#   ('located', 'VBN'),
#   ('near', 'IN'),
#   ('korea', 'NN'),
#   ('town', 'NN'),
#   (',', ','),
#   ('where', 'WRB'),
#   ('nine', 'CD'),
#   ('different', 'JJ'),
#   ('languages', 'NNS'),
#   ('are', 'BER'),
#   ('spoken', 'VBN'),
#   ('on', 'IN'),
#   ('campus', 'NN'),
#   (',', ','),
#   ('participated', 'VBN'),
#   ('in', 'IN'),
#   ('this', 'DT'),
#   ('very', 'AP'),
#   ('exciting', 'JJ'),
#   ('event', 'NN'),
#   ('.', '.')],
#  [('so', 'RB'),
#   (',', ','),
#   ('michael', 'NN'),
#   (',', ','),
#   ('we', 'PPSS'),
#   ('want', 'VB'),
#   ('to', 'TO'),
#   ('give', 'VB'),
#   ('you', 'PPO'),
#   (',', ','),
#   ('as', 'CS'),
#   ('manager', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('year', 'NN'),
#   (',', ','),
#   ('this', 'DT'),
#   ('plaque', 'NN'),
#   ('from', 'IN'),
#   ('the', 'AT'),
#   ('county', 'NN'),
#   ('of', 'IN'),
#   ('los', 'NN'),
#   ('angeles', 'NN'),
#   ('.', '.')],
#  [('and', 'CC'),
#   ('we', 'PPSS'),
#   ('wish', 'VB'),
#   ('you', 'PPO'),
#   ('many', 'AP'),
#   (',', ','),
#   ('many', 'AP'),
#   ('more', 'AP'),
#   ('successful', 'JJ'),
#   ('seasons', 'NNS'),
#   ('.', '.')],
#  [('and', 'CC'),
#   ('i', 'NN'),
#   ('had', 'HVD'),
#   ('the', 'AT'),
#   ('opportunity', 'NN'),
#   ('of', 'IN'),
#   ('being', 'BEG'),
#   ('there', 'RB'),
#   ('when', 'WRB'),
#   ('they', 'PPSS'),
#   ('won', 'VBD'),
#   ('the', 'AT'),
#   ('world', 'NN'),
#   ('series', 'NN'),
#   ('a', 'AT'),
#   ('couple', 'NN'),
#   ('years', 'NNS'),
#   ('ago', 'RB'),
#   (',', ','),
#   ('and', 'CC'),
#   ('that', 'CS'),
#   ('was', 'BEDZ'),
#   ('a', 'AT'),
#   ('very', 'QL'),
#   ('great', 'JJ'),
#   ('feeling', 'NN'),
#   ('.', '.')],
#  [('a', 'AT'),
#   ('little', 'JJ'),
#   ('different', 'JJ'),
#   ('than', 'CS'),
#   ('when', 'WRB'),
#   ('i', 'NN'),
#   ('was', 'BEDZ'),
#   ('a', 'AT'),
#   ('little', 'JJ'),
#   ('boy', 'NN'),
#   ('at', 'IN'),
#   ('wrigley', 'NN'),
#   ('field', 'NN'),
#   ('watching', 'VBG'),
#   ('the', 'AT'),
#   ('los', 'NN'),
#   ('angeles', 'NN'),
#   ('angels', 'NNS'),
#   ('lose', 'VB'),
#   ('under', 'IN'),
#   ('bill', 'NN'),
#   ('kelly', 'NN'),
#   ('who', 'WPS'),
#   ('was', 'BEDZ'),
#   ('the', 'AT'),
#   ('manager', 'NN'),
#   ('then', 'RB'),
#   ('.', '.')],
#  [('anyway', 'RB'),
#   (',', ','),
#   ('congratulations', 'NNS'),
#   ('and', 'CC'),
#   ('god', 'NN'),
#   ('bless', 'VB'),
#   ('you', 'PPO'),
#   ('.', '.')],
#  [('[', ','), ('applause', 'NN'), ('.', '.'), (']', ',')],
#  [('and', 'CC'),
#   ('this', 'DT'),
#   ('is', 'BEZ'),
#   ('for', 'IN'),
#   ('the', 'AT'),
#   ('los', 'NN'),
#   ('angeles', 'NN'),
#   ('angels', 'NNS'),
#   ("'", "'"),
#   ('western', 'JJ'),
#   ('division', 'NN'),
#   ('championship', 'NN'),
#   ('.', '.')],
#  [('good', 'JJ'), ('champions', 'NNS'), ('.', '.')],
#  [('[', ','), ('applause', 'NN'), ('.', '.'), (']', ',')],
#  [('mike', 'NN'),
#   ('scioscia', 'NN'),
#   (':', ':'),
#   ('supervisor', 'NN'),
#   ('antonovich', 'NN'),
#   ('and', 'CC'),
#   ('all', 'ABN'),
#   ('the', 'AT'),
#   ('board', 'NN'),
#   ('of', 'IN'),
#   ('supervisors', 'NNS'),
#   (',', ','),
#   ('i', 'NN'),
#   ('want', 'VB'),
#   ('to', 'TO'),
#   ('thank', 'VB'),
#   ('you', 'PPO'),
#   ('ver', 'NN'),
#   ('much', 'QL'),
#   ('for', 'IN'),
#   ('this', 'DT'),
#   ('presentation', 'NN'),
#   (',', ','),
#   ('this', 'DT'),
#   ('honor', 'NN'),
#   ('.', '.')],
#  [('the', 'AT'),
#   ('amount', 'NN'),
#   ('of', 'IN'),
#   ('support', 'NN'),
#   ('we', 'PPSS'),
#   ('get', 'VB'),
#   ('through', 'IN'),
#   ('southern', 'JJ'),
#   ('california', 'NN'),
#   ('is', 'BEZ'),
#   ('incredible', 'JJ'),
#   ('.', '.')],
#  [('almost', 'RB'),
#   ('3.5', 'CD'),
#   ('million', 'CD'),
#   ('fans', 'NNS'),
#   ('came', 'VBD'),
#   ('to', 'TO'),
#   ('see', 'VB'),
#   ('us', 'PPO'),
#   ('down', 'RP'),
#   ('at', 'IN'),
#   ('angels', 'NNS'),
#   ("'", "'"),
#   ('stadium', 'NN'),
#   ('.', '.')],
#  [('we', 'PPSS'),
#   ('had', 'HVD'),
#   ('a', 'AT'),
#   ('great', 'JJ'),
#   ('regular', 'JJ'),
#   ('season', 'NN'),
#   ('.', '.')],
#  [('and', 'CC'),
#   ('as', 'CS'),
#   ('we', 'PPSS'),
#   ('prepare', 'VB'),
#   ('for', 'IN'),
#   ('this', 'DT'),
#   ('next', 'AP'),
#   ('season', 'NN'),
#   (',', ','),
#   ('2009', 'NN'),
#   (',', ','),
#   ('supervisor', 'NN'),
#   (',', ','),
#   ('we', 'PPSS'),
#   ("'re", 'NN'),
#   ('going', 'VBG'),
#   ('to', 'TO'),
#   ('do', 'DO'),
#   ('a', 'AT'),
#   ('little', 'JJ'),
#   ('better', 'JJR'),
#   ('in', 'IN'),
#   ('the', 'AT'),
#   ('playoffs', 'NN'),
#   ('.', '.')],
#  [('i', 'NN'),
#   ('know', 'VB'),
#   ('as', 'CS'),
#   ('disappointed', 'VBN'),
#   ('as', 'CS'),
#   ('you', 'PPSS'),
#   ('were', 'BED'),
#   (',', ','),
#   ('we', 'PPSS'),
#   ('were', 'BED'),
#   ('more', 'QL'),
#   ('disappointed', 'VBN'),
#   ('.', '.')],
#  [('and', 'CC'),
#   ('it', 'PPS'),
#   ("'s", 'NN'),
#   ('a', 'AT'),
#   ('great', 'JJ'),
#   ('regular', 'JJ'),
#   ('season', 'NN'),
#   ('we', 'PPSS'),
#   ('had', 'HVD'),
#   ('.', '.')],
#  [('i', 'NN'),
#   ('thank', 'VB'),
#   ('you', 'PPO'),
#   ('for', 'IN'),
#   ('this', 'DT'),
#   ('plaque', 'NN'),
#   ('and', 'CC'),
#   ('this', 'DT'),
#   ('ceremony', 'NN'),
#   ('.', '.')],
#  [('but', 'CC'),
#   ('we', 'PPSS'),
#   ('are', 'BER'),
#   ('going', 'VBG'),
#   ('to', 'TO'),
#   ('do', 'DO'),
#   ('better', 'RBR'),
#   ('in', 'IN'),
#   ('the', 'AT'),
#   ('playoffs', 'NN'),
#   (',', ','),
#   ('supervisor', 'NN'),
#   (',', ','),
#   ('i', 'NN'),
#   ('promise', 'NN'),
#   ('you', 'PPSS'),
#   ('that', 'WPS'),
#   ('.', '.')],
#  [('thank', 'VB'), ('you', 'PPO'), ('very', 'QL'), ('much', 'AP'), ('.', '.')],
#  [('god', 'NN'), ('bless', 'VB'), ('you', 'PPO'), ('.', '.')],
#  [('[', ','), ('applause', 'NN'), ('.', '.'), (']', ',')],
#  [('sup', 'VB'), ('.', '.')],
#  [('knabe', 'NN'),
#   (',', ','),
#   ('chair', 'NN'),
#   (':', ':'),
#   ('all', 'ABN'),
#   ('right', 'JJ'),
#   ('.', '.')],
#  [('mark', 'NN'), ('?', '.')],
#  [('i', 'NN'),
#   ('understand', 'VB'),
#   ('you', 'PPO'),
#   ('have', 'HV'),
#   ('a', 'AT'),
#   ('very', 'QL'),
#   ('special', 'JJ'),
#   ('presentation', 'NN'),
#   ('for', 'IN'),
#   ('us', 'PPO'),
#   (',', ','),
#   ('as', 'CS'),
#   ('well', 'RB'),
#   (',', ','),
#   ('too', 'RB'),
#   (',', ','),
#   ('huh', 'UH'),
#   ('?', '.')],
#  [('sup', 'VB'), ('.', '.')],
#  [('ridley-thomas', 'NN'),
#   (':', ':'),
#   ('thank', 'VB'),
#   ('you', 'PPO'),
#   ('very', 'QL'),
#   ('much', 'AP'),
#   (',', ','),
#   ('mr.', 'NN'),
#   ('chairman', 'NN'),
#   (',', ','),
#   ('members', 'NNS'),
#   ('.', '.')],
#  [('i', 'NN'),
#   ("'m", 'NN'),
#   ('pleased', 'VBN'),
#   ('to', 'TO'),
#   ('ask', 'VB'),
#   ('that', 'CS'),
#   ('we', 'PPSS'),
#   ('be', 'BE'),
#   ('joined', 'VBN'),
#   ('by', 'IN'),
#   ('the', 'AT'),
#   ('los', 'NN'),
#   ('angeles', 'NN'),
#   ('county', 'NN'),
#   ('arts', 'NNS'),
#   ('commission', 'NN'),
#   ('director', 'NN'),
#   ('.', '.')],
#  [('you', 'PPSS'),
#   ('know', 'VB'),
#   ('her', 'PPO'),
#   ('as', 'CS'),
#   ('laura', 'NN'),
#   ('zucker', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('those', 'DTS'),
#   ('representing', 'VBG'),
#   ('the', 'AT'),
#   ('united', 'VBN'),
#   ('children', 'NNS'),
#   ("'s", 'NN'),
#   ('chorus', 'NN'),
#   ('.', '.')],
#  [('the', 'AT'),
#   ('directors', 'NNS'),
#   ('are', 'BER'),
#   ('willie', 'NN'),
#   ('norwood', 'NN'),
#   (',', ','),
#   ('sr.', 'NN'),
#   ('and', 'CC'),
#   ('ravaline', 'NN'),
#   ('harold', 'NN'),
#   ('.', '.')],
#  [('and', 'CC'),
#   ('members', 'NNS'),
#   ('of', 'IN'),
#   ('that', 'DT'),
#   ('chorus', 'NN'),
#   ('you', 'PPSS'),
#   ('will', 'MD'),
#   ('hear', 'VB'),
#   ('from', 'IN'),
#   ('soon', 'RB'),
#   ('.', '.')],
#  [('i', 'NN'),
#   ("'d", 'NN'),
#   ('like', 'CS'),
#   ('for', 'IN'),
#   ('you', 'PPO'),
#   ('to', 'TO'),
#   ('know', 'VB'),
#   ('that', 'CS'),
#   ('the', 'AT'),
#   ('u.c.c', 'NN'),
#   ('.', '.')],
#  [('was', 'BEDZ'),
#   ('formed', 'VBN'),
#   ('in', 'IN'),
#   ('the', 'AT'),
#   ('summer', 'NN'),
#   ('of', 'IN'),
#   ('1993', 'NN'),
#   ('during', 'IN'),
#   ('what', 'WDT'),
#   ('is', 'BEZ'),
#   ('known', 'VBN'),
#   ('as', 'CS'),
#   ('the', 'AT'),
#   ('crusade', 'NN'),
#   ('for', 'IN'),
#   ('christ', 'NN'),
#   ('campaign', 'NN'),
#   ('held', 'VBN'),
#   ('here', 'RB'),
#   ('in', 'IN'),
#   ('the', 'AT'),
#   ('county', 'NN'),
#   ('of', 'IN'),
#   ('los', 'NN'),
#   ('angeles', 'NN'),
#   ('.', '.')],
#  [('young', 'JJ'),
#   ('men', 'NNS'),
#   ('and', 'CC'),
#   ('women', 'NNS'),
#   ('from', 'IN'),
#   ('various', 'JJ'),
#   ('churches', 'NNS'),
#   ('of', 'IN'),
#   ('christ', 'NN'),
#   ('throughout', 'IN'),
#   ('the', 'AT'),
#   ('los', 'NN'),
#   ('angeles', 'NN'),
#   ('and', 'CC'),
#   ('surrounding', 'VBG'),
#   ('counties', 'NNS'),
#   ('came', 'VBD'),
#   ('together', 'RB'),
#   ('to', 'IN'),
#   ('perform', 'VB'),
#   ('what', 'WDT'),
#   ('is', 'BEZ'),
#   ('known', 'VBN'),
#   ('as', 'CS'),
#   ('this', 'DT'),
#   ('tremendous', 'JJ'),
#   ('event', 'NN'),
#   ('.', '.')],
#  [('and', 'CC'),
#   ('with', 'IN'),
#   ('such', 'JJ'),
#   ('rave', 'NN'),
#   ('reviews', 'NNS'),
#   ('following', 'VBG'),
#   ('that', 'CS'),
#   ('event', 'NN'),
#   (',', ','),
#   ('it', 'PPS'),
#   ('was', 'BEDZ'),
#   ('requested', 'VBN'),
#   ('that', 'CS'),
#   ('the', 'AT'),
#   ('group', 'NN'),
#   ('remain', 'VB'),
#   ('together', 'RB'),
#   ('.', '.')],
#  [('you', 'PPSS'),
#   ('will', 'MD'),
#   ('want', 'VB'),
#   ('to', 'TO'),
#   ('know', 'VB'),
#   ('that', 'CS'),
#   ('this', 'DT'),
#   ('group', 'NN'),
#   (',', ','),
#   ('ranging', 'VBG'),
#   ('in', 'IN'),
#   ('ages', 'NNS'),
#   ('3', 'CD'),
#   ('to', 'IN'),
#   ('those', 'DTS'),
#   ('in', 'IN'),
#   ('their', 'PP$'),
#   ('late', 'JJ'),
#   ('20s', 'NN'),
#   (',', ','),
#   ('enlighten', 'VB'),
#   ('audiences', 'NNS'),
#   ('with', 'IN'),
#   ('their', 'PP$'),
#   ('extraordinary', 'JJ'),
#   ('gifts', 'NNS'),
#   ('in', 'IN'),
#   ('entertaining', 'VBG'),
#   ('us', 'PPO'),
#   ('in', 'IN'),
#   ('that', 'DT'),
#   ('which', 'WDT'),
#   ('we', 'PPSS'),
#   ('know', 'VB'),
#   ('as', 'CS'),
#   ('a', 'AT'),
#   ('capello', 'NN'),
#   ('singing', 'NN'),
#   ('.', '.')],
#  [('the', 'AT'),
#   ('chorus', 'NN'),
#   ('director', 'NN'),
#   (',', ','),
#   ('willie', 'NN'),
#   ('norwood', 'NN'),
#   ('sr.', 'NN'),
#   (',', ','),
#   ('has', 'HVZ'),
#   ('been', 'BEN'),
#   ('directing', 'VBG'),
#   ('the', 'AT'),
#   ('u.c.c', 'NN'),
#   ('.', '.')],
#  [('for', 'CS'),
#   ('the', 'AT'),
#   ('last', 'AP'),
#   ('14', 'CD'),
#   ('years', 'NNS'),
#   ('.', '.')],
#  [('he', 'PPS'),
#   ('is', 'BEZ'),
#   ('the', 'AT'),
#   ('minister', 'NN'),
#   ('of', 'IN'),
#   ('music', 'NN'),
#   ('at', 'IN'),
#   ('the', 'AT'),
#   ('woodland', 'NN'),
#   ('hills', 'NNS'),
#   ('church', 'NN'),
#   ('of', 'IN'),
#   ('christ', 'NN'),
#   ('and', 'CC'),
#   ('the', 'AT'),
#   ('father', 'NN'),
#   ('of', 'IN'),
#   ('singer', 'NN'),
#   ('actress', 'NN'),
#   ('brandy', 'NN'),
#   ('norwood', 'NN'),
#   ('and', 'CC'),
#   ('singer', 'NN'),
#   ('actor', 'NN'),
#   ('willie', 'NN'),
#   ('``', '``'),
#   ('ray', 'NN'),
#   ('jay', 'NN'),
#   ("''", "''"),
#   ('norwood', 'NN'),
#   (',', ','),
#   ('who', 'WPS'),
#   ('also', 'RB'),
#   ('sang', 'VBD'),
#   ('in', 'IN'),
#   ('the', 'AT'),
#   ('chorus', 'NN'),
#   ('.', '.')],
#  [('he', 'PPS'),
#   ("'s", 'NN'),
#   ('vocally', 'RB'),
#   ('talented', 'JJ'),
#   (',', ','),
#   ('as', 'CS'),
#   ('you', 'PPSS'),
#   ('will', 'MD'),
#   ('soon', 'RB'),
#   ('see', 'VB'),
#   ('.', '.')],
#  [('and', 'CC'),
#   ('those', 'DTS'),
#   ('who', 'WPS'),
#   ('are', 'BER'),
#   ('part', 'NN'),
#   ('of', 'IN'),
#   ('his', 'PP$'),
#   ('family', 'NN'),
#   ('are', 'BER'),
#   ('six-year-old', 'NN'),
#   ('granddaughter', 'NN'),
#   ('has', 'HVZ'),
#   ('also', 'RB'),
#   ('joined', 'VBN'),
#   ('the', 'AT'),
#   ('chorus', 'NN'),
#   ('.', '.')],
#  [('and', 'CC'),
#   ('so', 'RB'),
#   ('we', 'PPSS'),
#   ('are', 'BER'),
#   ('tremendously', 'QL'),
#   ('honored', 'VBN'),
#   ('to', 'TO'),
#   ('have', 'HV'),
#   ('them', 'PPO'),
#   ('here', 'RB'),
#   ('with', 'IN'),
#   ('us', 'PPO'),
#   ('today', 'NR'),
#   (',', ','),
#   ('mr.', 'NN'),
#   ('chairman', 'NN'),
#   ('and', 'CC'),
#   ('colleagues', 'NNS'),
#   ('.', '.')],
#  [('you', 'PPSS'),
#   ("'ll", 'NN'),
#   ('want', 'VB'),
#   ('to', 'TO'),
#   ('note', 'VB'),
#   ('the', 'AT'),
#   ('figueroa', 'NN'),
#   ('church', 'NN'),
#   ('of', 'IN'),
#   ('christ', 'NN'),
#   ('has', 'HVZ'),
#   ('that', 'DT'),
#   ('which', 'WDT'),
#   ('we', 'PPSS'),
#   ('know', 'VB'),
#   ('as', 'CS'),
#   ('the', 'AT'),
#   ('little', 'JJ'),
#   ('angels', 'NNS'),
#   ("'", "'"),
#   ('chorus', 'NN'),
#   (',', ','),
#   ('one', 'CD'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('first', 'OD'),
#   ('to', 'TO'),
#   ('be', 'BE'),
#   ('invited', 'VBN'),
#   ('here', 'RB'),
#   ('to', 'IN'),
#   ('sing', 'VB'),
#   ('in', 'IN'),
#   ('the', 'AT'),
#   ('late', 'JJ'),
# ...
#   ('.', '.')],
#  [('sup', 'VB'), ('.', '.')],
#  [('molina', 'NN'),
#   (':', ':'),
#   ('i', 'NN'),
#   ('can', 'MD'),
#   ('also', 'RB'),
#   ('assure', 'VB'),
#   ('you', 'PPO'),
#   ('that', 'CS'),
#   ('on', 'IN'),
#   ('sunday', 'NN'),
#   ('you', 'PPSS'),
#   ('have', 'HV'),
#   ('to', 'TO'),
#   ('find', 'VB'),
#   ('some', 'DTI'),
#   ('other', 'AP'),
#   ('flight', 'NN'),
#   ('to', 'IN'),
#   ('go', 'VB'),
#   ('there', 'RB'),
#   ('.', '.')],
#  [('there', 'EX'),
#   ('are', 'BER'),
#   ('no', 'AT'),
#   ('flights', 'NNS'),
#   ('available', 'JJ'),
#   ('to', 'TO'),
#   ('d.c.', 'NN'),
#   ('on', 'IN'),
#   ('sunday', 'NN'),
#   ('.', '.')],
#  [('under', 'IN'),
#   ('sheriff', 'NN'),
#   ('larry', 'NN'),
#   ('waldie', 'NN'),
#   (':', ':'),
#   ('we', 'PPSS'),
#   ('could', 'MD'),
#   ('not', '*'),
#   ('go', 'VB'),
#   ('commercially', 'RB'),
#   ('.', '.')],
#  [('it', 'PPS'),
#   ('would', 'MD'),
#   ('be', 'BE'),
#   ('an', 'AT'),
#   ('impossible', 'JJ'),
#   ('task', 'NN'),
#   ('.', '.')],
#  [('sup', 'VB'), ('.', '.')],
#  [('ridley-thomas', 'NN'),
#   (':', ':'),
#   ('so', 'CS'),
#   ('whatever', 'WDT'),
#   ('we', 'PPSS'),
#   ('suggest', 'VB'),
#   (',', ','),
#   ('if', 'CS'),
#   ('i', 'NN'),
#   ('may', 'MD'),
#   (',', ','),
#   ('mr', 'NN'),
#   ('.', '.')],
#  [('chair', 'NN'), ('.', '.')],
#  [('sup', 'VB'), ('.', '.')],
#  [('molina', 'NN'),
#   (':', ':'),
#   ('give', 'VB'),
#   ('up', 'RP'),
#   ('your', 'PP$'),
#   ('ticket', 'NN'),
#   ('and', 'CC'),
#   ('send', 'VB'),
#   ('it', 'PPO'),
#   ('a', 'AT'),
#   ('cop', 'NN'),
#   ('?', '.')],
#  [('sup', 'VB'), ('.', '.')],
#  [('yaroslavsky', 'NN'),
#   (':', ':'),
#   ('you', 'PPSS'),
#   ('could', 'MD'),
#   ('sublease', 'NN'),
#   ('the', 'AT'),
#   ('hotel', 'NN'),
#   ('rooms', 'NNS'),
#   ('and', 'CC'),
#   ('make', 'VB'),
#   ('some', 'DTI'),
#   ('money', 'NN'),
#   ('.', '.')],
#  [('sup', 'VB'), ('.', '.')],
#  [('molina', 'NN'),
#   (':', ':'),
#   ('you', 'PPSS'),
#   ('could', 'MD'),
#   ('make', 'VB'),
#   ('some', 'DTI'),
#   ('money', 'NN'),
#   ('on', 'IN'),
#   ('it', 'PPO'),
#   ('.', '.')],
#  [('sup', 'VB'), ('.', '.')],
#  [('ridley-thomas', 'NN'),
#   (':', ':'),
#   ('what', 'WDT'),
#   ('i', 'NN'),
#   ('would', 'MD'),
#   ('not', '*'),
#   ('want', 'VB'),
#   ('to', 'TO'),
#   ('do', 'DO'),
#   ('is', 'BEZ'),
#   ('suggest', 'VB'),
#   ('a', 'AT'),
#   ('number', 'NN'),
#   ('that', 'CS'),
#   ('makes', 'VBZ'),
#   ('it', 'PPO'),
#   ('impractical', 'JJ'),
#   ('to', 'TO'),
#   ('accomplish', 'VB'),
#   ('.', '.')],
#  [('so', 'RB'),
#   ('what', 'WDT'),
#   ('seems', 'VBZ'),
#   ('to', 'TO'),
#   ('me', 'PPO'),
#   ('the', 'AT'),
#   ('variables', 'NNS'),
#   ('that', 'WPS'),
#   ('we', 'PPSS'),
#   ('are', 'BER'),
#   ('obliged', 'VBN'),
#   ('to', 'TO'),
#   ('consider', 'VB'),
#   ('have', 'HV'),
#   ('to', 'TO'),
#   ('be', 'BE'),
#   ('in', 'IN'),
#   ('the', 'AT'),
#   ('interest', 'NN'),
#   ('of', 'IN'),
#   ('doing', 'VBG'),
#   ('it', 'PPO'),
#   ('or', 'CC'),
#   ('not', '*'),
#   ('.', '.')],
#  [('and', 'CC'),
#   ('as', 'CS'),
#   ('you', 'PPSS'),
#   ("'ve", 'NN'),
#   ('gleaned', 'VBN'),
#   ('or', 'CC'),
#   ('inferred', 'VBD'),
#   (',', ','),
#   ('mr', 'NN'),
#   ('.', '.')],
#  [('chair', 'NN'),
#   (',', ','),
#   ('i', 'NN'),
#   ("'m", 'NN'),
#   ('inclined', 'VBN'),
#   ('to', 'TO'),
#   ('move', 'VB'),
#   ('forward', 'RB'),
#   ('with', 'IN'),
#   ('the', 'AT'),
#   ('number', 'NN'),
#   ('that', 'CS'),
#   ('makes', 'VBZ'),
#   ('sense', 'NN'),
#   ('.', '.')],
#  [('it', 'PPS'),
#   ('has', 'HVZ'),
#   ('been', 'BEN'),
#   ('suggested', 'VBN'),
#   ('that', 'CS'),
#   ('the', 'AT'),
#   ('proposed', 'VBN'),
#   ('and/or', 'CC'),
#   ('requested', 'VBD'),
#   ('number', 'NN'),
#   ('is', 'BEZ'),
#   ('not', '*'),
#   ('supportable', 'NN'),
#   ('.', '.')],
#  [('supervisor', 'NN'),
#   ('molina', 'NN'),
#   ('has', 'HVZ'),
#   ('asked', 'VBN'),
#   ('what', 'WDT'),
#   ('is', 'BEZ'),
#   ('so', 'QL'),
#   ('we', 'PPSS'),
#   ('can', 'MD'),
#   ('move', 'VB'),
#   ('.', '.')],
#  [('is', 'BEZ'),
#   ('the', 'AT'),
#   ('number', 'NN'),
#   ('300', 'CD'),
#   ('that', 'WPS'),
#   ('works', 'VBZ'),
#   ('?', '.')],
#  [('what', 'WDT'), ('is', 'BEZ'), ('it', 'PPS'), ('?', '.')],
#  [('under', 'IN'),
#   ('sheriff', 'NN'),
#   ('larry', 'NN'),
#   ('waldie', 'NN'),
#   (':', ':'),
#   ('well', 'RB'),
#   (',', ','),
#   ('they', 'PPSS'),
#   ('requested', 'VBN'),
#   ('they', 'PPSS'),
#   ('needed', 'VBD'),
#   ('5', 'CD'),
#   ('.', '.')],
#  [('we', 'PPSS'),
#   ('could', 'MD'),
#   ("n't", 'NN'),
#   ('do', 'DO'),
#   ('it', 'PPO'),
#   ('.', '.')],
#  [('347', 'NN'), ('.', '.')],
#  [('there', 'EX'),
#   ("'s", 'NN'),
#   ('an', 'AT'),
#   ('issue', 'NN'),
#   ('here', 'RB'),
#   ('beside', 'IN'),
#   ('the', 'AT'),
#   ('number', 'NN'),
#   ('we', 'PPSS'),
#   ('throw', 'VB'),
#   ('out', 'RP'),
#   ('to', 'IN'),
#   ('them', 'PPO'),
#   ('.', '.')],
#  [('it', 'PPS'),
#   ("'s", 'NN'),
#   ('what', 'WDT'),
#   ('they', 'PPSS'),
#   ('need', 'VB'),
#   ('and', 'CC'),
#   ('what', 'WDT'),
#   ('they', 'PPSS'),
#   ('can', 'MD'),
#   ('do', 'DO'),
#   ('to', 'TO'),
#   ('get', 'VB'),
#   ('the', 'AT'),
#   ('job', 'NN'),
#   ('done', 'VBN'),
#   ('.', '.')],
#  [('that', 'DT'),
#   ("'s", 'NN'),
#   ('what', 'WDT'),
#   ('they', 'PPSS'),
#   ("'ve", 'NN'),
#   ('asked', 'VBD'),
#   ('for', 'IN'),
#   ('.', '.')],
#  [('now', 'RB'),
#   (',', ','),
#   ('when', 'WRB'),
#   ('we', 'PPSS'),
#   ('say', 'VB'),
#   ('okay', 'JJ'),
#   (',', ','),
#   ('we', 'PPSS'),
#   ("'re", 'NN'),
#   ('only', 'RB'),
#   ('going', 'VBG'),
#   ('to', 'TO'),
#   ('send', 'VB'),
#   ('you', 'PPO'),
#   ('200', 'CD'),
#   ('or', 'CC'),
#   ('250', 'CD'),
#   (',', ','),
#   ('it', 'PPS'),
#   ("'s", 'NN'),
#   ('a', 'AT'),
#   ('burden', 'NN'),
#   ('on', 'IN'),
#   ('them', 'PPO'),
#   ('at', 'IN'),
#   ('this', 'DT'),
#   ('late', 'JJ'),
#   ('time', 'NN'),
#   ('also', 'RB'),
#   (',', ','),
#   ('then', 'RB'),
#   (',', ','),
#   ('to', 'TO'),
#   ('get', 'VB'),
#   ('other', 'AP'),
#   ('agencies', 'NNS'),
#   ('who', 'WPS'),
#   ('have', 'HV'),
#   ('not', '*'),
#   ('responded', 'VBD'),
#   ('.', '.')],
#  [('and', 'CC'),
#   ('here', 'RB'),
#   ('we', 'PPSS'),
#   ("'re", 'NN'),
#   ('dealing', 'VBG'),
#   ('with', 'IN'),
#   ('the', 'AT'),
#   ('protection', 'NN'),
#   ('for', 'IN'),
#   ('the', 'AT'),
#   ('president-elect', 'NN'),
#   ('.', '.')],
#  [('there', 'EX'),
#   ('is', 'BEZ'),
#   ('an', 'AT'),
#   ('issue', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('ability', 'NN'),
#   ('to', 'IN'),
#   ('get', 'VB'),
#   ('the', 'AT'),
#   ('help', 'NN'),
#   ('that', 'CS'),
#   ('they', 'PPSS'),
#   ('thought', 'VBD'),
#   ('they', 'PPSS'),
#   ('were', 'BED'),
#   ('going', 'VBG'),
#   ('to', 'TO'),
#   ('get', 'VB'),
#   ('from', 'IN'),
#   ('us', 'PPO'),
#   ('.', '.')],
#  [('so', 'RB'),
#   ('it', 'PPS'),
#   ("'s", 'NN'),
#   ('a', 'AT'),
#   ('real', 'JJ'),
#   ('issue', 'NN'),
#   ('.', '.')],
#  [('sup', 'VB'), ('.', '.')],
#  [('molina', 'NN'), (':', ':'), ('all', 'ABN'), ('right', 'JJ'), ('.', '.')],
#  [('sup', 'VB'), ('.', '.')],
#  [('antonovich', 'NN'),
#   (':', ':'),
#   ('i', 'NN'),
#   ('would', 'MD'),
#   ('move', 'VB'),
#   ('that', 'CS'),
#   ('we', 'PPSS'),
#   ('authorize', 'VB'),
#   ('67', 'CD'),
#   ('which', 'WDT'),
#   ('was', 'BEDZ'),
#   ('the', 'AT'),
#   ('number', 'NN'),
#   ('we', 'PPSS'),
#   ('used', 'VBD'),
#   ('at', 'IN'),
#   ('the', 'AT'),
#   ('2004', 'NN'),
#   ('.', '.')],
#  [('sup', 'VB'), ('.', '.')],
#  [('ridley-thomas', 'NN'),
#   (':', ':'),
#   ('yeah', 'RB'),
#   (',', ','),
#   ('that', 'CS'),
#   ('does', 'DOZ'),
#   ("n't", 'NN'),
#   ('work', 'NN'),
#   ('for', 'IN'),
#   ('me', 'PPO'),
#   ('.', '.')],
#  [('sup', 'VB'), ('.', '.')],
#  [('molina', 'NN'),
#   (':', ':'),
#   ('i', 'NN'),
#   ("'m", 'NN'),
#   ('going', 'VBG'),
#   ('to', 'TO'),
#   ('ask', 'VB'),
#   ('if', 'CS'),
#   ('we', 'PPSS'),
#   ('could', 'MD'),
#   ('lay', 'VB'),
#   ('this', 'DT'),
#   ('on', 'IN'),
#   ('the', 'AT'),
#   ('table', 'NN'),
#   ('for', 'IN'),
#   ('about', 'RB'),
#   ('10', 'CD'),
#   ('minutes', 'NNS'),
#   ('and', 'CC'),
#   ('go', 'VB'),
#   ('on', 'IN'),
#   ('to', 'IN'),
#   ('another', 'DT'),
#   ('item', 'NN'),
#   ('and', 'CC'),
#   ('then', 'RB'),
#   ('come', 'VB'),
#   ('back', 'RB'),
#   ('to', 'IN'),
#   ('it', 'PPO'),
#   ('.', '.')],
#  [('i', 'NN'),
#   ("'m", 'NN'),
#   ('going', 'VBG'),
#   ('to', 'TO'),
#   ('ask', 'VB'),
#   ('a', 'AT'),
#   ('couple', 'NN'),
#   ('of', 'IN'),
#   ('questions', 'NNS'),
#   ('.', '.')],
#  [('so', 'RB'),
#   ('next', 'AP'),
#   ('item', 'NN'),
#   ('is', 'BEZ'),
#   ('item', 'NN'),
#   ('number', 'NN'),
#   ('68', 'CD'),
#   ('.', '.')],
#  [('sup', 'VB'), ('.', '.')],
#  [('knabe', 'NN'),
#   (',', ','),
#   ('chair', 'NN'),
#   (':', ':'),
#   ('mr.', 'NN'),
#   ('sachs', 'NN'),
#   (',', ','),
#   ('we', 'PPSS'),
#   ('did', 'DOD'),
#   ("n't", 'NN'),
#   ('forget', 'VB'),
#   ('about', 'IN'),
#   ('you', 'PPO'),
#   (',', ','),
#   ('but', 'CC'),
#   ('we', 'PPSS'),
#   ('still', 'RB'),
#   ('have', 'HV'),
#   ('the', 'AT'),
#   ('item', 'NN'),
#   ('on', 'IN'),
#   ('the', 'AT'),
#   ('table', 'NN'),
#   ('.', '.')],
#  [('sup', 'VB'), ('.', '.')],
#  [('molina', 'NN'),
#   (':', ':'),
#   ('why', 'WRB'),
#   ('do', 'DO'),
#   ("n't", 'NN'),
#   ('we', 'PPSS'),
#   ('do', 'DO'),
#   ('the', 'AT'),
#   ('public', 'JJ'),
#   (',', ','),
#   ('the', 'AT'),
#   ('ones', 'NNS'),
#   ('he', 'PPS'),
#   ("'s", 'NN'),
#   ('held', 'VBN'),
#   ('.', '.')],
#  [('if', 'CS'),
#   ('i', 'NN'),
#   ('could', 'MD'),
#   ('call', 'VB'),
#   ('item', 'NN'),
#   ('number', 'NN'),
#   ('7', 'CD'),
#   ('and', 'CC'),
#   ('28', 'CD'),
#   ('and', 'CC'),
#   ('33', 'CD'),
#   ('.', '.')],
#  [('sup', 'VB'), ('.', '.')],
#  [('knabe', 'NN'),
#   (',', ','),
#   ('chair', 'NN'),
#   (':', ':'),
#   ('and', 'CC'),
#   ('69', 'CD'),
#   ('while', 'CS'),
#   ('you', 'PPSS'),
#   ("'re", 'NN'),
#   ('at', 'IN'),
#   ('it', 'PPO'),
#   ('.', '.')],
#  [('sup', 'VB'), ('.', '.')],
#  [('yaroslavksy', 'NN'),
#   (':', ':'),
#   ('what', 'WDT'),
#   ('were', 'BED'),
#   ('the', 'AT'),
#   ('others', 'NNS'),
#   ('?', '.')],
#  [('sup', 'VB'), ('.', '.')],
#  [('knabe', 'NN'),
#   (',', ','),
#   ('chair', 'NN'),
#   (':', ':'),
#   ('7', 'CD'),
#   (',', ','),
#   ('28', 'CD'),
#   (',', ','),
#   ('33', 'CD-TL'),
#   (',', ','),
#   ('36', 'CD'),
#   (',', ','),
#   ('47', 'CD'),
#   (',', ','),
#   ('51', 'CD'),
#   (',', ','),
#   ('and', 'CC'),
#   ('69', 'CD'),
#   ('.', '.')],
#  [('arnold', 'NN'),
#   ('sachs', 'NN'),
#   (':', ':'),
#   ('good', 'JJ'),
#   ('morning', 'NN'),
#   (',', ','),
#   ('county', 'NN'),
#   ('board', 'NN'),
#   ('of', 'IN'),
#   ('supervisors', 'NNS'),
#   ('.', '.')],
#  [('item', 'NN'),
#   ('7', 'CD'),
#   ('i', 'NN'),
#   ('was', 'BEDZ'),
#   ('concerned', 'VBN'),
#   ('about', 'IN'),
#   ('one', 'CD'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('items', 'NNS'),
#   ('in', 'IN'),
#   ('item', 'NN'),
#   ('7', 'CD'),
#   (',', ','),
#   ('the', 'AT'),
#   ('transportation', 'NN'),
#   ('school', 'NN'),
#   ('.', '.')],
#  [('in', 'IN'),
#   ('the', 'AT'),
#   ('south', 'NR'),
#   ('bay', 'NN'),
#   ('where', 'WRB'),
#   ('i', 'NN'),
#   ('reside', 'VB'),
#   (',', ','),
#   ('hermosa', 'NN'),
#   ('beach', 'NN'),
#   (',', ','),
#   ('they', 'PPSS'),
#   ('have', 'HV'),
#   ('a', 'AT'),
#   ('program', 'NN'),
#   ('for', 'IN'),
#   ('transporting', 'VBG'),
#   ('disabled', 'VBN'),
#   ('children', 'NNS'),
#   ('.', '.')],
#  [('hermosa', 'NN'),
#   ('beach', 'NN'),
#   ('is', 'BEZ'),
#   ('2', 'CD'),
#   ('1/2', 'CD'),
#   ('miles', 'NNS'),
#   ('long', 'JJ'),
#   (',', ','),
#   ('maybe', 'RB'),
#   ('a', 'AT'),
#   ('mile', 'NN'),
#   ('wide', 'JJ'),
#   ('.', '.')],
#  [('and', 'CC'),
#   ('that', 'CS'),
#   ('program', 'NN'),
#   ('although', 'CS'),
#   ('it', 'PPS'),
#   ("'s", 'NN'),
#   ('open', 'JJ'),
#   ('and', 'CC'),
#   ('transparent', 'JJ'),
#   (',', ','),
#   ('the', 'AT'),
#   ('company', 'NN'),
#   ('collects', 'VBZ'),
#   ('$', 'NN'),
#   ('100', 'CD'),
#   ('for', 'IN'),
#   ('each', 'DT'),
#   ('student', 'NN'),
#   ('that', 'CS'),
#   ("'s", 'NN'),
#   ('transported', 'VBN'),
#   ('plus', 'CC'),
#   ('expenses', 'NNS'),
#   ('.', '.')],
#  [('each', 'DT'),
#   ('medical', 'JJ'),
#   ('student', 'NN'),
#   (',', ','),
#   ('they', 'PPSS'),
#   ('use', 'VB'),
#   ('it', 'PPO'),
#   ('for', 'IN'),
#   ('medical', 'JJ'),
#   (',', ','),
#   ('for', 'IN'),
#   ('children', 'NNS'),
#   ('with', 'IN'),
#   ('medical', 'JJ'),
#   ('needs', 'NNS'),
#   ('.', '.')],
#  [('that', 'DT'),
#   ("'s", 'NN'),
#   ('an', 'AT'),
#   ('awful', 'JJ'),
#   ('lot', 'NN'),
#   ('of', 'IN'),
#   ('money', 'NN'),
#   ('to', 'IN'),
#   ('travel', 'NN'),
#   ('2', 'CD'),
#   ('1/2', 'CD'),
#   ('miles', 'NNS'),
#   ('.', '.')],
#  [('so', 'RB'),
#   ('although', 'CS'),
#   ('the', 'AT'),
#   ('contracts', 'NNS'),
#   ('may', 'MD'),
#   ('look', 'VB'),
#   ('transparent', 'JJ'),
#   (',', ','),
#   ('although', 'CS'),
#   ('there', 'EX'),
#   ('may', 'MD'),
#   ('not', '*'),
#   ('be', 'BE'),
#   ('a', 'AT'),
#   ('conflict', 'NN'),
#   ('of', 'IN'),
#   ('interest', 'NN'),
#   (',', ','),
#   ('it', 'PPS'),
#   ('would', 'MD'),
#   ('be', 'BE'),
#   ('really', 'QL'),
#   ('nice', 'JJ'),
#   ('to', 'TO'),
#   ('make', 'VB'),
#   ('sure', 'JJ'),
#   ('that', 'CS'),
#   ('they', 'PPSS'),
#   ("'re", 'NN'),
#   ('open', 'JJ'),
#   ('and', 'CC'),
#   ('competitive', 'JJ'),
#   ('in', 'IN'),
#   ('their', 'PP$'),
#   ('bidding', 'NN'),
#   ('process', 'NN'),
#   ('.', '.')],
#  [('item', 'NN'), ('number', 'NN'), ('7', 'CD'), ('.', '.')],
#  [('sup', 'VB'), ('.', '.')],
#  [('knabe', 'NN'),
#   (',', ','),
#   ('chair', 'NN'),
#   (':', ':'),
#   ('okay', 'JJ'),
#   ('.', '.')],
#  [('the', 'AT'),
#   ('item', 'NN'),
#   ('is', 'BEZ'),
#   ('now', 'RB'),
#   ('before', 'CS'),
#   ('us', 'PPO'),
#   ('.', '.')],
#  [('moved', 'VBD'),
#   ('by', 'IN'),
#   ('supervisor', 'NN'),
#   ('antonovich', 'NN'),
#   ('.', '.')],
#  [('the', 'AT'),
#   ('chair', 'NN'),
#   ('will', 'MD'),
#   ('second', 'OD'),
#   ('.', '.')],
#  [('without', 'IN'),
#   ('objection', 'NN'),
#   (',', ','),
#   ('so', 'CS'),
#   ('ordered', 'VBN'),
#   ('.', '.')],
#  [('i', 'NN'),
#   ('would', 'MD'),
#   ('add', 'VB'),
#   ('most', 'AP'),
#   ('of', 'IN'),
#   ('that', 'DT'),
#   ('process', 'NN'),
#   ('is', 'BEZ'),
#   ('bid', 'NN'),
#   ('.', '.')],
#  [('and', 'CC'),
#   ('there', 'EX'),
#   ('were', 'BED'),
#   ('very', 'QL'),
#   ('few', 'AP'),
#   ('providers', 'NN'),
#   ('of', 'IN'),
#   ('that', 'DT'),
#   ('service', 'NN'),
#   ('.', '.')],
#  [('so', 'RB'),
#   ('it', 'PPS'),
#   ('is', 'BEZ'),
#   ('a', 'AT'),
#   ('good', 'JJ'),
#   ('service', 'NN'),
#   ('.', '.')],
#  [('although', 'CS'),
#   ('totally', 'RB'),
#   ('unrelated', 'JJ'),
#   ('to', 'TO'),
#   ('this', 'DT'),
#   ('item', 'NN'),
#   ('.', '.')],
#  [('but', 'CC'), ('that', 'CS'), ("'s", 'NN'), ('okay', 'JJ'), ('.', '.')],
#  [('arnold', 'NN'),
#   ('sachs', 'NN'),
#   (':', ':'),
#   ('well', 'RB'),
#   (',', ','),
#   ('it', 'PPS'),
#   ("'s", 'NN'),
#   ('disability', 'NN'),
#   ('.', '.')],
#  [('sup', 'VB'), ('.', '.')],
#  [('knabe', 'NN'),
#   (',', ','),
#   ('chair', 'NN'),
#   (':', ':'),
#   ('a.d.a.', 'NN'),
#   (',', ','),
#   ('right', 'QL'),
#   ('.', '.')],
#  [('arnold', 'NN'),
#   ('sachs', 'NN'),
#   (':', ':'),
#   ('next', 'AP'),
#   ('item', 'NN'),
#   (',', ','),
#   ('sir', 'NN'),
#   ('?', '.')],
#  [('sup', 'VB'), ('.', '.')],
#  [('knabe', 'NN'),
#   (',', ','),
#   ('chair', 'NN'),
#   (':', ':'),
#   ('next', 'AP'),
#   ('item', 'NN'),
#   ('would', 'MD'),
#   ('be', 'BE'),
#   ('item', 'NN'),
#   ('28', 'CD'),
#   ('.', '.')],
#  [('arnold', 'NN'),
#   ('sachs', 'NN'),
#   (':', ':'),
#   ('item', 'NN'),
#   ('28', 'CD'),
#   ('.', '.')],
#  [('another', 'DT'), ('big', 'JJ'), ('pot', 'NN'), ('.', '.')],
#  [('is', 'BEZ'),
#   ('this', 'DT'),
#   ('any', 'DTI'),
#   ('kind', 'NN'),
#   ('of', 'IN'),
#   ('relationship', 'NN'),
#   ('to', 'IN'),
#   ('any', 'DTI'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('other', 'AP'),
#   ('transportation', 'NN'),
#   ('funding', 'VBG'),
#   ('that', 'CS'),
#   ('is', 'BEZ'),
#   ('now', 'RB'),
#   ('coming', 'VBG'),
#   ('up', 'RP'),
#   ('prop', 'NN'),
#   ('1-h', 'NN'),
#   (',', ','),
#   ('prop', 'NN'),
#   ('a', 'AT'),
#   (',', ','),
#   ('prop', 'NN'),
#   ('c', 'NN'),
#   ('?', '.')],
#  [('i', 'NN'),
#   ('know', 'VB'),
#   ('it', 'PPO'),
#   ("'s", 'NN'),
#   ('not', '*'),
#   ('prop', 'NN'),
#   ('r', 'NN'),
#   (',', ','),
#   ('but', 'CC'),
#   ('there', 'EX'),
#   ('just', 'RB'),
#   ('seems', 'VBZ'),
#   ('to', 'TO'),
#   ('be', 'BE'),
#   ('more', 'QL'),
#   ('and', 'CC'),
#   ('more', 'AP'),
#   ('pots', 'NNS'),
#   ('all', 'ABN'),
#   ('of', 'IN'),
#   ('a', 'AT'),
#   ('sudden', 'JJ'),
#   ('opening', 'VBG'),
#   ('up', 'RP'),
#   ('for', 'IN'),
#   ('funding', 'VBG'),
#   ('for', 'IN'),
#   ('transportation', 'NN'),
#   ('issues', 'NNS'),
#   ('.', '.')],
#  [('and', 'CC'),
#   ('who', 'WPS'),
#   ("'s", 'NN'),
#   ('overseeing', 'NN'),
#   ('and', 'CC'),
#   ('who', 'WPS'),
#   ("'s", 'NN'),
#   ('looking', 'VBG'),
#   ('out', 'RP'),
#   ('for', 'IN'),
#   ('the', 'AT'),
#   ('general', 'JJ'),
#   ('public', 'NN'),
#   ("'s", 'NN'),
#   ('welfare', 'NN'),
#   ('on', 'IN'),
#   ('how', 'WRB'),
#   ('this', 'DT'),
#   ('money', 'NN'),
#   ('is', 'BEZ'),
#   ('being', 'BEG'),
#   ('spent', 'VBN'),
#   ('?', '.')],
#  ...]

# %%
#brown_tagger = train_tagger_on_brown()

# %%
def V2Vchunker(sentence):
    grammar= r"""
    V2V_CHUNK: 
           {<V.*> <TO> <V.*>}
    """
    cp=nltk.RegexpParser(grammar)
    result = cp.parse(sentence)
    return result

# %%
from operator import itemgetter

for sent in mybook_tags:
    V2V_tree = V2Vchunker(sent)
    for subtree in V2V_tree.subtrees():
        if subtree.label() == 'V2V_CHUNK': 
            print(subtree)
# Out:
# (V2V_CHUNK came/VBD to/TO united/VBN)
# (V2V_CHUNK want/VB to/TO extend/VB)
# (V2V_CHUNK want/VB to/TO present/VB)
# (V2V_CHUNK want/VB to/TO welcome/VB)
# (V2V_CHUNK referred/VBN to/TO closed/VBN)
# (V2V_CHUNK allowed/VBN to/TO select/VB)
# (V2V_CHUNK want/VB to/TO give/VB)
# (V2V_CHUNK want/VB to/TO thank/VB)
# (V2V_CHUNK came/VBD to/TO see/VB)
# (V2V_CHUNK pleased/VBN to/TO ask/VB)
# (V2V_CHUNK want/VB to/TO know/VB)
# (V2V_CHUNK want/VB to/TO note/VB)
# (V2V_CHUNK want/VB to/TO know/VB)
# (V2V_CHUNK delighted/VBN to/TO hear/VB)
# (V2V_CHUNK hope/VB to/TO see/VB)
# (V2V_CHUNK hope/VB to/TO continue/VB)
# (V2V_CHUNK going/VBG to/TO perform/VB)
# (V2V_CHUNK wanted/VBD to/TO see/VB)
# (V2V_CHUNK going/VBG to/TO ask/VB)
# (V2V_CHUNK going/VBG to/TO recognize/VB)
# (V2V_CHUNK going/VBG to/TO ask/VB)
# (V2V_CHUNK want/VB to/TO thank/VB)
# (V2V_CHUNK trying/VBG to/TO figure/VB)
# (V2V_CHUNK want/VB to/TO make/VB)
# (V2V_CHUNK want/VB to/TO begin/VB)
# (V2V_CHUNK want/VB to/TO congratulate/VB)
# (V2V_CHUNK going/VBG to/TO ask/VB)
# (V2V_CHUNK want/VB to/TO congratulate/VB)
# (V2V_CHUNK continue/VB to/TO work/VB)
# (V2V_CHUNK continue/VB to/TO distinguish/VB)
# (V2V_CHUNK continued/VBN to/TO distinguish/VB)
# (V2V_CHUNK threatening/VBG to/TO close/VB)
# (V2V_CHUNK want/VB to/TO underestimate/VB)
# (V2V_CHUNK wanted/VBD to/TO thank/VB)
# (V2V_CHUNK going/VBG to/TO recognize/VB)
# (V2V_CHUNK need/VB to/TO grow/VB)
# (V2V_CHUNK trying/VBG to/TO get/VB)
# (V2V_CHUNK trying/VBG to/TO get/VB)
# (V2V_CHUNK want/VB to/TO begin/VB)
# (V2V_CHUNK refused/VBD to/TO pay/VB)
# (V2V_CHUNK tried/VBD to/TO understand/VB)
# (V2V_CHUNK going/VBG to/TO cost/VB)
# (V2V_CHUNK going/VBG to/TO permit/VB)
# (V2V_CHUNK going/VBG to/TO limit/VB)
# (V2V_CHUNK want/VB to/TO make/VB)
# (V2V_CHUNK trying/VBG to/TO provide/VB)
# (V2V_CHUNK want/VB to/TO say/VB)
# (V2V_CHUNK want/VB to/TO express/VB)
# (V2V_CHUNK going/VBG to/TO happen/VB)
# (V2V_CHUNK afford/VB to/TO pay/VB)
# (V2V_CHUNK supposed/VBN to/TO send/VB)
# (V2V_CHUNK want/VB to/TO keep/VB)
# (V2V_CHUNK like/VB to/TO go/VB)
# (V2V_CHUNK want/VB to/TO help/VB)
# (V2V_CHUNK going/VBG to/TO use/VB)
# (V2V_CHUNK going/VBG to/TO go/VB)
# (V2V_CHUNK going/VBG to/TO cost/VB)
# (V2V_CHUNK going/VBG to/TO cover/VB)
# (V2V_CHUNK asked/VBD to/TO participate/VB)
# (V2V_CHUNK going/VBG to/TO happen/VB)
# (V2V_CHUNK came/VBD to/TO rely/VB)
# (V2V_CHUNK going/VBG to/TO become/VB)
# (V2V_CHUNK going/VBG to/TO support/VB)
# (V2V_CHUNK inclined/VBN to/TO move/VB)
# (V2V_CHUNK want/VB to/TO underscore/VB)
# (V2V_CHUNK going/VBG to/TO go/VB)
# (V2V_CHUNK going/VBG to/TO reimburse/VB)
# (V2V_CHUNK trying/VBG to/TO understand/VB)
# (V2V_CHUNK need/VB to/TO know/VB)
# (V2V_CHUNK trying/VBG to/TO push/VB)
# (V2V_CHUNK obliged/VBN to/TO consider/VB)
# (V2V_CHUNK inclined/VBN to/TO move/VB)
# (V2V_CHUNK going/VBG to/TO send/VB)
# (V2V_CHUNK going/VBG to/TO get/VB)
# (V2V_CHUNK going/VBG to/TO ask/VB)
# (V2V_CHUNK going/VBG to/TO ask/VB)
# (V2V_CHUNK going/VBG to/TO give/VB)
# (V2V_CHUNK going/VBG to/TO turn/VB)
# (V2V_CHUNK want/VB to/TO put/VB)
# (V2V_CHUNK afford/VB to/TO give/VB)
# (V2V_CHUNK came/VBD to/TO covering/VBG)
# (V2V_CHUNK need/VB to/TO vote/VB)
# (V2V_CHUNK going/VBG to/TO move/VB)
# (V2V_CHUNK going/VBG to/TO ask/VB)
# (V2V_CHUNK like/VB to/TO direct/VB)
# (V2V_CHUNK like/VB to/TO recommend/VB)
# (V2V_CHUNK got/VBD to/TO make/VB)
# (V2V_CHUNK want/VB to/TO make/VB)
# (V2V_CHUNK chooses/VBZ to/TO ask/VB)
# (V2V_CHUNK trying/VBG to/TO avoid/VB)
# (V2V_CHUNK like/VB to/TO get/VB)
# (V2V_CHUNK going/VBG to/TO direct/VB)
# (V2V_CHUNK going/VBG to/TO look/VB)
# (V2V_CHUNK wanted/VBD to/TO see/VB)
# (V2V_CHUNK want/VB to/TO make/VB)
# (V2V_CHUNK want/VB to/TO repeat/VB)
# (V2V_CHUNK want/VB to/TO say/VB)
# (V2V_CHUNK want/VB to/TO thank/VB)
# (V2V_CHUNK needed/VBN to/TO hear/VB)
# (V2V_CHUNK continues/VBZ to/TO surprise/VB)
# (V2V_CHUNK going/VBG to/TO assist/VB)
# (V2V_CHUNK get/VB to/TO go/VB)
# (V2V_CHUNK trying/VBG to/TO get/VB)
# (V2V_CHUNK trying/VBG to/TO get/VB)
# (V2V_CHUNK trying/VBG to/TO understand/VB)
# (V2V_CHUNK trying/VBG to/TO put/VB)
# (V2V_CHUNK trying/VBG to/TO sort/VB)
# (V2V_CHUNK want/VB to/TO tell/VB)
# (V2V_CHUNK going/VBG to/TO guide/VB)
# (V2V_CHUNK want/VB to/TO make/VB)
# (V2V_CHUNK going/VBG to/TO get/VB)
# (V2V_CHUNK use/VB to/TO select/VB)
# (V2V_CHUNK wanted/VBD to/TO ask/VB)
# (V2V_CHUNK want/VB to/TO divide/VB)
# (V2V_CHUNK trying/VBG to/TO develop/VB)
# (V2V_CHUNK propose/VB to/TO limit/VB)
# (V2V_CHUNK prepared/VBN to/TO support/VB)
# (V2V_CHUNK trying/VBG to/TO stretch/VB)
# (V2V_CHUNK going/VBG to/TO ask/VB)
# (V2V_CHUNK going/VBG to/TO absorb/VB)
# (V2V_CHUNK going/VBG to/TO pay/VB)
# (V2V_CHUNK going/VBG to/TO ask/VB)
# (V2V_CHUNK wanted/VBD to/TO protect/VB)
# (V2V_CHUNK going/VBG to/TO pick/VB)
# (V2V_CHUNK going/VBG to/TO pick/VB)
# (V2V_CHUNK going/VBG to/TO ask/VB)
# (V2V_CHUNK want/VB to/TO get/VB)
# (V2V_CHUNK want/VB to/TO make/VB)
# (V2V_CHUNK change/VB to/TO reflect/VB)
# (V2V_CHUNK got/VBD to/TO say/VB)
# (V2V_CHUNK going/VBG to/TO give/VB)
# (V2V_CHUNK wanted/VBD to/TO send/VB)
# (V2V_CHUNK need/VB to/TO know/VB)
# (V2V_CHUNK pledged/VBN to/TO initiate/VB)
# (V2V_CHUNK begun/VBN to/TO work/VB)
# (V2V_CHUNK leaves/VBZ to/TO cherish/VB)
# (V2V_CHUNK trying/VBG to/TO find/VB)
# (V2V_CHUNK want/VB to/TO get/VB)
# (V2V_CHUNK used/VBN to/TO serve/VB)
# (V2V_CHUNK proceed/VB to/TO make/VB)
# (V2V_CHUNK try/VB to/TO work/VB)
# (V2V_CHUNK try/VB to/TO address/VB)
# (V2V_CHUNK want/VB to/TO make/VB)
# (V2V_CHUNK starting/VBG to/TO come/VB)
# (V2V_CHUNK starting/VBG to/TO come/VB)
# (V2V_CHUNK going/VBG to/TO move/VB)
# (V2V_CHUNK modified/VBN to/TO require/VB)
# (V2V_CHUNK going/VBG to/TO address/VB)
# (V2V_CHUNK going/VBG to/TO handle/VB)
# (V2V_CHUNK want/VB to/TO hold/VB)
# (V2V_CHUNK trying/VBG to/TO gather/VB)
# (V2V_CHUNK going/VBG to/TO take/VB)
# (V2V_CHUNK going/VBG to/TO call/VB)
# (V2V_CHUNK failed/VBD to/TO build/VB)
# (V2V_CHUNK want/VB to/TO know/VB)
# (V2V_CHUNK going/VBG to/TO call/VB)
# (V2V_CHUNK plan/VB to/TO testify/VB)
# (V2V_CHUNK affirm/VB to/TO tell/VB)
# (V2V_CHUNK revised/VBN to/TO address/VB)
# (V2V_CHUNK like/VB to/TO mention/VB)
# (V2V_CHUNK want/VB to/TO use/VB)
# (V2V_CHUNK want/VB to/TO thank/VB)
# (V2V_CHUNK want/VB to/TO speak/VB)
# (V2V_CHUNK forced/VBN to/TO face/VB)
# (V2V_CHUNK wants/VBZ to/TO buy/VB)
# (V2V_CHUNK want/VB to/TO save/VB)
# (V2V_CHUNK want/VB to/TO maximize/VB)
# (V2V_CHUNK equipped/VBN to/TO absorb/VB)
# (V2V_CHUNK like/VB to/TO read/VB)
# (V2V_CHUNK intend/VB to/TO raise/VB)
# (V2V_CHUNK intending/VBG to/TO raise/VB)
# (V2V_CHUNK like/VB to/TO ask/VB)
# (V2V_CHUNK search/VB to/TO see/VB)
# (V2V_CHUNK tried/VBD to/TO look/VB)
# (V2V_CHUNK wanted/VBD to/TO make/VB)
# (V2V_CHUNK continue/VB to/TO refer/VB)
# (V2V_CHUNK sniffed/VBD to/TO detect/VB)
# (V2V_CHUNK done/VBN to/TO protect/VB)
# (V2V_CHUNK protected/VBN to/TO allow/VB)
# (V2V_CHUNK want/VB to/TO respond/VB)
# (V2V_CHUNK going/VBG to/TO release/VB)
# (V2V_CHUNK going/VBG to/TO continue/VB)
# (V2V_CHUNK want/VB to/TO make/VB)
# (V2V_CHUNK asked/VBN to/TO commit/VB)
# (V2V_CHUNK approached/VBN to/TO increase/VB)
# (V2V_CHUNK going/VBG to/TO extend/VB)
# (V2V_CHUNK want/VB to/TO give/VB)
# (V2V_CHUNK done/VBN to/TO find/VB)
# (V2V_CHUNK funding/VBG to/TO meet/VB)
# (V2V_CHUNK want/VB to/TO hear/VB)
# (V2V_CHUNK produced/VBN to/TO come/VB)
# (V2V_CHUNK trying/VBG to/TO address/VB)
# (V2V_CHUNK passed/VBN to/TO help/VB)
# (V2V_CHUNK need/VB to/TO go/VB)
# (V2V_CHUNK estimated/VBN to/TO cost/VB)
# (V2V_CHUNK obligated/VBN to/TO pay/VB)
# (V2V_CHUNK voted/VBN to/TO support/VB)
# (V2V_CHUNK voted/VBD to/TO support/VB)
# (V2V_CHUNK want/VB to/TO pursue/VB)
# (V2V_CHUNK wishing/VBG to/TO speak/VB)
# (V2V_CHUNK wanted/VBD to/TO reiterate/VB)
# (V2V_CHUNK tried/VBN to/TO take/VB)
# (V2V_CHUNK tried/VBD to/TO stand/VB)
# (V2V_CHUNK want/VB to/TO reiterate/VB)
# (V2V_CHUNK like/VB to/TO relate/VB)
# (V2V_CHUNK wanted/VBD to/TO bring/VB)
# (V2V_CHUNK allowed/VBN to/TO keep/VB)
# (V2V_CHUNK wanted/VBD to/TO lease/VB)
# (V2V_CHUNK used/VBN to/TO get/VB)
# (V2V_CHUNK coming/VBG to/TO lease/VB)
# (V2V_CHUNK want/VB to/TO take/VB)
# (V2V_CHUNK used/VBN to/TO see/VB)
# (V2V_CHUNK trying/VBG to/TO find/VB)
# (V2V_CHUNK need/VB to/TO take/VB)
# (V2V_CHUNK going/VBG to/TO go/VB)
# (V2V_CHUNK begin/VB to/TO determine/VB)
# (V2V_CHUNK going/VBG to/TO create/VB)
# (V2V_CHUNK going/VBG to/TO create/VB)
# (V2V_CHUNK like/VB to/TO say/VB)

# %%
def NP_IN_chunker(sentence):
    grammar= r"""
    NP_IN_CHUNK: 
           {<[CDJNP].*>+} 
          
    """
    cp=nltk.RegexpParser(grammar)
    result = cp.parse(sentence)
    return result

# %%
for sent in mybook_tags:
    NP_IN_tree = NP_IN_chunker(sent)
    for subtree in NP_IN_tree.subtrees():
        if subtree.label() == 'NP_IN_CHUNK': print(subtree)
# Out:
# (NP_IN_CHUNK knabe/NN)
# (NP_IN_CHUNK chair/NN)
# (NP_IN_CHUNK meeting/NN)
# (NP_IN_CHUNK order/NN)
# (NP_IN_CHUNK if/CS everyone/PN)
# (NP_IN_CHUNK rise/NN)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK invocation/NN this/DT morning/NN)
# (NP_IN_CHUNK father/NN mauricio/NN goloron/NN)
# (NP_IN_CHUNK st./NN martha/NN 's/NN church/NN)
# (NP_IN_CHUNK puente/NN and/CC)
# (NP_IN_CHUNK pledge/NN)
# (NP_IN_CHUNK victor/NN aprea/NN)
# (NP_IN_CHUNK member/NN post/NN 790/CD)
# (NP_IN_CHUNK west/NR covina/NN)
# (NP_IN_CHUNK american/NN legion/NN)
# (NP_IN_CHUNK father/NN)
# (NP_IN_CHUNK fr/NN)
# (NP_IN_CHUNK mauricio/NN goloron/NN)
# (NP_IN_CHUNK god/NN)
# (NP_IN_CHUNK us/PPO)
# (NP_IN_CHUNK darkness/NN)
# (NP_IN_CHUNK his/PP$ wonderful/JJ light/NN)
# (NP_IN_CHUNK god/NN 's/NN light/NN guide/NN us/PPO and/CC)
# (NP_IN_CHUNK us/PPO as/CS)
# (NP_IN_CHUNK community/NN)
# (NP_IN_CHUNK god/NN 's/NN wisdom/NN direct/JJ this/DT board/NN)
# (NP_IN_CHUNK its/PP$ work/NN and/CC decisions/NNS today/NR and/CC)
# (NP_IN_CHUNK day/NN)
# (NP_IN_CHUNK god/NN 's/NN love/NN)
# (NP_IN_CHUNK those/DTS)
# (NP_IN_CHUNK our/PP$ county/NN and/CC)
# (NP_IN_CHUNK god/NN 's/NN peace/NN)
# (NP_IN_CHUNK us/PPO one/CD)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK us/PPO)
# (NP_IN_CHUNK common/JJ good/NN)
# (NP_IN_CHUNK our/PP$ neighbors/NNS)
# (NP_IN_CHUNK prayer/NN)
# (NP_IN_CHUNK spanish/NN)
# (NP_IN_CHUNK prayer/NN)
# (NP_IN_CHUNK tagalog/NN)
# (NP_IN_CHUNK victor/NN aprea/NN)
# (NP_IN_CHUNK face/NN)
# (NP_IN_CHUNK flag/NN)
# (NP_IN_CHUNK your/PP$ right/JJ land/NN)
# (NP_IN_CHUNK your/PP$ heart/NN and/CC)
# (NP_IN_CHUNK me/PPO)
# (NP_IN_CHUNK pledge/NN)
# (NP_IN_CHUNK allegiance/NN)
# (NP_IN_CHUNK pledge/NN)
# (NP_IN_CHUNK allegiance/NN)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK supervisor/NN molina/NN)
# (NP_IN_CHUNK molina/NN)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK mr./NN chairman/NN)
# (NP_IN_CHUNK it/PPS 's/NN my/PP$ honor/NN this/DT morning/NN)
# (NP_IN_CHUNK present/JJ)
# (NP_IN_CHUNK certificate/NN)
# (NP_IN_CHUNK appreciation/NN)
# (NP_IN_CHUNK father/NN mauricio/NN goloron/NN)
# (NP_IN_CHUNK father/NN goloron/NN)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK southern/JJ philippines/NN)
# (NP_IN_CHUNK he/PPS)
# (NP_IN_CHUNK seminary/NN)
# (NP_IN_CHUNK age/NN)
# (NP_IN_CHUNK 12/CD and/CC)
# (NP_IN_CHUNK society/NN)
# (NP_IN_CHUNK jesus/NN and/CC)
# (NP_IN_CHUNK priest/NN)
# (NP_IN_CHUNK 1984/CD-TL)
# (NP_IN_CHUNK 1998/NN)
# (NP_IN_CHUNK father/NN goloron/NN)
# (NP_IN_CHUNK states/NNS)
# (NP_IN_CHUNK he/PPS)
# (NP_IN_CHUNK immaculate/JJ heart/NN)
# (NP_IN_CHUNK mary/NN church/NN)
# (NP_IN_CHUNK hollywood/NN)
# (NP_IN_CHUNK st./NN catherine/NN laborne/NN church/NN)
# (NP_IN_CHUNK torrens/NN and/CC)
# (NP_IN_CHUNK heads/NNS)
# (NP_IN_CHUNK robust/NN congregation/NN)
# (NP_IN_CHUNK st./NN martha/NN 's/NN church/NN)
# (NP_IN_CHUNK velinda/NN)
# (NP_IN_CHUNK st./NN martha/NN 's/NN)
# (NP_IN_CHUNK community/NN and/CC their/PP$)
# (NP_IN_CHUNK compassionate/JJ parishioners/NNS)
# (NP_IN_CHUNK good/JJ works/NNS and/CC community/NN service/NN)
# (NP_IN_CHUNK such/JJ as/CS)
# (NP_IN_CHUNK food/NN banks/NNS and/CC)
# (NP_IN_CHUNK clothing/NN bank/NN)
# (NP_IN_CHUNK needy/JJ)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK our/PP$ heartfelt/JJ thanks/NNS)
# (NP_IN_CHUNK goloron/NN and/CC we/PPSS)
# (NP_IN_CHUNK him/PPO)
# (NP_IN_CHUNK certificate/NN)
# (NP_IN_CHUNK appreciation/NN)
# (NP_IN_CHUNK us/PPO)
# (NP_IN_CHUNK our/PP$ invocation/NN)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK father/NN)
# (NP_IN_CHUNK applause/NN)
# (NP_IN_CHUNK supervisor/NN antonovich/NN)
# (NP_IN_CHUNK antonovich/NN)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK victor/NN aprea/NN)
# (NP_IN_CHUNK covina/NN)
# (NP_IN_CHUNK today/NR as/CS)
# (NP_IN_CHUNK member/NN)
# (NP_IN_CHUNK west/NR covina/NN post/NN)
# (NP_IN_CHUNK 790/CD)
# (NP_IN_CHUNK american/NN legion/NN)
# (NP_IN_CHUNK he/PPS)
# (NP_IN_CHUNK as/CS administrative/JJ assistant/NN)
# (NP_IN_CHUNK city/NN)
# (NP_IN_CHUNK los/NN angeles/NN transportation/NN department/NN)
# (NP_IN_CHUNK graduate/NN)
# (NP_IN_CHUNK washington/NN generals/NNS high/JJ school/NN)
# (NP_IN_CHUNK los/NN angeles/NN and/CC university/NN)
# (NP_IN_CHUNK southern/JJ california/NN)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK applause/NN)
# (NP_IN_CHUNK knabe/NN)
# (NP_IN_CHUNK chair/NN)
# (NP_IN_CHUNK okay/JJ)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK reading/NN)
# (NP_IN_CHUNK agenda/NN)
# (NP_IN_CHUNK clerk/NN sachi/NN hamai/NN)
# (NP_IN_CHUNK good/JJ morning/NN)
# (NP_IN_CHUNK mr./NN chairman/NN)
# (NP_IN_CHUNK members/NNS)
# (NP_IN_CHUNK board/NN)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK today/NR 's/NN agenda/NN)
# (NP_IN_CHUNK page/NN 3/CD)
# (NP_IN_CHUNK agenda/NN)
# (NP_IN_CHUNK meeting/NN)
# (NP_IN_CHUNK community/NN development/NN commission/NN)
# (NP_IN_CHUNK items/NNS 1-d/NN)
# (NP_IN_CHUNK 4-d./NN)
# (NP_IN_CHUNK knabe/NN)
# (NP_IN_CHUNK chair/NN)
# (NP_IN_CHUNK supervisor/NN yaroslavsky/NN)
# (NP_IN_CHUNK seconded/NN)
# (NP_IN_CHUNK antonovich/NN)
# (NP_IN_CHUNK objection/NN)
# (NP_IN_CHUNK so/CS)
# (NP_IN_CHUNK clerk/NN sachi/NN hamai/NN)
# (NP_IN_CHUNK agenda/NN)
# (NP_IN_CHUNK meeting/NN)
# (NP_IN_CHUNK authority/NN)
# (NP_IN_CHUNK item/NN 1-h./NN)
# (NP_IN_CHUNK knabe/NN)
# (NP_IN_CHUNK chair/NN)
# (NP_IN_CHUNK clerk/NN sachi/NN hamai/NN)
# (NP_IN_CHUNK item/NN 1-h/NN)
# (NP_IN_CHUNK agenda/NN)
# (NP_IN_CHUNK authority/NN)
# (NP_IN_CHUNK knabe/NN)
# (NP_IN_CHUNK chair/NN)
# (NP_IN_CHUNK yaroslavsky/NN)
# (NP_IN_CHUNK seconded/NN)
# (NP_IN_CHUNK molina/NN)
# (NP_IN_CHUNK objection/NN)
# (NP_IN_CHUNK so/CS)
# (NP_IN_CHUNK clerk/NN sachi/NN hamai/NN)
# (NP_IN_CHUNK page/NN 6/CD)
# (NP_IN_CHUNK agenda/NN)
# (NP_IN_CHUNK meeting/NN)
# (NP_IN_CHUNK regional/JJ park/NN and/CC)
# (NP_IN_CHUNK space/NN district/NN)
# (NP_IN_CHUNK item/NN 1-p./NN)
# (NP_IN_CHUNK knabe/NN)
# (NP_IN_CHUNK chair/NN)
# (NP_IN_CHUNK supervisor/NN molina/NN)
# (NP_IN_CHUNK seconded/NN)
# (NP_IN_CHUNK supervisor/NN antonovich/NN)
# (NP_IN_CHUNK objection/NN)
# (NP_IN_CHUNK so/CS)
# (NP_IN_CHUNK clerk/NN sachi/NN hamai/NN)
# (NP_IN_CHUNK board/NN)
# (NP_IN_CHUNK supervisors/NNS items/NNS 1/CD)
# (NP_IN_CHUNK 7/CD)
# (NP_IN_CHUNK item/NN number/NN 7/CD)
# (NP_IN_CHUNK request/NN)
# (NP_IN_CHUNK member/NN)
# (NP_IN_CHUNK public/JJ)
# (NP_IN_CHUNK this/DT item/NN)
# (NP_IN_CHUNK items/NNS)
# (NP_IN_CHUNK before/CS you/PPSS)
# (NP_IN_CHUNK knabe/NN)
# (NP_IN_CHUNK chair/NN)
# (NP_IN_CHUNK item/NN 7/CD)
# (NP_IN_CHUNK clerk/NN sachi/NN hamai/NN)
# (NP_IN_CHUNK knabe/NN)
# (NP_IN_CHUNK chair/NN)
# (NP_IN_CHUNK okay/JJ)
# (NP_IN_CHUNK remainder/NN)
# (NP_IN_CHUNK supervisor/NN ridley-thomas/NN)
# (NP_IN_CHUNK seconded/NN)
# (NP_IN_CHUNK chair/NN)
# (NP_IN_CHUNK objection/NN)
# (NP_IN_CHUNK so/CS)
# (NP_IN_CHUNK clerk/NN sachi/NN hamai/NN)
# (NP_IN_CHUNK items/NNS 8/CD)
# (NP_IN_CHUNK 66/CD)
# (NP_IN_CHUNK item/NN number/NN 8/CD)
# (NP_IN_CHUNK as/CS)
# (NP_IN_CHUNK agenda/NN)
# (NP_IN_CHUNK chief/JJS executive/NN officer/NN requests/NNS)
# (NP_IN_CHUNK this/DT item/NN)
# (NP_IN_CHUNK his/PP$ office/NN)
# (NP_IN_CHUNK knabe/NN)
# (NP_IN_CHUNK chair/NN)
# (NP_IN_CHUNK remainder/NN)
# (NP_IN_CHUNK before/CS us/PPO)
# (NP_IN_CHUNK clerk/NN sachi/NN hamai/NN)
# (NP_IN_CHUNK item/NN 8/CD)
# (NP_IN_CHUNK knabe/NN)
# (NP_IN_CHUNK chair/NN)
# (NP_IN_CHUNK so/CS)
# (NP_IN_CHUNK clerk/NN sachi/NN hamai/NN)
# (NP_IN_CHUNK item/NN 10/CD)
# (NP_IN_CHUNK supervisor/NN antonovich/NN requests/NNS)
# (NP_IN_CHUNK this/DT item/NN)
# (NP_IN_CHUNK item/NN number/NN 12/CD)
# (NP_IN_CHUNK supervisor/NN knabe/NN requests/NNS)
# (NP_IN_CHUNK this/DT item/NN)
# (NP_IN_CHUNK item/NN number/NN 13/CD)
# (NP_IN_CHUNK chief/JJS executive/NN officer/NN requests/NNS)
# (NP_IN_CHUNK this/DT item/NN)
# (NP_IN_CHUNK january/NN)
# (NP_IN_CHUNK 2009/NN)
# (NP_IN_CHUNK knabe/NN)
# (NP_IN_CHUNK chair/NN)
# (NP_IN_CHUNK so/CS)
# (NP_IN_CHUNK clerk/NN sachi/NN hamai/NN)
# (NP_IN_CHUNK item/NN number/NN 20/CD)
# (NP_IN_CHUNK supervisor/NN knabe/NN requests/NNS)
# (NP_IN_CHUNK this/DT item/NN)
# (NP_IN_CHUNK item/NN number/NN 23/CD)
# (NP_IN_CHUNK supervisor/NN knabe/NN and/CC)
# (NP_IN_CHUNK member/NN)
# (NP_IN_CHUNK public/JJ request/NN that/CS this/DT item/NN)
# (NP_IN_CHUNK 23/CD)
# (NP_IN_CHUNK item/NN number/NN 28/CD)
# (NP_IN_CHUNK 's/NN)
# (NP_IN_CHUNK request/NN)
# (NP_IN_CHUNK member/NN)
# (NP_IN_CHUNK public/JJ)
# (NP_IN_CHUNK this/DT item/NN)
# (NP_IN_CHUNK 28/CD-HL)
# (NP_IN_CHUNK item/NN number/NN 33/CD)
# (NP_IN_CHUNK 's/NN)
# (NP_IN_CHUNK request/NN)
# (NP_IN_CHUNK member/NN)
# (NP_IN_CHUNK public/JJ)
# (NP_IN_CHUNK this/DT item/NN)
# (NP_IN_CHUNK item/NN number/NN 36/CD)
# (NP_IN_CHUNK 's/NN)
# (NP_IN_CHUNK request/NN)
# (NP_IN_CHUNK member/NN)
# (NP_IN_CHUNK public/JJ)
# (NP_IN_CHUNK this/DT item/NN)
# (NP_IN_CHUNK item/NN number/NN 47/CD)
# (NP_IN_CHUNK 's/NN)
# (NP_IN_CHUNK request/NN)
# (NP_IN_CHUNK member/NN)
# (NP_IN_CHUNK public/JJ)
# (NP_IN_CHUNK this/DT item/NN)
# (NP_IN_CHUNK item/NN 51/CD)
# (NP_IN_CHUNK 's/NN)
# (NP_IN_CHUNK request/NN)
# (NP_IN_CHUNK member/NN)
# (NP_IN_CHUNK public/JJ)
# (NP_IN_CHUNK this/DT item/NN)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK item/NN number/NN 60/CD)
# (NP_IN_CHUNK interim/NN director/NN)
# (NP_IN_CHUNK health/NN services/NNS requests/NNS)
# (NP_IN_CHUNK corrective/NN action/NN plan/NN)
# (NP_IN_CHUNK january/NN)
# (NP_IN_CHUNK 2009/NN)
# (NP_IN_CHUNK but/CC)
# (NP_IN_CHUNK settlement/NN)
# (NP_IN_CHUNK today/NR)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK items/NNS)
# (NP_IN_CHUNK before/CS you/PPSS)
# (NP_IN_CHUNK knabe/NN)
# (NP_IN_CHUNK chair/NN)
# (NP_IN_CHUNK items/NNS)
# (NP_IN_CHUNK supervisor/NN ridley-thomas/NN)
# (NP_IN_CHUNK seconded/NN)
# (NP_IN_CHUNK supervisor/NN yaroslavsky/NN)
# (NP_IN_CHUNK objection/NN)
# (NP_IN_CHUNK so/CS)
# (NP_IN_CHUNK those/DTS)
# (NP_IN_CHUNK and/CC continuances/NN)
# (NP_IN_CHUNK clerk/NN sachi/NN hamai/NN)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK page/NN 32/CD)
# (NP_IN_CHUNK ordinance/NN)
# (NP_IN_CHUNK introduction/NN)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK item/NN number/NN 67/CD)
# (NP_IN_CHUNK as/CS)
# (NP_IN_CHUNK agenda/NN)
# (NP_IN_CHUNK chief/JJS executive/NN officer/NN requests/NNS)
# (NP_IN_CHUNK this/DT item/NN)
# (NP_IN_CHUNK his/PP$ office/NN)
# (NP_IN_CHUNK knabe/NN)
# (NP_IN_CHUNK chair/NN)
# (NP_IN_CHUNK so/CS)
# (NP_IN_CHUNK clerk/NN sachi/NN hamai/NN)
# (NP_IN_CHUNK discussion/NN items/NNS)
# (NP_IN_CHUNK items/NNS 67/CD)
# (NP_IN_CHUNK 73/CD)
# (NP_IN_CHUNK item/NN 68/CD we/PPSS)
# (NP_IN_CHUNK discussion/NN)
# (NP_IN_CHUNK item/NN 69/CD)
# (NP_IN_CHUNK as/CS)
# (NP_IN_CHUNK supplemental/JJ agenda/NN)
# (NP_IN_CHUNK this/DT recommendation/NN)
# (NP_IN_CHUNK and/CC we/PPSS)
# (NP_IN_CHUNK this/DT)
# (NP_IN_CHUNK discussion/NN)
# (NP_IN_CHUNK item/NN 70/CD we/PPSS)
# (NP_IN_CHUNK discussion/NN)
# (NP_IN_CHUNK public/JJ hearings/NNS)
# (NP_IN_CHUNK item/NN 71/CD we/PPSS)
# (NP_IN_CHUNK public/JJ hearing/NN)
# (NP_IN_CHUNK item/NN 72/CD)
# (NP_IN_CHUNK as/CS)
# (NP_IN_CHUNK supplemental/JJ agenda/NN)
# (NP_IN_CHUNK supervisor/NN ridley-thomas/NN requests/NNS)
# (NP_IN_CHUNK this/DT item/NN)
# (NP_IN_CHUNK discussion/NN)
# (NP_IN_CHUNK january/NN)
# (NP_IN_CHUNK 2009/NN)
# (NP_IN_CHUNK knabe/NN)
# (NP_IN_CHUNK chair/NN)
# (NP_IN_CHUNK so/CS)
# (NP_IN_CHUNK clerk/NN sachi/NN hamai/NN)
# (NP_IN_CHUNK item/NN 73/CD)
# (NP_IN_CHUNK as/CS)
# (NP_IN_CHUNK supplemental/JJ agenda/NN)
# (NP_IN_CHUNK supervisor/NN ridley-thomas/NN requests/NNS)
# (NP_IN_CHUNK this/DT item/NN)
# (NP_IN_CHUNK discussion/NN)
# (NP_IN_CHUNK february/NN)
# (NP_IN_CHUNK 2009/NN)
# (NP_IN_CHUNK knabe/NN)
# (NP_IN_CHUNK chair/NN)
# (NP_IN_CHUNK so/CS)
# (NP_IN_CHUNK clerk/NN sachi/NN hamai/NN)
# (NP_IN_CHUNK page/NN 35/CD)
# (NP_IN_CHUNK miscellaneous/JJ additions/NNS)
# (NP_IN_CHUNK agenda/NN)
# (NP_IN_CHUNK than/CS 72/CD hours/NNS)
# (NP_IN_CHUNK advance/NN)
# (NP_IN_CHUNK meeting/NN as/CS)
# (NP_IN_CHUNK supplemental/JJ agenda/NN)
# (NP_IN_CHUNK 74-a/NN)
# (NP_IN_CHUNK request/NN)
# (NP_IN_CHUNK member/NN)
# (NP_IN_CHUNK public/JJ)
# (NP_IN_CHUNK this/DT item/NN)
# (NP_IN_CHUNK 74-b/NN)
# (NP_IN_CHUNK government/NN code/NN section/NN 54957/NN)
# (NP_IN_CHUNK chief/JJS executive/NN officer/NN requests/NNS)
# (NP_IN_CHUNK this/DT)
# (NP_IN_CHUNK session/NN)
# (NP_IN_CHUNK knabe/NN)
# (NP_IN_CHUNK chair/NN)
# (NP_IN_CHUNK so/CS)
# (NP_IN_CHUNK clerk/NN sachi/NN hamai/NN)
# (NP_IN_CHUNK that/CS)
# (NP_IN_CHUNK reading/NN)
# (NP_IN_CHUNK agenda/NN)
# (NP_IN_CHUNK supervisorial/NN items/NNS)
# (NP_IN_CHUNK supervisorial/NN district/NN number/NN 1/CD)
# (NP_IN_CHUNK knabe/NN)
# (NP_IN_CHUNK chair/NN)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK number/NN)
# (NP_IN_CHUNK special/JJ presentations/NNS)
# (NP_IN_CHUNK i/NN)
# (NP_IN_CHUNK supervisor/NN antonovich/NN and/CC)
# (NP_IN_CHUNK supervisor/NN ridley-thomas/NN)
# (NP_IN_CHUNK antonovich/NN)
# (NP_IN_CHUNK it/PPS 's/NN)
# (NP_IN_CHUNK real/JJ great/JJ pleasure/NN)
# (NP_IN_CHUNK one/CD)
# (NP_IN_CHUNK great/JJ role/NN models/NNS)
# (NP_IN_CHUNK michael/NN scioscia/NN)
# (NP_IN_CHUNK manager/NN)
# (NP_IN_CHUNK los/NN angeles/NN angels/NNS)
# (NP_IN_CHUNK anaheim/NN)
# (NP_IN_CHUNK california/NN angels/NNS)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK los/NN angeles/NN angels/NNS)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK los/NN angeles/NN angels/NNS)
# (NP_IN_CHUNK anaheim/NN)
# (NP_IN_CHUNK and/CC they/PPSS)
# (NP_IN_CHUNK los/NN angeles/NN dodgers/NN)
# (NP_IN_CHUNK chinatown/NN)
# (NP_IN_CHUNK time/NN)
# (NP_IN_CHUNK time/NN)
# (NP_IN_CHUNK laughter/NN)
# (NP_IN_CHUNK recognition/NN)
# (NP_IN_CHUNK
#   their/PP$
#   hard/JJ
#   work/NN
#   and/CC
#   leadership/NN
#   and/CC
#   dedication/NN)
# (NP_IN_CHUNK angels/NNS)
# (NP_IN_CHUNK anaheim/NN)
# (NP_IN_CHUNK
#   2008/NN
#   american/NN
#   league/NN
#   western/JJ
#   division/NN
#   championship/NN)
# (NP_IN_CHUNK consecutive/JJ year/NN and/CC posting/NN)
# (NP_IN_CHUNK 100/CD wins/NNS)
# (NP_IN_CHUNK system/NN)
# (NP_IN_CHUNK time/NN)
# (NP_IN_CHUNK their/PP$ franchise/NN history/NN)
# (NP_IN_CHUNK 2008/NN angels/NNS)
# (NP_IN_CHUNK it/PPS)
# (NP_IN_CHUNK 48th/NN season/NN)
# (NP_IN_CHUNK franchise/NN)
# (NP_IN_CHUNK regular/JJ season/NN)
# (NP_IN_CHUNK angels/NNS)
# (NP_IN_CHUNK their/PP$)
# (NP_IN_CHUNK american/NN west/NR division/NN title/NN and/CC)
# (NP_IN_CHUNK franchise/NN record/NN)
# (NP_IN_CHUNK season/NN)
# (NP_IN_CHUNK mike/NN scioscia/NN)
# (NP_IN_CHUNK catcher/NN)
# (NP_IN_CHUNK los/NN angeles/NN dodgers/NN)
# (NP_IN_CHUNK his/PP$)
# (NP_IN_CHUNK season/NN as/CS manager/NN)
# (NP_IN_CHUNK angels/NNS)
# (NP_IN_CHUNK he/PPS)
# (NP_IN_CHUNK 803/NN)
# (NP_IN_CHUNK 655/NN win-loss/NN record/NN)
# (NP_IN_CHUNK 551/NN)
# (NP_IN_CHUNK percentage/NN)
# (NP_IN_CHUNK angels/NNS)
# (NP_IN_CHUNK he/PPS)
# (NP_IN_CHUNK 800/CD)
# (NP_IN_CHUNK plateau/NN)
# (NP_IN_CHUNK september/NN)
# (NP_IN_CHUNK 2-1/NN victory/NN)
# (NP_IN_CHUNK seattle/NN)
# (NP_IN_CHUNK michael/NN)
# (NP_IN_CHUNK longest-tenured/NN manager/NN)
# (NP_IN_CHUNK american/NN league/NN baseball/NN)
# (NP_IN_CHUNK he/PPS 's/NN)
# (NP_IN_CHUNK manager/NN)
# (NP_IN_CHUNK angel/NN history/NN)
# (NP_IN_CHUNK and/CC he/PPS 's/NN)
# (NP_IN_CHUNK angels/NNS)
# (NP_IN_CHUNK post/NN season/NN)
# (NP_IN_CHUNK four/CD)
# (NP_IN_CHUNK five/CD seasons/NNS)
# (NP_IN_CHUNK he/PPS 's/NN)
# (NP_IN_CHUNK angels/NNS manager/NN)
# (NP_IN_CHUNK
#   american/NN
#   league/NN
#   's/NN
#   western/JJ
#   division/NN
#   championship/NN)
# (NP_IN_CHUNK surpassing/NN gene/NN mock/JJ)
# (NP_IN_CHUNK and/CC he/PPS 's/NN)
# (NP_IN_CHUNK angels/NNS)
# (NP_IN_CHUNK five/CD straight/JJ)
# (NP_IN_CHUNK seasons/NNS)
# (NP_IN_CHUNK 2004/NN)
# (NP_IN_CHUNK 2008/NN)
# (NP_IN_CHUNK his/PP$ leadership/NN)
# (NP_IN_CHUNK they/PPSS)
# (NP_IN_CHUNK 90/CD or/CC)
# (NP_IN_CHUNK five/CD)
# (NP_IN_CHUNK seven/CD seasons/NNS)
# (NP_IN_CHUNK numerous/JJ community/NN events/NNS)
# (NP_IN_CHUNK he/PPS 's/NN co/NN chair/NN)
# (NP_IN_CHUNK
#   angels/NNS
#   care/NN
#   65/CD
#   roses/NNS
#   golf/NN
#   tournament/NN)
# (NP_IN_CHUNK chairman/NN)
# (NP_IN_CHUNK heart/NN association/NN heart/NN and/CC soul/NN walk/NN)
# (NP_IN_CHUNK local/JJ little/JJ leagues/NNS)
# (NP_IN_CHUNK
#   mike/NN
#   scioscia/NN
#   youth/NN
#   baseball/NN
#   clinic/NN
#   make-a-wish/NN
#   foundation/NN)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK his/PP$ leadership/NN)
# (NP_IN_CHUNK monrovia/NN boys/NNS and/CC girls/NNS club/NN raise/NN)
# (NP_IN_CHUNK 75/CD percent/NN)
# (NP_IN_CHUNK their/PP$ budget/NN each/DT january/february/NN)
# (NP_IN_CHUNK
#   they/PPSS
#   do/DO
#   their/PP$
#   annual/JJ
#   dinner/NN
#   and/CC
#   mike/NN
#   does/DOZ)
# (NP_IN_CHUNK phenomenal/JJ job/NN as/CS)
# (NP_IN_CHUNK auctioneer/NN)
# (NP_IN_CHUNK and/CC they/PPSS)
# (NP_IN_CHUNK that/CS amount/NN)
# (NP_IN_CHUNK money/NN)
# (NP_IN_CHUNK entire/JJ year/NN)
# (NP_IN_CHUNK it/PPS)
# (NP_IN_CHUNK young/JJ boys/NNS and/CC girls/NNS)
# (NP_IN_CHUNK san/NN gabriel/NN valley/NN)
# (NP_IN_CHUNK monrovia/NN)
# (NP_IN_CHUNK he/PPS)
# (NP_IN_CHUNK italian/NN american/NN hall/NN)
# (NP_IN_CHUNK fame/NN)
# (NP_IN_CHUNK
#   2007/NN
#   and/CC
#   major/JJ
#   league/NN
#   baseball/NN
#   's/NN
#   arizona/NN)
# (NP_IN_CHUNK league/NN)
# (NP_IN_CHUNK fame/NN)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK los/NN angeles/NN angels/NNS)
# (NP_IN_CHUNK
#   los/NN
#   angeles/NN
#   county/NN
#   's/NN
#   boys/NNS
#   and/CC
#   girls/NNS)
# (NP_IN_CHUNK
#   their/PP$
#   annual/JJ
#   children/NNS
#   's/NN
#   holiday/NN
#   celebration/NN)
# (NP_IN_CHUNK place/NN today/NR)
# (NP_IN_CHUNK this/DT afternoon/NN)
# (NP_IN_CHUNK angels/NNS stadium/NN)
# (NP_IN_CHUNK tony/NN riggins/NN)
# (NP_IN_CHUNK general/JJ manager/NN)
# (NP_IN_CHUNK and/CC michael/NN)
# (NP_IN_CHUNK children/NNS)
# (NP_IN_CHUNK children/NNS)
# (NP_IN_CHUNK opportunity/NN)
# (NP_IN_CHUNK holiday/NN songs/NNS and/CC)
# (NP_IN_CHUNK angel/NN christmas/NN tree/NN ornaments/NNS)
# (NP_IN_CHUNK they/PPSS 're/NN)
# (NP_IN_CHUNK traditional/JJ baseball/NN meal/NN and/CC)
# (NP_IN_CHUNK their/PP$ own/JJ christmas/NN gift/NN)
# (NP_IN_CHUNK this/DT summer/NN)
# (NP_IN_CHUNK as/CS part/NN)
# (NP_IN_CHUNK
#   national/JJ
#   summer/NN
#   mental/JJ
#   health/NN
#   awareness/NN
#   program/NN)
# (NP_IN_CHUNK i/NN)
# (NP_IN_CHUNK angels/NNS)
# (NP_IN_CHUNK general/JJ manager/NN tony/NN riggins/NN and/CC)
# (NP_IN_CHUNK hand/NN pitcher/NN darren/NN oliver/NN)
# (NP_IN_CHUNK hosting/NN)
# (NP_IN_CHUNK prevention/NN and/CC early/JJ intervention/NN event/NN)
# (NP_IN_CHUNK children/NNS)
# (NP_IN_CHUNK proper/JJ foods/NNS)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK
#   positive/JJ
#   mental/JJ
#   health/NN
#   and/CC
#   wellness/NN
#   attitude/NN)
# (NP_IN_CHUNK than/CS 200/CD students/NNS)
# (NP_IN_CHUNK frank/JJ telamo/NN elementary/JJ school/NN)
# (NP_IN_CHUNK los/NN angeles/NN)
# (NP_IN_CHUNK korea/NN town/NN)
# (NP_IN_CHUNK nine/CD different/JJ languages/NNS)
# (NP_IN_CHUNK campus/NN)
# (NP_IN_CHUNK this/DT)
# (NP_IN_CHUNK exciting/JJ event/NN)
# (NP_IN_CHUNK michael/NN)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK as/CS manager/NN)
# (NP_IN_CHUNK year/NN)
# (NP_IN_CHUNK this/DT plaque/NN)
# (NP_IN_CHUNK county/NN)
# (NP_IN_CHUNK los/NN angeles/NN)
# (NP_IN_CHUNK and/CC we/PPSS)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK successful/JJ seasons/NNS)
# (NP_IN_CHUNK and/CC i/NN)
# (NP_IN_CHUNK opportunity/NN)
# (NP_IN_CHUNK they/PPSS)
# (NP_IN_CHUNK world/NN series/NN)
# (NP_IN_CHUNK couple/NN years/NNS)
# (NP_IN_CHUNK and/CC that/CS)
# (NP_IN_CHUNK great/JJ feeling/NN)
# (NP_IN_CHUNK little/JJ different/JJ than/CS)
# (NP_IN_CHUNK i/NN)
# (NP_IN_CHUNK little/JJ boy/NN)
# (NP_IN_CHUNK wrigley/NN field/NN)
# (NP_IN_CHUNK los/NN angeles/NN angels/NNS)
# (NP_IN_CHUNK bill/NN kelly/NN)
# (NP_IN_CHUNK manager/NN)
# (NP_IN_CHUNK congratulations/NNS and/CC god/NN)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK applause/NN)
# (NP_IN_CHUNK and/CC this/DT)
# (NP_IN_CHUNK los/NN angeles/NN angels/NNS)
# (NP_IN_CHUNK western/JJ division/NN championship/NN)
# (NP_IN_CHUNK good/JJ champions/NNS)
# (NP_IN_CHUNK applause/NN)
# (NP_IN_CHUNK mike/NN scioscia/NN)
# (NP_IN_CHUNK supervisor/NN antonovich/NN and/CC)
# (NP_IN_CHUNK board/NN)
# (NP_IN_CHUNK supervisors/NNS)
# (NP_IN_CHUNK i/NN)
# (NP_IN_CHUNK you/PPO ver/NN)
# (NP_IN_CHUNK this/DT presentation/NN)
# (NP_IN_CHUNK this/DT honor/NN)
# (NP_IN_CHUNK amount/NN)
# (NP_IN_CHUNK support/NN we/PPSS)
# (NP_IN_CHUNK southern/JJ california/NN)
# (NP_IN_CHUNK incredible/JJ)
# (NP_IN_CHUNK 3.5/CD million/CD fans/NNS)
# (NP_IN_CHUNK us/PPO)
# (NP_IN_CHUNK angels/NNS)
# (NP_IN_CHUNK stadium/NN)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK great/JJ regular/JJ season/NN)
# (NP_IN_CHUNK and/CC as/CS we/PPSS)
# (NP_IN_CHUNK this/DT)
# (NP_IN_CHUNK season/NN)
# (NP_IN_CHUNK 2009/NN)
# (NP_IN_CHUNK supervisor/NN)
# (NP_IN_CHUNK we/PPSS 're/NN)
# (NP_IN_CHUNK do/DO)
# (NP_IN_CHUNK little/JJ better/JJR)
# (NP_IN_CHUNK playoffs/NN)
# (NP_IN_CHUNK i/NN)
# (NP_IN_CHUNK as/CS)
# (NP_IN_CHUNK as/CS you/PPSS)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK and/CC it/PPS 's/NN)
# (NP_IN_CHUNK great/JJ regular/JJ season/NN we/PPSS)
# (NP_IN_CHUNK i/NN)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK this/DT plaque/NN and/CC this/DT ceremony/NN)
# (NP_IN_CHUNK but/CC we/PPSS)
# (NP_IN_CHUNK do/DO)
# (NP_IN_CHUNK playoffs/NN)
# (NP_IN_CHUNK supervisor/NN)
# (NP_IN_CHUNK i/NN promise/NN you/PPSS)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK god/NN)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK applause/NN)
# (NP_IN_CHUNK knabe/NN)
# (NP_IN_CHUNK chair/NN)
# (NP_IN_CHUNK right/JJ)
# (NP_IN_CHUNK mark/NN)
# (NP_IN_CHUNK i/NN)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK special/JJ presentation/NN)
# (NP_IN_CHUNK us/PPO)
# (NP_IN_CHUNK as/CS)
# (NP_IN_CHUNK ridley-thomas/NN)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK mr./NN chairman/NN)
# (NP_IN_CHUNK members/NNS)
# (NP_IN_CHUNK i/NN 'm/NN)
# (NP_IN_CHUNK that/CS we/PPSS)
# (NP_IN_CHUNK
#   los/NN
#   angeles/NN
#   county/NN
#   arts/NNS
#   commission/NN
#   director/NN)
# (NP_IN_CHUNK you/PPSS)
# (NP_IN_CHUNK her/PPO as/CS laura/NN zucker/NN)
# (NP_IN_CHUNK and/CC those/DTS)
# (NP_IN_CHUNK children/NNS 's/NN chorus/NN)
# (NP_IN_CHUNK directors/NNS)
# (NP_IN_CHUNK willie/NN norwood/NN)
# (NP_IN_CHUNK sr./NN and/CC ravaline/NN harold/NN)
# (NP_IN_CHUNK and/CC members/NNS)
# (NP_IN_CHUNK that/DT chorus/NN you/PPSS)
# (NP_IN_CHUNK i/NN 'd/NN like/CS)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK that/CS)
# (NP_IN_CHUNK u.c.c/NN)
# (NP_IN_CHUNK summer/NN)
# (NP_IN_CHUNK 1993/NN)
# (NP_IN_CHUNK as/CS)
# (NP_IN_CHUNK crusade/NN)
# (NP_IN_CHUNK christ/NN campaign/NN)
# (NP_IN_CHUNK county/NN)
# (NP_IN_CHUNK los/NN angeles/NN)
# (NP_IN_CHUNK young/JJ men/NNS and/CC women/NNS)
# (NP_IN_CHUNK various/JJ churches/NNS)
# (NP_IN_CHUNK christ/NN)
# (NP_IN_CHUNK los/NN angeles/NN and/CC)
# (NP_IN_CHUNK counties/NNS)
# (NP_IN_CHUNK as/CS this/DT tremendous/JJ event/NN)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK such/JJ rave/NN reviews/NNS)
# (NP_IN_CHUNK that/CS event/NN)
# (NP_IN_CHUNK it/PPS)
# (NP_IN_CHUNK that/CS)
# (NP_IN_CHUNK group/NN)
# (NP_IN_CHUNK you/PPSS)
# (NP_IN_CHUNK that/CS this/DT group/NN)
# (NP_IN_CHUNK ages/NNS 3/CD)
# (NP_IN_CHUNK those/DTS)
# (NP_IN_CHUNK their/PP$ late/JJ 20s/NN)
# (NP_IN_CHUNK audiences/NNS)
# (NP_IN_CHUNK their/PP$ extraordinary/JJ gifts/NNS)
# (NP_IN_CHUNK us/PPO)
# (NP_IN_CHUNK that/DT)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK as/CS)
# (NP_IN_CHUNK capello/NN singing/NN)
# (NP_IN_CHUNK chorus/NN director/NN)
# (NP_IN_CHUNK willie/NN norwood/NN sr./NN)
# (NP_IN_CHUNK u.c.c/NN)
# (NP_IN_CHUNK for/CS)
# (NP_IN_CHUNK 14/CD years/NNS)
# (NP_IN_CHUNK he/PPS)
# (NP_IN_CHUNK minister/NN)
# (NP_IN_CHUNK music/NN)
# (NP_IN_CHUNK woodland/NN hills/NNS church/NN)
# (NP_IN_CHUNK christ/NN and/CC)
# (NP_IN_CHUNK father/NN)
# (NP_IN_CHUNK
#   singer/NN
#   actress/NN
#   brandy/NN
#   norwood/NN
#   and/CC
#   singer/NN
#   actor/NN
#   willie/NN)
# (NP_IN_CHUNK ray/NN jay/NN)
# (NP_IN_CHUNK norwood/NN)
# (NP_IN_CHUNK chorus/NN)
# (NP_IN_CHUNK he/PPS 's/NN)
# (NP_IN_CHUNK talented/JJ)
# (NP_IN_CHUNK as/CS you/PPSS)
# (NP_IN_CHUNK and/CC those/DTS)
# (NP_IN_CHUNK part/NN)
# (NP_IN_CHUNK his/PP$ family/NN)
# (NP_IN_CHUNK six-year-old/NN granddaughter/NN)
# (NP_IN_CHUNK chorus/NN)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK them/PPO)
# (NP_IN_CHUNK us/PPO today/NR)
# (NP_IN_CHUNK mr./NN chairman/NN and/CC colleagues/NNS)
# (NP_IN_CHUNK you/PPSS 'll/NN)
# (NP_IN_CHUNK figueroa/NN church/NN)
# (NP_IN_CHUNK christ/NN)
# (NP_IN_CHUNK that/DT)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK as/CS)
# (NP_IN_CHUNK little/JJ angels/NNS)
# (NP_IN_CHUNK chorus/NN)
# (NP_IN_CHUNK one/CD)
# (NP_IN_CHUNK late/JJ '60s/NNS)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK great/JJ things/NNS)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK me/PPO)
# (NP_IN_CHUNK that/CS we/PPSS)
# (NP_IN_CHUNK them/PPO)
# (NP_IN_CHUNK us/PPO this/DT morning/NN)
# (NP_IN_CHUNK you/PPSS)
# (NP_IN_CHUNK that/CS they/PPSS)
# (NP_IN_CHUNK holiday/NN celebration/NN national/JJ show/NN)
# (NP_IN_CHUNK december/NN)
# (NP_IN_CHUNK and/CC december/NN)
# (NP_IN_CHUNK 10/CD)
# (NP_IN_CHUNK p.b.s/NN)
# (NP_IN_CHUNK nationwide/JJ)
# (NP_IN_CHUNK sure/JJ that/CS you/PPSS do/DO n't/NN)
# (NP_IN_CHUNK it/PPO)
# (NP_IN_CHUNK addition/NN)
# (NP_IN_CHUNK they/PPSS)
# (NP_IN_CHUNK annual/JJ holiday/NN celebration/NN)
# (NP_IN_CHUNK dorothy/NN chandler/NN pavilion/NN)
# (NP_IN_CHUNK december/NN)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK i/NN)
# (NP_IN_CHUNK this/DT opportunity/NN)
# (NP_IN_CHUNK present/JJ this/DT presentation/NN)
# (NP_IN_CHUNK you/PPO and/CC)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK your/PP$ contributions/NNS)
# (NP_IN_CHUNK and/CC we/PPSS)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK me/PPO)
# (NP_IN_CHUNK and/CC congratulating/NN)
# (NP_IN_CHUNK children/NNS 's/NN chorus/NN)
# (NP_IN_CHUNK applause/NN)
# (NP_IN_CHUNK we/PPSS 'll/NN)
# (NP_IN_CHUNK ravaline/NN and/CC)
# (NP_IN_CHUNK we/PPSS 'll/NN)
# (NP_IN_CHUNK chorus/NN)
# (NP_IN_CHUNK ravaline/NN harold/NN)
# (NP_IN_CHUNK honorable/JJ mark/NN ridley-thomas/NN)
# (NP_IN_CHUNK our/PP$ supervisor/NN)
# (NP_IN_CHUNK district/NN)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK supervisors/NNS)
# (NP_IN_CHUNK this/DT great/JJ city/NN)
# (NP_IN_CHUNK los/NN angeles/NN)
# (NP_IN_CHUNK
#   laura/NN
#   zucker/NN
#   and/CC
#   adam/NN
#   davis/NN
#   and/CC
#   heather/NN
#   rigby/NN)
# (NP_IN_CHUNK los/NN angeles/NN county/NN arts/NNS commission/NN)
# (NP_IN_CHUNK your/PP$ recommendation/NN)
# (NP_IN_CHUNK children/NNS 's/NN chorus/NN)
# (NP_IN_CHUNK this/DT great/JJ honor/NN)
# (NP_IN_CHUNK mr./NN norwood/NN and/CC i/NN and/CC)
# (NP_IN_CHUNK
#   children/NNS
#   's/NN
#   chorus/NN
#   and/CC
#   their/PP$
#   parents/NNS)
# (NP_IN_CHUNK privileged/JJ today/NR)
# (NP_IN_CHUNK this/DT role/NN)
# (NP_IN_CHUNK our/PP$ achievements/NNS)
# (NP_IN_CHUNK 13/CD years/NNS)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK happy/JJ)
# (NP_IN_CHUNK this/DT year/NN)
# (NP_IN_CHUNK annual/JJ holiday/NN celebration/NN)
# (NP_IN_CHUNK me/PPO)
# (NP_IN_CHUNK significant/JJ)
# (NP_IN_CHUNK early/JJ '60s/NNS)
# (NP_IN_CHUNK i/NN)
# (NP_IN_CHUNK i/NN)
# (NP_IN_CHUNK 12/CD years/NNS old/JJ)
# (NP_IN_CHUNK supervisor/NN kenneth/NN hahn/NN)
# (NP_IN_CHUNK 49/CD years/NNS)
# (NP_IN_CHUNK i/NN 'm/NN)
# (NP_IN_CHUNK as/CS)
# (NP_IN_CHUNK this/DT magnificent/JJ group/NN)
# (NP_IN_CHUNK young/JJ people/NNS)
# (NP_IN_CHUNK ages/NNS 4/CD)
# (NP_IN_CHUNK 20/CD as/CS)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK one-hour/NN celebration/NN tomorrow/NR night/NN)
# (NP_IN_CHUNK for/CS)
# (NP_IN_CHUNK year/NN they/PPSS)
# (NP_IN_CHUNK highlights/NNS)
# (NP_IN_CHUNK version/NN)
# (NP_IN_CHUNK 2007/NN show/NN)
# (NP_IN_CHUNK and/CC it/PPS)
# (NP_IN_CHUNK air/NN)
# (NP_IN_CHUNK time/NN tomorrow/NR night/NN)
# (NP_IN_CHUNK december/NN)
# (NP_IN_CHUNK 10/CD)
# (NP_IN_CHUNK k.c.e.t/NN)
# (NP_IN_CHUNK stations/NNS)
# (NP_IN_CHUNK country/NN and/CC)
# (NP_IN_CHUNK christmas/NN eve/NN)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK as/CS supervisor/NN ridley-thomas/NN)
# (NP_IN_CHUNK it/PPS 's/NN free/JJ)
# (NP_IN_CHUNK it/PPS 's/NN free/JJ)
# (NP_IN_CHUNK your/PP$ friends/NNS)
# (NP_IN_CHUNK and/CC we/PPSS)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK mr./NN norwood/NN)
# (NP_IN_CHUNK u.c.c./NN)
# (NP_IN_CHUNK parents/NNS and/CC i/NN)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK this/DT wonderful/JJ honor/NN)
# (NP_IN_CHUNK and/CC we/PPSS)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK our/PP$ community/NN)
# (NP_IN_CHUNK years/NNS)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK applause/NN)
# (NP_IN_CHUNK i/NN)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK and/CC we/PPSS)
# (NP_IN_CHUNK song/NN we/PPSS 'll/NN)
# (NP_IN_CHUNK national/JJ show/NN tomorrow/NR night/NN)
# (NP_IN_CHUNK jesus/NN)
# (NP_IN_CHUNK wonderful/JJ child/NN)
# (NP_IN_CHUNK u.c.c/NN)
# (NP_IN_CHUNK choir/NN)
# (NP_IN_CHUNK jesus/NN)
# (NP_IN_CHUNK wonderful/JJ child/NN)
# (NP_IN_CHUNK jesus/NN)
# (NP_IN_CHUNK jesus/NN)
# (NP_IN_CHUNK so/CS lowly/NN)
# (NP_IN_CHUNK meek/JJ and/CC mild/JJ new/JJ life/NN)
# (NP_IN_CHUNK new/JJ hope/NN)
# (NP_IN_CHUNK new/JJ joy/NN he/PPS)
# (NP_IN_CHUNK wo/NN n't/NN you/PPSS)
# (NP_IN_CHUNK angels/NNS)
# (NP_IN_CHUNK glory/NN)
# (NP_IN_CHUNK glory/NN)
# (NP_IN_CHUNK glory/NN)
# (NP_IN_CHUNK newborn/JJ king/NN)
# (NP_IN_CHUNK jesus/NN)
# (NP_IN_CHUNK jesus/NN)
# (NP_IN_CHUNK jesus/NN)
# (NP_IN_CHUNK wonderful/JJ child/NN)
# (NP_IN_CHUNK jesus/NN)
# (NP_IN_CHUNK jesus/NN)
# (NP_IN_CHUNK jesus/NN)
# (NP_IN_CHUNK so/CS lowly/NN)
# (NP_IN_CHUNK meek/JJ and/CC mild/JJ)
# (NP_IN_CHUNK new/JJ life/NN)
# (NP_IN_CHUNK new/JJ hope/NN)
# (NP_IN_CHUNK new/JJ joy/NN he/PPS)
# (NP_IN_CHUNK wo/NN n't/NN you/PPSS)
# (NP_IN_CHUNK angels/NNS)
# (NP_IN_CHUNK glory/NN)
# (NP_IN_CHUNK glory/NN)
# (NP_IN_CHUNK glory/NN)
# (NP_IN_CHUNK newborn/JJ king/NN)
# (NP_IN_CHUNK he/PPS)
# (NP_IN_CHUNK angels/NNS)
# (NP_IN_CHUNK lowly/NN manger/NN)
# (NP_IN_CHUNK virgin/NN mary/NN)
# (NP_IN_CHUNK his/PP$ mother/NN)
# (NP_IN_CHUNK and/CC joseph/NN)
# (NP_IN_CHUNK his/PP$ earthly/JJ father/NN)
# (NP_IN_CHUNK three/CD wise/JJ men/NNS)
# (NP_IN_CHUNK they/PPSS)
# (NP_IN_CHUNK star/NN)
# (NP_IN_CHUNK king/NN jesus/NN)
# (NP_IN_CHUNK he/PPS)
# (NP_IN_CHUNK manger/NN)
# (NP_IN_CHUNK hay/NN)
# (NP_IN_CHUNK jesus/NN)
# (NP_IN_CHUNK jesus/NN)
# (NP_IN_CHUNK jesus/NN)
# (NP_IN_CHUNK wonderful/JJ child/NN)
# (NP_IN_CHUNK jesus/NN)
# (NP_IN_CHUNK jesus/NN)
# (NP_IN_CHUNK jesus/NN)
# (NP_IN_CHUNK so/CS lowly/NN)
# (NP_IN_CHUNK meek/JJ and/CC mild/JJ new/JJ life/NN)
# (NP_IN_CHUNK new/JJ hope/NN)
# (NP_IN_CHUNK new/JJ joy/NN he/PPS)
# (NP_IN_CHUNK wo/NN n't/NN you/PPSS)
# (NP_IN_CHUNK angels/NNS)
# (NP_IN_CHUNK glory/NN)
# (NP_IN_CHUNK glory/NN)
# (NP_IN_CHUNK glory/NN)
# (NP_IN_CHUNK newborn/JJ king/NN)
# (NP_IN_CHUNK he/PPS)
# (NP_IN_CHUNK angels/NNS)
# (NP_IN_CHUNK he/PPS)
# (NP_IN_CHUNK he/PPS)
# (NP_IN_CHUNK lowly/NN manger/NN)
# (NP_IN_CHUNK virgin/NN mary/NN)
# (NP_IN_CHUNK his/PP$ mother/NN)
# (NP_IN_CHUNK and/CC you/PPSS)
# (NP_IN_CHUNK joseph/NN)
# (NP_IN_CHUNK his/PP$ earthly/JJ father/NN)
# (NP_IN_CHUNK three/CD wise/JJ men/NNS)
# (NP_IN_CHUNK they/PPSS)
# (NP_IN_CHUNK star/NN)
# (NP_IN_CHUNK they/PPSS)
# (NP_IN_CHUNK king/NN jesus/NN)
# (NP_IN_CHUNK he/PPS)
# (NP_IN_CHUNK manger/NN)
# (NP_IN_CHUNK hay/NN)
# (NP_IN_CHUNK jesus/NN)
# (NP_IN_CHUNK jesus/NN)
# (NP_IN_CHUNK jesus/NN)
# (NP_IN_CHUNK wonderful/JJ child/NN)
# (NP_IN_CHUNK jesus/NN)
# (NP_IN_CHUNK jesus/NN)
# (NP_IN_CHUNK jesus/NN)
# (NP_IN_CHUNK so/CS lowly/NN)
# (NP_IN_CHUNK meek/JJ and/CC mild/JJ)
# (NP_IN_CHUNK new/JJ life/NN)
# (NP_IN_CHUNK new/JJ hope/NN)
# (NP_IN_CHUNK wo/NN n't/NN you/PPSS)
# (NP_IN_CHUNK angels/NNS)
# (NP_IN_CHUNK glory/NN)
# (NP_IN_CHUNK glory/NN)
# (NP_IN_CHUNK glory/NN)
# (NP_IN_CHUNK newborn/JJ king/NN)
# (NP_IN_CHUNK jesus/NN)
# (NP_IN_CHUNK glory/NN)
# (NP_IN_CHUNK newborn/JJ king/NN)
# (NP_IN_CHUNK glory/NN)
# (NP_IN_CHUNK glory/NN)
# (NP_IN_CHUNK newborn/JJ heavenly/JJ king/NN)
# (NP_IN_CHUNK peace/NN)
# (NP_IN_CHUNK applause/NN)
# (NP_IN_CHUNK ridley-thomas/NN)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK and/CC we/PPSS)
# (NP_IN_CHUNK you/PPO and/CC we/PPSS)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK p.b.s/NN)
# (NP_IN_CHUNK tomorrow/NR evening/NN)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK warm/JJ invitation/NN)
# (NP_IN_CHUNK those/DTS)
# (NP_IN_CHUNK it/PPO)
# (NP_IN_CHUNK dorothy/NN chandler/NN pavilion/NN)
# (NP_IN_CHUNK mr./NN chairman/NN)
# (NP_IN_CHUNK 's/NN)
# (NP_IN_CHUNK them/PPO another/DT big/JJ round/NN)
# (NP_IN_CHUNK applause/NN)
# (NP_IN_CHUNK applause/NN)
# (NP_IN_CHUNK knabe/NN)
# (NP_IN_CHUNK chair/NN)
# (NP_IN_CHUNK great/JJ way/NN)
# (NP_IN_CHUNK start/NN our/PP$)
# (NP_IN_CHUNK meeting/NN)
# (NP_IN_CHUNK year/NN)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK i/NN 'm/NN)
# (NP_IN_CHUNK dr./NN john/NN schunoff/NN and/CC kathy/NN cheister/NN)
# (NP_IN_CHUNK ph/NN)
# (NP_IN_CHUNK director/NN)
# (NP_IN_CHUNK
#   our/PP$
#   county/NN
#   's/NN
#   emergency/NN
#   medical/JJ
#   services/NNS
#   agency/NN)
# (NP_IN_CHUNK me/PPO)
# (NP_IN_CHUNK representatives/NNS)
# (NP_IN_CHUNK county/NN 's/NN 13/CD trauma/NN centers/NNS)
# (NP_IN_CHUNK it/PPS)
# (NP_IN_CHUNK my/PP$ pleasure/NN)
# (NP_IN_CHUNK my/PP$ colleagues/NNS today/NR)
# (NP_IN_CHUNK and/CC they/PPSS 're/NN)
# (NP_IN_CHUNK various/JJ trauma/NN centers/NNS)
# (NP_IN_CHUNK their/PP$ districts/NNS)
# (NP_IN_CHUNK
#   our/PP$
#   los/NN
#   angeles/NN
#   county/NN
#   trauma/NN
#   system/NN
#   's/NN)
# (NP_IN_CHUNK anniversary/NN)
# (NP_IN_CHUNK hospitals/NNS)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK today/NR)
# (NP_IN_CHUNK county/NN residents/NNS)
# (NP_IN_CHUNK highest/JJT level/NN)
# (NP_IN_CHUNK life-saving/NN surgical/JJ interventions/NN)
# (NP_IN_CHUNK those/DTS)
# (NP_IN_CHUNK major/JJ loss/NN or/CC shock/NN)
# (NP_IN_CHUNK vehicular/JJ crashes/NNS)
# (NP_IN_CHUNK gunshot/NN or/CC knife/NN wounds/NNS)
# (NP_IN_CHUNK or/CC)
# (NP_IN_CHUNK violent/JJ accidents/NNS)
# (NP_IN_CHUNK trauma/NN)
# (NP_IN_CHUNK cause/NN)
# (NP_IN_CHUNK death/NN)
# (NP_IN_CHUNK people/NNS)
# (NP_IN_CHUNK ages/NNS)
# (NP_IN_CHUNK 1/CD and/CC 44/CD)
# (NP_IN_CHUNK 19,000/CD patients/NNS)
# (NP_IN_CHUNK los/NN angeles/NN county/NN trauma/NN centers/NNS)
# (NP_IN_CHUNK year/NN)
# (NP_IN_CHUNK that/DT 's/NN)
# (NP_IN_CHUNK 53/CD patients/NNS)
# (NP_IN_CHUNK day/NN)
# (NP_IN_CHUNK and/CC it/PPS 's/NN)
# (NP_IN_CHUNK 1983/NN)
# (NP_IN_CHUNK 400,000/CD)
# (NP_IN_CHUNK trauma/NN patients/NNS)
# (NP_IN_CHUNK our/PP$ local/JJ trauma/NN centers/NNS)
# (NP_IN_CHUNK i/NN)
# (NP_IN_CHUNK presentation/NN)
# (NP_IN_CHUNK my/PP$ two/CD hospitals/NNS)
# (NP_IN_CHUNK i/NN)
# (NP_IN_CHUNK these/DTS folks/NNS)
# (NP_IN_CHUNK this/DT morning/NN)
# (NP_IN_CHUNK i/NN)
# (NP_IN_CHUNK i/NN)
# (NP_IN_CHUNK i/NN)
# (NP_IN_CHUNK i/NN 've/NN)
# (NP_IN_CHUNK long/JJ)
# (NP_IN_CHUNK because/CS i/NN)
# (NP_IN_CHUNK years/NNS)
# (NP_IN_CHUNK everybody/PN)
# (NP_IN_CHUNK hauls/NNS)
# (NP_IN_CHUNK floor/NN)
# (NP_IN_CHUNK trauma/NN service/NN)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK level/NN 1/CD)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK level/NN 2/CD and/CC level/NN 3/CD)
# (NP_IN_CHUNK and/CC i/NN)
# (NP_IN_CHUNK ladies/NNS and/CC gentlemen/NNS)
# (NP_IN_CHUNK these/DTS)
# (NP_IN_CHUNK survivors/NNS)
# (NP_IN_CHUNK 's/NN)
# (NP_IN_CHUNK them/PPO)
# (NP_IN_CHUNK big/JJ round/NN)
# (NP_IN_CHUNK applause/NN)
# (NP_IN_CHUNK applause/NN)
# (NP_IN_CHUNK and/CC i/NN 'm/NN)
# (NP_IN_CHUNK liz/NN ragenold/NN)
# (NP_IN_CHUNK long/JJ beach/NN memorial/JJ medical/JJ center/NN)
# (NP_IN_CHUNK me/PPO)
# (NP_IN_CHUNK and/CC we/PPSS)
# (NP_IN_CHUNK long/JJ beach/NN memorial/JJ)
# (NP_IN_CHUNK their/PP$ ongoing/NN efforts/NNS)
# (NP_IN_CHUNK service/NN)
# (NP_IN_CHUNK trauma/NN care/NN)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK dr./NN james/NN murray/NN)
# (NP_IN_CHUNK medical/JJ center/NN)
# (NP_IN_CHUNK as/CS)
# (NP_IN_CHUNK it/PPO)
# (NP_IN_CHUNK city/NN)
# (NP_IN_CHUNK long/JJ beach/NN)
# (NP_IN_CHUNK fortunate/JJ)
# (NP_IN_CHUNK supervisor/NN molina/NN)
# (NP_IN_CHUNK you/PPSS)
# (NP_IN_CHUNK some/DTI presentations/NNS)
# (NP_IN_CHUNK molina/NN)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK mr./NN chairman/NN)
# (NP_IN_CHUNK you/PPSS)
# (NP_IN_CHUNK we/PPSS ca/NN n't/NN)
# (NP_IN_CHUNK wonderful/JJ partnership/NN we/PPSS)
# (NP_IN_CHUNK whole/JJ area/NN)
# (NP_IN_CHUNK trauma/NN)
# (NP_IN_CHUNK as/CS supervisor/NN knabe/NN)
# (NP_IN_CHUNK years/NNS)
# (NP_IN_CHUNK everybody/PN)
# (NP_IN_CHUNK front/JJ)
# (NP_IN_CHUNK part/NN)
# (NP_IN_CHUNK action/NN)
# (NP_IN_CHUNK but/CC)
# (NP_IN_CHUNK end/NN)
# (NP_IN_CHUNK day/NN)
# (NP_IN_CHUNK everybody/PN)
# (NP_IN_CHUNK it/PPO)
# (NP_IN_CHUNK hardest/JJT service/NN delivery/NN model/NN)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK significant/JJ)
# (NP_IN_CHUNK each/DT)
# (NP_IN_CHUNK us/PPO hope/NN we/PPSS)
# (NP_IN_CHUNK trauma/NN ward/NN)
# (NP_IN_CHUNK but/CC)
# (NP_IN_CHUNK reality/NN)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK sure/JJ)
# (NP_IN_CHUNK 's/NN one/CD)
# (NP_IN_CHUNK available/JJ)
# (NP_IN_CHUNK us/PPO)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK it/PPO)
# (NP_IN_CHUNK we/PPSS 're/NN)
# (NP_IN_CHUNK quality/NN)
# (NP_IN_CHUNK work/NN and/CC)
# (NP_IN_CHUNK delivery/NN)
# (NP_IN_CHUNK patient/NN care/NN)
# (NP_IN_CHUNK our/PP$ trauma/NN facilities/NNS)
# (NP_IN_CHUNK i/NN)
# (NP_IN_CHUNK course/NN)
# (NP_IN_CHUNK one/CD)
# (NP_IN_CHUNK our/PP$)
# (NP_IN_CHUNK own/JJ)
# (NP_IN_CHUNK l.a./NN county/NN u.s.c./NN)
# (NP_IN_CHUNK one/CD)
# (NP_IN_CHUNK our/PP$ superstars/NN)
# (NP_IN_CHUNK i/NN 've/NN)
# (NP_IN_CHUNK l.a./NN county/NN u.s.c/NN)
# (NP_IN_CHUNK it/PPS)
# (NP_IN_CHUNK hospital/NN that/CS)
# (NP_IN_CHUNK trauma/NN patients/NNS)
# (NP_IN_CHUNK it/PPS)
# (NP_IN_CHUNK 22/CD percent/NN)
# (NP_IN_CHUNK trauma/NN patients/NNS)
# (NP_IN_CHUNK county/NN)
# (NP_IN_CHUNK 4,000/CD people/NNS)
# (NP_IN_CHUNK year/NN)
# (NP_IN_CHUNK our/PP$ new/JJ facility/NN today/NR)
# (NP_IN_CHUNK helicopter/NN pad/NN)
# (NP_IN_CHUNK roof/NN)
# (NP_IN_CHUNK care/NN and/CC)
# (NP_IN_CHUNK course/NN)
# (NP_IN_CHUNK rapid/JJ response/NN)
# (NP_IN_CHUNK our/PP$ patients/NNS)
# (NP_IN_CHUNK i/NN)
# (NP_IN_CHUNK today/NR)
# (NP_IN_CHUNK presentation/NN)
# (NP_IN_CHUNK administrator/NN pete/NN delgado/NN and/CC)
# (NP_IN_CHUNK shirley/NN nemoto/NN)
# (NP_IN_CHUNK us/PPO and/CC we/PPSS)
# (NP_IN_CHUNK them/PPO because/CS they/PPSS do/DO such/JJ)
# (NP_IN_CHUNK outstanding/JJ job/NN)
# (NP_IN_CHUNK congratulations/NNS)
# (NP_IN_CHUNK applause/NN)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK another/DT superstar/NN)
# (NP_IN_CHUNK district/NN)
# (NP_IN_CHUNK i/NN 'm/NN)
# (NP_IN_CHUNK proud/JJ)
# (NP_IN_CHUNK that/CS 's/NN california/NN hospital/NN)
# (NP_IN_CHUNK i/NN 'm/NN)
# (NP_IN_CHUNK diana/NN torres/NN and/CC gladys/NN guerrero/NN)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK us/PPO)
# (NP_IN_CHUNK california/NN hospital/NN)
# (NP_IN_CHUNK busiest/JJT trauma/NN hospital/NN)
# (NP_IN_CHUNK county/NN)
# (NP_IN_CHUNK 11/CD percent/NN)
# (NP_IN_CHUNK county/NN 's/NN trauma/NN patients/NNS)
# (NP_IN_CHUNK 2,000/CD trauma/NN patients/NNS)
# (NP_IN_CHUNK year/NN)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK their/PP$ partnership/NN)
# (NP_IN_CHUNK us/PPO)
# (NP_IN_CHUNK they/PPSS)
# (NP_IN_CHUNK it/PPO)
# (NP_IN_CHUNK longest/JJT time/NN)
# (NP_IN_CHUNK and/CC they/PPSS)
# (NP_IN_CHUNK vital/JJ partner/NN)
# (NP_IN_CHUNK our/PP$ healthcare/NN and/CC safety/NN net/NN)
# (NP_IN_CHUNK l.a./NN county/NN)
# (NP_IN_CHUNK i/NN)
# (NP_IN_CHUNK california/NN hospital/NN medical/JJ center/NN)
# (NP_IN_CHUNK congratulations/NNS)
# (NP_IN_CHUNK applause/NN)
# (NP_IN_CHUNK knabe/NN)
# (NP_IN_CHUNK chair/NN)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK supervisor/NN ridley-thomas/NN)
# (NP_IN_CHUNK ridley-thomas/NN)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK mr./NN chairman/NN and/CC colleagues/NNS)
# (NP_IN_CHUNK i/NN 'm/NN)
# (NP_IN_CHUNK able/JJ)
# (NP_IN_CHUNK this/DT presentation/NN)
# (NP_IN_CHUNK two/CD)
# (NP_IN_CHUNK stellar/JJ trauma/NN centers/NNS)
# (NP_IN_CHUNK county/NN 's/NN network/NN)
# (NP_IN_CHUNK you/PPSS)
# (NP_IN_CHUNK that/CS i/NN)
# (NP_IN_CHUNK opportunity/NN)
# (NP_IN_CHUNK these/DTS institutions/NNS)
# (NP_IN_CHUNK my/PP$ capacity/NN)
# (NP_IN_CHUNK chair/NN)
# (NP_IN_CHUNK committee/NN)
# (NP_IN_CHUNK healthcare/NN crisis/NN)
# (NP_IN_CHUNK county/NN)
# (NP_IN_CHUNK los/NN angeles/NN)
# (NP_IN_CHUNK assembly/NN and/CC)
# (NP_IN_CHUNK senate/NN)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK able/JJ)
# (NP_IN_CHUNK them/PPO)
# (NP_IN_CHUNK context/NN)
# (NP_IN_CHUNK this/DT ceremony/NN)
# (NP_IN_CHUNK it/PPS)
# (NP_IN_CHUNK that/CS these/DTS healthcare/NN providers/NN)
# (NP_IN_CHUNK top/NN tier/NN)
# (NP_IN_CHUNK respects/NNS)
# (NP_IN_CHUNK specialists/NNS)
# (NP_IN_CHUNK their/PP$ respective/JJ staffs/NNS)
# (NP_IN_CHUNK and/CC we/PPSS)
# (NP_IN_CHUNK note/NN)
# (NP_IN_CHUNK fact/NN that/CS they/PPSS)
# (NP_IN_CHUNK each/DT and/CC)
# (NP_IN_CHUNK day/NN)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK i/NN)
# (NP_IN_CHUNK program/NN manager/NN)
# (NP_IN_CHUNK laura/NN schneider/NN)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK director/NN)
# (NP_IN_CHUNK dr./NN brant/NN putnam/NN)
# (NP_IN_CHUNK harbor/NN u.c.l.a/NN)
# (NP_IN_CHUNK medical/JJ center/NN)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK this/DT presentation/NN)
# (NP_IN_CHUNK them/PPO)
# (NP_IN_CHUNK great/JJ appreciation/NN and/CC admiration/NN)
# (NP_IN_CHUNK work/NN you/PPSS)
# (NP_IN_CHUNK work/NN you/PPSS)
# (NP_IN_CHUNK and/CC that/CS)
# (NP_IN_CHUNK you/PPSS)
# (NP_IN_CHUNK do/DO)
# (NP_IN_CHUNK behalf/NN)
# (NP_IN_CHUNK county/NN board/NN)
# (NP_IN_CHUNK supervisors/NNS)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK this/DT)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK great/JJ appreciation/NN)
# (NP_IN_CHUNK applause/NN)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK i/NN)
# (NP_IN_CHUNK
#   program/NN
#   manager/NN
#   and/CC
#   director/NN
#   renee/NN
#   gray/NN
#   and/CC
#   dr./NN
#   takachi/NN
#   shepherd/NN)
# (NP_IN_CHUNK st./NN francis/NN medical/JJ center/NN)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK them/PPO)
# (NP_IN_CHUNK their/PP$ resolution/NN and/CC commendation/NN)
# (NP_IN_CHUNK work/NN that/CS they/PPSS)
# (NP_IN_CHUNK county/NN)
# (NP_IN_CHUNK los/NN angeles/NN)
# (NP_IN_CHUNK southeast/NR portion/NN)
# (NP_IN_CHUNK county/NN)
# (NP_IN_CHUNK los/NN angeles/NN)
# (NP_IN_CHUNK and/CC they/PPSS)
# (NP_IN_CHUNK themselves/PPLS)
# (NP_IN_CHUNK challenging/JJ circumstances/NNS)
# (NP_IN_CHUNK recent/JJ years/NNS)
# (NP_IN_CHUNK but/CC they/PPSS)
# (NP_IN_CHUNK work/NN that/CS they/PPSS do/DO)
# (NP_IN_CHUNK hospital/NN but/CC)
# (NP_IN_CHUNK terms/NNS)
# (NP_IN_CHUNK trauma/NN center/NN itself/PPL)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK that/DT)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK that/CS)
# (NP_IN_CHUNK county/NN)
# (NP_IN_CHUNK los/NN angeles/NN)
# (NP_IN_CHUNK its/PP$ entirety/NN)
# (NP_IN_CHUNK those/DTS)
# (NP_IN_CHUNK patients/NNS)
# (NP_IN_CHUNK st./NN francis/NN medical/JJ center/NN)
# (NP_IN_CHUNK appreciative/JJ)
# (NP_IN_CHUNK work/NN that/CS you/PPSS)
# (NP_IN_CHUNK you/PPSS)
# (NP_IN_CHUNK and/CC we/PPSS partner/NN)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK work/NN that/CS)
# (NP_IN_CHUNK future/NN)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK applause/NN)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK mr./NN chairman/NN)
# (NP_IN_CHUNK knabe/NN)
# (NP_IN_CHUNK chair/NN)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK mr./NN yaroslavsky/NN)
# (NP_IN_CHUNK yaroslavsky/NN)
# (NP_IN_CHUNK i/NN)
# (NP_IN_CHUNK mr./NN chairman/NN)
# (NP_IN_CHUNK district/NN)
# (NP_IN_CHUNK because/CS it/PPS 's/NN)
# (NP_IN_CHUNK district/NN)
# (NP_IN_CHUNK county/NN and/CC straddles/NN)
# (NP_IN_CHUNK hollywood/NN hills/NNS)
# (NP_IN_CHUNK santa/NN monica/NN mountains/NNS)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK five/CD trauma/NN centers/NNS)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK proud/JJ)
# (NP_IN_CHUNK me/PPO)
# (NP_IN_CHUNK and/CC present/JJ this/DT proclamation/NN)
# (NP_IN_CHUNK children/NNS 's/NN hospital/NN)
# (NP_IN_CHUNK los/NN angeles/NN)
# (NP_IN_CHUNK children/NNS 's/NN hospital/NN)
# (NP_IN_CHUNK trauma/NN center/NN but/CC)
# (NP_IN_CHUNK pediatric/NN trauma/NN center/NN)
# (NP_IN_CHUNK i/NN)
# (NP_IN_CHUNK it/PPO 's/NN)
# (NP_IN_CHUNK northerly/JJ pediatric/NN center/NN)
# (NP_IN_CHUNK county/NN)
# (NP_IN_CHUNK los/NN angeles/NN)
# (NP_IN_CHUNK something/PN we/PPSS 're/NN)
# (NP_IN_CHUNK rectify/NN)
# (NP_IN_CHUNK san/NN fernando/NN valley/NN)
# (NP_IN_CHUNK help/NN)
# (NP_IN_CHUNK children/NNS 's/NN hospital/NN)
# (NP_IN_CHUNK some/DTI point/NN)
# (NP_IN_CHUNK but/CC they/PPSS do/DO)
# (NP_IN_CHUNK outstanding/JJ job/NN)
# (NP_IN_CHUNK they/PPSS 're/NN)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK me/PPO present/JJ this/DT proclamation/NN)
# (NP_IN_CHUNK children/NNS 's/NN hospital/NN)
# (NP_IN_CHUNK michael/NN jordan/NN)
# (NP_IN_CHUNK hospital/NN)
# (NP_IN_CHUNK applause/NN)
# (NP_IN_CHUNK children/NNS 's/NN)
# (NP_IN_CHUNK two/CD blocks/NNS)
# (NP_IN_CHUNK supervisor/NN molina/NN 's/NN district/NN)
# (NP_IN_CHUNK so/CS we/PPSS)
# (NP_IN_CHUNK your/PP$ sphere/NN)
# (NP_IN_CHUNK influence/NN)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK me/PPO)
# (NP_IN_CHUNK word/NN)
# (NP_IN_CHUNK i/NN)
# (NP_IN_CHUNK rest/NN)
# (NP_IN_CHUNK presentations/NNS)
# (NP_IN_CHUNK one/CD thing/NN we/PPSS)
# (NP_IN_CHUNK do/DO)
# (NP_IN_CHUNK people/NNS)
# (NP_IN_CHUNK los/NN angeles/NN county/NN)
# (NP_IN_CHUNK 2002/NN)
# (NP_IN_CHUNK proposition/NN)
# (NP_IN_CHUNK measure/NN b/NN)
# (NP_IN_CHUNK trauma/NN centers/NNS)
# (NP_IN_CHUNK time/NN we/PPSS)
# (NP_IN_CHUNK 13/CD trauma/NN centers/NNS)
# (NP_IN_CHUNK this/DT county/NN)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK we/PPSS able/JJ)
# (NP_IN_CHUNK them/PPO)
# (NP_IN_CHUNK but/CC)
# (NP_IN_CHUNK california/NN hospital/NN)
# (NP_IN_CHUNK as/CS)
# (NP_IN_CHUNK result/NN)
# (NP_IN_CHUNK problems/NNS we/PPSS)
# (NP_IN_CHUNK king/NN)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK temporary/JJ)
# (NP_IN_CHUNK but/CC we/PPSS)
# (NP_IN_CHUNK able/JJ)
# (NP_IN_CHUNK trauma/NN center/NN)
# (NP_IN_CHUNK california/NN)
# (NP_IN_CHUNK part/NN because/CS)
# (NP_IN_CHUNK funds/NNS)
# (NP_IN_CHUNK measure/NN b/NN)
# (NP_IN_CHUNK and/CC i/NN)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK important/JJ that/CS)
# (NP_IN_CHUNK people/NNS)
# (NP_IN_CHUNK los/NN angeles/NN county/NN)
# (NP_IN_CHUNK this/DT)
# (NP_IN_CHUNK thanks/NNS)
# (NP_IN_CHUNK and/CC we/PPSS)
# (NP_IN_CHUNK good/JJ)
# (NP_IN_CHUNK their/PP$ promise/NN)
# (NP_IN_CHUNK them/PPO and/CC their/PP$ expectations/NNS)
# (NP_IN_CHUNK we/PPSS 're/NN)
# (NP_IN_CHUNK that/DT)
# (NP_IN_CHUNK me/PPO present/JJ this/DT proclamation/NN)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK football/NN team/NN this/DT year/NN)
# (NP_IN_CHUNK but/CC we/PPSS do/DO)
# (NP_IN_CHUNK great/JJ medical/JJ center/NN and/CC that/CS 's/NN)
# (NP_IN_CHUNK u.c.l.a/NN)
# (NP_IN_CHUNK medical/JJ center/NN)
# (NP_IN_CHUNK me/PPO)
# (NP_IN_CHUNK marilyn/NN cohen/NN)
# (NP_IN_CHUNK marilyn/NN)
# (NP_IN_CHUNK it/PPS 's/NN)
# (NP_IN_CHUNK privilege/NN)
# (NP_IN_CHUNK present/JJ this/DT proclamation/NN)
# (NP_IN_CHUNK cedar/NN sinai/NN medical/JJ center/NN)
# (NP_IN_CHUNK dan/NN marbillis/NN)
# (NP_IN_CHUNK one/CD)
# (NP_IN_CHUNK two/CD trauma/NN centers/NNS)
# (NP_IN_CHUNK san/NN fernando/NN valley/NN)
# (NP_IN_CHUNK northridge/NN hospital/NN medical/JJ center/NN)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK them/PPO today/NR)
# (NP_IN_CHUNK melanie/NN crowley/NN)
# (NP_IN_CHUNK melanie/NN)
# (NP_IN_CHUNK but/CC)
# (NP_IN_CHUNK providence/NN holy/JJ cross/NN medical/JJ center/NN)
# (NP_IN_CHUNK such/JJ)
# (NP_IN_CHUNK great/JJ partner/NN)
# (NP_IN_CHUNK county/NN)
# (NP_IN_CHUNK los/NN angeles/NN)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK holy/JJ cross/NN)
# (NP_IN_CHUNK judy/NN sterling/JJ)
# (NP_IN_CHUNK judy/NN)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK that/CS)
# (NP_IN_CHUNK building/NN)
# (NP_IN_CHUNK construction/NN)
# (NP_IN_CHUNK its/PP$ construction/NN)
# (NP_IN_CHUNK fruition/NN)
# (NP_IN_CHUNK and/CC we/PPSS)
# (NP_IN_CHUNK that/CS trauma/NN center/NN)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK mr./NN chairman/NN)
# (NP_IN_CHUNK knabe/NN)
# (NP_IN_CHUNK chair/NN)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK supervisor/NN antonovich/NN)
# (NP_IN_CHUNK antonovich/NN)
# (NP_IN_CHUNK two/CD hospitals/NNS)
# (NP_IN_CHUNK our/PP$ area/NN that/CS we/PPSS 're/NN)
# (NP_IN_CHUNK proud/JJ)
# (NP_IN_CHUNK that/DT)
# (NP_IN_CHUNK superb/JJ job/NN)
# (NP_IN_CHUNK san/NN gabriel/NN valley/NN)
# (NP_IN_CHUNK huntington/NN memorial/JJ 's/NN trauma/NN center/NN)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK santa/NN clarita/NN valley/NN)
# (NP_IN_CHUNK henry/NN mayo/NN newhall/NN memorial/JJ hospital/NN)
# (NP_IN_CHUNK huntington/NN)
# (NP_IN_CHUNK they/PPSS)
# (NP_IN_CHUNK good/JJ emergency/NN room/NN)
# (NP_IN_CHUNK my/PP$ little/JJ boy/NN)
# (NP_IN_CHUNK yesterday/NR)
# (NP_IN_CHUNK knee/NN injury/NN)
# (NP_IN_CHUNK great/JJ service/NN)
# (NP_IN_CHUNK and/CC henry/NN mayo/NN)
# (NP_IN_CHUNK knabe/NN)
# (NP_IN_CHUNK chair/NN)
# (NP_IN_CHUNK okay/JJ)
# (NP_IN_CHUNK we/PPSS 're/NN)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK mike/NN)
# (NP_IN_CHUNK we/PPSS 'll/NN do/DO)
# (NP_IN_CHUNK group/NN photo/NN)
# (NP_IN_CHUNK five/CD supervisors/NNS)
# (NP_IN_CHUNK everybody/PN)
# (NP_IN_CHUNK nice/JJ and/CC)
# (NP_IN_CHUNK while/CS we/PPSS 're/NN)
# (NP_IN_CHUNK moment/NN)
# (NP_IN_CHUNK celebration/NN 25/CD years/NNS)
# (NP_IN_CHUNK i/NN do/DO n't/NN)
# (NP_IN_CHUNK any/DTI)
# (NP_IN_CHUNK us/PPO)
# (NP_IN_CHUNK importance/NN)
# (NP_IN_CHUNK these/DTS hospitals/NNS)
# (NP_IN_CHUNK
#   our/PP$
#   10/CD
#   million/CD
#   plus/CC
#   residents/NNS
#   or/CC
#   visitors/NNS)
# (NP_IN_CHUNK 's/NN)
# (NP_IN_CHUNK them/PPO)
# (NP_IN_CHUNK big/JJ round/NN)
# (NP_IN_CHUNK applause/NN)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK them/PPO)
# (NP_IN_CHUNK applause/NN)
# (NP_IN_CHUNK kathy/NN and/CC dr./NN schunhoff/NN)
# (NP_IN_CHUNK if/CS you/PPSS 'd/NN like/CS)
# (NP_IN_CHUNK couple/NN words/NNS)
# (NP_IN_CHUNK dr./NN john/NN schunhoff/NN)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK supervisor/NN)
# (NP_IN_CHUNK fact/NN that/CS)
# (NP_IN_CHUNK trauma/NN centers/NNS)
# (NP_IN_CHUNK backbone/NN)
# (NP_IN_CHUNK emergency/NN medical/JJ system/NN)
# (NP_IN_CHUNK tragic/JJ incident/NN)
# (NP_IN_CHUNK metrolink/NN and/CC)
# (NP_IN_CHUNK value/NN)
# (NP_IN_CHUNK these/DTS trauma/NN centers/NNS)
# (NP_IN_CHUNK entire/JJ county/NN)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK honor/NN them/PPO today/NR)
# (NP_IN_CHUNK kathy/NN cheister/NN)
# (NP_IN_CHUNK i/NN)
# (NP_IN_CHUNK trauma/NN centers/NNS)
# (NP_IN_CHUNK hard/JJ work/NN they/PPSS do/DO)
# (NP_IN_CHUNK daily/JJ basis/NN)
# (NP_IN_CHUNK 25/CD years/NNS)
# (NP_IN_CHUNK care/NN)
# (NP_IN_CHUNK 400,000/CD patients/NNS)
# (NP_IN_CHUNK we/PPSS 're/NN)
# (NP_IN_CHUNK proud/JJ)
# (NP_IN_CHUNK them/PPO and/CC)
# (NP_IN_CHUNK board/NN)
# (NP_IN_CHUNK their/PP$ ongoing/NN support/NN)
# (NP_IN_CHUNK emergency/NN medical/JJ services/NNS and/CC)
# (NP_IN_CHUNK trauma/NN services/NNS)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK knabe/NN)
# (NP_IN_CHUNK chair/NN)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK applause/NN)
# (NP_IN_CHUNK nice/JJ holiday/NN)
# (NP_IN_CHUNK healthy/JJ)
# (NP_IN_CHUNK and/CC i/NN)
# (NP_IN_CHUNK i/NN do/DO n't/NN)
# (NP_IN_CHUNK you/PPO)
# ...
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK mr./NN sachs/NN)
# (NP_IN_CHUNK gottlieb/NN)
# (NP_IN_CHUNK if/CS you/PPSS 'd/NN)
# (NP_IN_CHUNK us/PPO as/CS)
# (NP_IN_CHUNK larry/NN)
# (NP_IN_CHUNK nancy/NN)
# (NP_IN_CHUNK arnold/NN)
# (NP_IN_CHUNK speaker/NN)
# (NP_IN_CHUNK okay/JJ)
# (NP_IN_CHUNK i/NN)
# (NP_IN_CHUNK little/JJ)
# (NP_IN_CHUNK history/NN)
# (NP_IN_CHUNK way/NN that/CS)
# (NP_IN_CHUNK marina/NN)
# (NP_IN_CHUNK as/CS)
# (NP_IN_CHUNK great/JJ source/NN)
# (NP_IN_CHUNK revenue/NN that/CS it/PPS)
# (NP_IN_CHUNK and/CC i/NN)
# (NP_IN_CHUNK lot/NN)
# (NP_IN_CHUNK this/DT)
# (NP_IN_CHUNK because/CS)
# (NP_IN_CHUNK i/NN)
# (NP_IN_CHUNK cases/NNS your/PP$ staff/NN)
# (NP_IN_CHUNK you/PPO information/NN)
# (NP_IN_CHUNK your/PP$ own/JJ)
# (NP_IN_CHUNK today/NR you/PPSS guys/NNS)
# (NP_IN_CHUNK that/DT)
# (NP_IN_CHUNK that/CS if/CS your/PP$ staff/NN does/DOZ n't/NN)
# (NP_IN_CHUNK you/PPO good/JJ information/NN)
# (NP_IN_CHUNK that/CS you/PPSS)
# (NP_IN_CHUNK bad/JJ decisions/NNS)
# (NP_IN_CHUNK i/NN)
# (NP_IN_CHUNK that/CS while/CS i/NN)
# (NP_IN_CHUNK and/CC i/NN)
# (NP_IN_CHUNK we/PPSS 're/NN)
# (NP_IN_CHUNK situation/NN)
# (NP_IN_CHUNK we/PPSS 're/NN)
# (NP_IN_CHUNK you/PPSS 're/NN)
# (NP_IN_CHUNK some/DTI bad/JJ information/NN)
# (NP_IN_CHUNK and/CC i/NN 'm/NN)
# (NP_IN_CHUNK shores/NNS)
# (NP_IN_CHUNK i/NN 'm/NN)
# (NP_IN_CHUNK marina/NN del/NN rey/NN)
# (NP_IN_CHUNK general/JJ)
# (NP_IN_CHUNK it/PPS 's/NN)
# (NP_IN_CHUNK accident/NN that/CS)
# (NP_IN_CHUNK history/NN)
# (NP_IN_CHUNK failure/NN)
# (NP_IN_CHUNK sound/JJ decisions/NNS)
# (NP_IN_CHUNK revenue/NN)
# (NP_IN_CHUNK marina/NN)
# (NP_IN_CHUNK abe/NN lurey/NN)
# (NP_IN_CHUNK his/PP$ leases/NNS long/JJ)
# (NP_IN_CHUNK he/PPS)
# (NP_IN_CHUNK them/PPO)
# (NP_IN_CHUNK he/PPS)
# (NP_IN_CHUNK this/DT board/NN)
# (NP_IN_CHUNK secret/NN partner/NN)
# (NP_IN_CHUNK order/NN)
# (NP_IN_CHUNK his/PP$ leases/NNS)
# (NP_IN_CHUNK partner/NN)
# (NP_IN_CHUNK saudi/NN and/CC)
# (NP_IN_CHUNK he/PPS)
# (NP_IN_CHUNK some/DTI)
# (NP_IN_CHUNK his/PP$ leases/NNS)
# (NP_IN_CHUNK he/PPS)
# (NP_IN_CHUNK your/PP$ legal/JJ reach/NN)
# (NP_IN_CHUNK do/DO anything/PN)
# (NP_IN_CHUNK it/PPO)
# (NP_IN_CHUNK valuable/JJ leases/NNS)
# (NP_IN_CHUNK marina/NN)
# (NP_IN_CHUNK unpaid/JJ)
# (NP_IN_CHUNK it/PPS)
# (NP_IN_CHUNK board/NN 's/NN decision/NN)
# (NP_IN_CHUNK charge/NN)
# (NP_IN_CHUNK fisherman/NN 's/NN village/NN)
# (NP_IN_CHUNK people/NNS)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK shops/NNS)
# (NP_IN_CHUNK little/JJ shops/NNS)
# (NP_IN_CHUNK pay/NN parking/NN)
# (NP_IN_CHUNK force/NN)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK quaint/JJ marina/NN destination/NN)
# (NP_IN_CHUNK bad/JJ decision/NN)
# (NP_IN_CHUNK board/NN)
# (NP_IN_CHUNK marina/NN city/NN club/NN)
# (NP_IN_CHUNK someone/PN)
# (NP_IN_CHUNK lease/NN money/NN)
# (NP_IN_CHUNK owners/NNS and/CC)
# (NP_IN_CHUNK it/PPO)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK board/NN)
# (NP_IN_CHUNK powerless/JJ)
# (NP_IN_CHUNK them/PPO)
# (NP_IN_CHUNK his/PP$ lease/NN)
# (NP_IN_CHUNK insurance/NN company/NN)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK payments/NNS)
# (NP_IN_CHUNK red/JJ onion/NN restaurant/NN)
# (NP_IN_CHUNK louise/NN 's/NN restaurant/NN)
# (NP_IN_CHUNK popular/JJ restaurant/NN chain/NN)
# (NP_IN_CHUNK it/PPO but/CC)
# (NP_IN_CHUNK board/NN)
# (NP_IN_CHUNK it/PPO)
# (NP_IN_CHUNK louise/NN 's/NN restaurants/NNS)
# (NP_IN_CHUNK lots/NNS)
# (NP_IN_CHUNK money/NN and/CC)
# (NP_IN_CHUNK good/JJ choice/NN)
# (NP_IN_CHUNK but/CC they/PPSS)
# (NP_IN_CHUNK easy/JJ 's/NN diner/NN)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK company/NN new/JJ)
# (NP_IN_CHUNK business/NN that/CS)
# (NP_IN_CHUNK small/JJ fraction/NN)
# (NP_IN_CHUNK customers/NNS)
# (NP_IN_CHUNK easy/JJ 's/NN)
# (NP_IN_CHUNK larger/JJR)
# (NP_IN_CHUNK restaurants/NNS)
# (NP_IN_CHUNK valuable/JJ waterfront/NN spot/NN)
# (NP_IN_CHUNK but/CC poor/JJ choices/NNS)
# (NP_IN_CHUNK it/PPO)
# (NP_IN_CHUNK prime/JJ time/NN steakhouse/NN)
# (NP_IN_CHUNK house/NN)
# (NP_IN_CHUNK organic/JJ paneficcio/NN)
# (NP_IN_CHUNK they/PPSS 're/NN)
# (NP_IN_CHUNK poor/JJ choices/NNS)
# (NP_IN_CHUNK lasorda/NN 's/NN restaurant/NN)
# (NP_IN_CHUNK marquesas/NN)
# (NP_IN_CHUNK waterfront/NN)
# (NP_IN_CHUNK empty/JJ)
# (NP_IN_CHUNK 10/CD years/NNS)
# (NP_IN_CHUNK benny/NN hana/NN 's/NN)
# (NP_IN_CHUNK empty/JJ)
# (NP_IN_CHUNK years/NNS)
# (NP_IN_CHUNK apartments/NNS)
# (NP_IN_CHUNK end/NN)
# (NP_IN_CHUNK marquesas/NN)
# (NP_IN_CHUNK years/NNS)
# (NP_IN_CHUNK they/PPSS)
# (NP_IN_CHUNK money/NN makers/NNS)
# (NP_IN_CHUNK county/NN)
# (NP_IN_CHUNK this/DT)
# (NP_IN_CHUNK giant/JJ new/JJ buildings/NNS)
# (NP_IN_CHUNK 2/CD percent/NN)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK number/NN)
# (NP_IN_CHUNK people/NNS)
# (NP_IN_CHUNK them/PPO)
# (NP_IN_CHUNK it/PPS)
# (NP_IN_CHUNK decade/NN)
# (NP_IN_CHUNK they/PPSS)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK that/DT revenue/NN)
# (NP_IN_CHUNK these/DTS years/NNS)
# (NP_IN_CHUNK hundreds/NNS if/CS)
# (NP_IN_CHUNK thousands/NNS)
# (NP_IN_CHUNK vacant/JJ apartments/NNS)
# (NP_IN_CHUNK our/PP$ new/JJ complexes/NNS)
# (NP_IN_CHUNK revenue/NN)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK middle/NN)
# (NP_IN_CHUNK this/DT)
# (NP_IN_CHUNK you/PPSS)
# (NP_IN_CHUNK another/DT income-producing/NN apartment/NN)
# (NP_IN_CHUNK build/NN another/DT large/JJ apartment/NN that/CS)
# (NP_IN_CHUNK county/NN)
# (NP_IN_CHUNK dime/NN)
# (NP_IN_CHUNK revenue/NN)
# (NP_IN_CHUNK 10/CD years/NNS)
# (NP_IN_CHUNK knabe/NN)
# (NP_IN_CHUNK chair/NN)
# (NP_IN_CHUNK your/PP$ time/NN)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK nancy/NN and/CC)
# (NP_IN_CHUNK arnold/NN and/CC)
# (NP_IN_CHUNK mr./NN gottlieb/NN)
# (NP_IN_CHUNK nancy/NN marino/NN)
# (NP_IN_CHUNK nancy/NN vernon/NN marino/NN)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK i/NN 'd/NN like/CS)
# (NP_IN_CHUNK some/DTI things/NNS)
# (NP_IN_CHUNK larry/NN)
# (NP_IN_CHUNK amortized/NN returns/NNS)
# (NP_IN_CHUNK county/NN)
# (NP_IN_CHUNK some/DTI)
# (NP_IN_CHUNK this/DT development/NN)
# (NP_IN_CHUNK california/NN coastal/JJ commission/NN)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK that/CS)
# (NP_IN_CHUNK comprehensive/JJ study/NN)
# (NP_IN_CHUNK comprehensive/JJ revision/NN)
# (NP_IN_CHUNK
#   marina/NN
#   del/NN
#   rey/NN
#   local/NN
#   coastal/JJ
#   program/NN
#   that/CS)
# (NP_IN_CHUNK success/NN rate/NN)
# (NP_IN_CHUNK it/PPS 's/NN)
# (NP_IN_CHUNK appropriate/JJ)
# (NP_IN_CHUNK future/JJ development/NN)
# (NP_IN_CHUNK marina/NN del/NN rey/NN)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK county/NN)
# (NP_IN_CHUNK headlong/NN)
# (NP_IN_CHUNK piecemeal/JJ approach/NN)
# (NP_IN_CHUNK one/CD)
# (NP_IN_CHUNK burdensome/JJ)
# (NP_IN_CHUNK those/DTS)
# (NP_IN_CHUNK us/PPO)
# (NP_IN_CHUNK challenge/NN)
# (NP_IN_CHUNK 's/NN)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK b/NN)
# (NP_IN_CHUNK some/DTI reasonable/JJ participation/NN)
# (NP_IN_CHUNK process/NN)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK master/NN plan/NN)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK it/PPO)
# (NP_IN_CHUNK long/JJ time/NN)
# (NP_IN_CHUNK l.c.p/NN)
# (NP_IN_CHUNK as/CS it/PPS)
# (NP_IN_CHUNK while/CS it/PPS)
# (NP_IN_CHUNK way/NN)
# (NP_IN_CHUNK date/NN)
# (NP_IN_CHUNK closest/JJT thing/NN we/PPSS)
# (NP_IN_CHUNK master/NN plan/NN)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK it/PPS)
# (NP_IN_CHUNK countless/JJ parcels/NNS)
# (NP_IN_CHUNK marina/NN that/CS)
# (NP_IN_CHUNK reallocated/NN)
# (NP_IN_CHUNK different/JJ land/NN use/NN)
# (NP_IN_CHUNK whole/JJ)
# (NP_IN_CHUNK things/NNS)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK look/NN)
# (NP_IN_CHUNK whole/JJ thing/NN)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK 's/NN)
# (NP_IN_CHUNK california/NN constitution/NN)
# (NP_IN_CHUNK public/JJ)
# (NP_IN_CHUNK right/NN)
# (NP_IN_CHUNK those/DTS)
# (NP_IN_CHUNK decisions/NNS)
# (NP_IN_CHUNK section/NN 30006/NN)
# (NP_IN_CHUNK us/PPO that/CS right/JJ or/CC does/DOZ n't/NN)
# (NP_IN_CHUNK us/PPO that/CS right/JJ)
# (NP_IN_CHUNK it/PPS)
# (NP_IN_CHUNK that/CS we/PPSS)
# (NP_IN_CHUNK that/DT right/NN it/PPS does/DOZ n't/NN)
# (NP_IN_CHUNK us/PPO some/DTI kind/NN)
# (NP_IN_CHUNK privilege/NN that/CS)
# (NP_IN_CHUNK us/PPO)
# (NP_IN_CHUNK it/PPS)
# (NP_IN_CHUNK that/CS we/PPSS)
# (NP_IN_CHUNK that/DT)
# (NP_IN_CHUNK right/JJ)
# (NP_IN_CHUNK and/CC this/DT process/NN)
# (NP_IN_CHUNK abusive/JJ)
# (NP_IN_CHUNK terms/NNS)
# (NP_IN_CHUNK number/NN)
# (NP_IN_CHUNK projects/NNS)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK and/CC we/PPSS)
# (NP_IN_CHUNK each/DT phase/NN)
# (NP_IN_CHUNK each/DT project/NN)
# (NP_IN_CHUNK order/NN)
# (NP_IN_CHUNK as/CS you/PPSS)
# (NP_IN_CHUNK unless/CS we/PPSS)
# (NP_IN_CHUNK this/DT herculean/NN task/NN)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK way/NN)
# (NP_IN_CHUNK process/NN)
# (NP_IN_CHUNK any/DTI meaningful/JJ way/NN)
# (NP_IN_CHUNK i/NN 'm/NN)
# (NP_IN_CHUNK you/PPO supervisors/NNS)
# (NP_IN_CHUNK do/DO today/NR)
# (NP_IN_CHUNK delay/NN)
# (NP_IN_CHUNK your/PP$ agenda/NN)
# (NP_IN_CHUNK available/JJ meeting/NN)
# (NP_IN_CHUNK issue/NN)
# (NP_IN_CHUNK master/NN plan/NN)
# (NP_IN_CHUNK marina/NN del/NN rey/NN)
# (NP_IN_CHUNK marina/NN del/NN rey/NN)
# (NP_IN_CHUNK talk/NN)
# (NP_IN_CHUNK community/NN)
# (NP_IN_CHUNK 's/NN)
# (NP_IN_CHUNK 's/NN)
# (NP_IN_CHUNK some/DTI)
# (NP_IN_CHUNK projects/NNS)
# (NP_IN_CHUNK larry/NN)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK 's/NN)
# (NP_IN_CHUNK it/PPS)
# (NP_IN_CHUNK good/JJ return/NN)
# (NP_IN_CHUNK county/NN)
# (NP_IN_CHUNK it/PPS)
# (NP_IN_CHUNK needs/NNS)
# (NP_IN_CHUNK people/NNS)
# (NP_IN_CHUNK community/NN)
# (NP_IN_CHUNK it/PPS)
# (NP_IN_CHUNK anyone/PN 's/NN quality/NN)
# (NP_IN_CHUNK life/NN)
# (NP_IN_CHUNK do/DO you/PPSS)
# (NP_IN_CHUNK this/DT)
# (NP_IN_CHUNK good/JJ long/JJ look/NN)
# (NP_IN_CHUNK before/CS)
# (NP_IN_CHUNK bad/JJ decisions/NNS)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK knabe/NN)
# (NP_IN_CHUNK chair/NN)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK arnold/NN)
# (NP_IN_CHUNK arnold/NN sachs/NN)
# (NP_IN_CHUNK good/JJ afternoon/NN)
# (NP_IN_CHUNK arnold/NN sachs/NN)
# (NP_IN_CHUNK i/NN start/NN my/PP$ public/JJ comment/NN)
# (NP_IN_CHUNK i/NN 'd/NN like/CS)
# (NP_IN_CHUNK everybody/PN)
# (NP_IN_CHUNK happy/JJ and/CC healthy/JJ holiday/NN season/NN)
# (NP_IN_CHUNK i/NN 'd/NN like/CS you/PPSS)
# (NP_IN_CHUNK weeks/NNS)
# (NP_IN_CHUNK you/PPSS)
# (NP_IN_CHUNK paul/NN newman/NN 's/NN death/NN)
# (NP_IN_CHUNK your/PP$ adjournments/NN)
# (NP_IN_CHUNK you/PPSS)
# (NP_IN_CHUNK van/NN johnson/NN 's/NN death/NN that/CS)
# (NP_IN_CHUNK your/PP$ adjournments/NN)
# (NP_IN_CHUNK but/CC back/NN)
# (NP_IN_CHUNK metro/NN)
# (NP_IN_CHUNK my/PP$ favorite/JJ subject/NN)
# (NP_IN_CHUNK if/CS you/PPSS)
# (NP_IN_CHUNK any/DTI kind/NN)
# (NP_IN_CHUNK loss/NN)
# (NP_IN_CHUNK recent/JJ)
# (NP_IN_CHUNK because/CS)
# (NP_IN_CHUNK recent/JJ downturn/NN)
# (NP_IN_CHUNK economy/NN)
# (NP_IN_CHUNK you/PPSS)
# (NP_IN_CHUNK metro/NN headquarters/NN and/CC)
# (NP_IN_CHUNK this/DT game/NN that/CS 's/NN)
# (NP_IN_CHUNK their/PP$ monthly/JJ)
# (NP_IN_CHUNK quarterly/JJ issue/NN)
# (NP_IN_CHUNK it/PPS 's/NN)
# (NP_IN_CHUNK we/PPSS 're/NN stealing/NN your/PP$ money/NN)
# (NP_IN_CHUNK ho/NN)
# (NP_IN_CHUNK ho-ho/NN)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK this/DT game/NN)
# (NP_IN_CHUNK kinds/NNS)
# (NP_IN_CHUNK projects/NNS)
# (NP_IN_CHUNK you/PPSS)
# (NP_IN_CHUNK and/CC you/PPSS)
# (NP_IN_CHUNK any/DTI kind/NN)
# (NP_IN_CHUNK metro/NN project/NN)
# (NP_IN_CHUNK you/PPSS)
# (NP_IN_CHUNK falsely/NN)
# (NP_IN_CHUNK i/NN 've/NN)
# (NP_IN_CHUNK this/DT)
# (NP_IN_CHUNK times/NNS)
# (NP_IN_CHUNK metro/NN dollars/NNS)
# (NP_IN_CHUNK
#   metro/NN
#   dollars/NNS
#   because/CS
#   metro/NN
#   dollars/NNS
#   do/DO
#   n't/NN
#   cover/NN)
# (NP_IN_CHUNK cost/NN)
# (NP_IN_CHUNK their/PP$ operations/NNS)
# (NP_IN_CHUNK it/PPS 's/NN)
# (NP_IN_CHUNK public/JJ dollars/NNS)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK metro/NN)
# (NP_IN_CHUNK they/PPSS)
# (NP_IN_CHUNK did/DOD)
# (NP_IN_CHUNK blueprint/NN)
# (NP_IN_CHUNK plan/NN)
# (NP_IN_CHUNK east/NR side/NN extension/NN)
# (NP_IN_CHUNK and/CC they/PPSS)
# (NP_IN_CHUNK steps/NNS)
# (NP_IN_CHUNK 1980s/NN)
# (NP_IN_CHUNK today/NR)
# (NP_IN_CHUNK and/CC like/CS)
# (NP_IN_CHUNK it/PPS)
# (NP_IN_CHUNK year/NN 2000/CD)
# (NP_IN_CHUNK major/JJ investment/NN study/NN)
# (NP_IN_CHUNK i/NN 'm/NN)
# (NP_IN_CHUNK metro/NN board/NN suspends/NN)
# (NP_IN_CHUNK 1998/NN metro/NN board/NN suspends/NN construction/NN)
# (NP_IN_CHUNK metro/NN red/JJ line/NN)
# (NP_IN_CHUNK east/NR l.a./NN studies/NNS)
# (NP_IN_CHUNK cost/NN efficient/JJ project/NN)
# (NP_IN_CHUNK year/NN 2000/CD)
# (NP_IN_CHUNK major/JJ investment/NN study/NN)
# (NP_IN_CHUNK 47/CD alternatives/NNS)
# (NP_IN_CHUNK metro/NN red/JJ line/NN)
# (NP_IN_CHUNK east/NR l.a./NN)
# (NP_IN_CHUNK one/CD study/NN)
# (NP_IN_CHUNK though/CS)
# (NP_IN_CHUNK because/CS as/CS)
# (NP_IN_CHUNK january/NN)
# (NP_IN_CHUNK they/PPSS 're/NN)
# (NP_IN_CHUNK maintenance/NN facilities/NNS)
# (NP_IN_CHUNK one/CD study/NN)
# (NP_IN_CHUNK gold/JJ line/NN)
# (NP_IN_CHUNK east/NR side/NN extension/NN)
# (NP_IN_CHUNK any/DTI kind/NN)
# (NP_IN_CHUNK permanent/JJ facilities/NNS)
# (NP_IN_CHUNK gold/JJ line/NN)
# (NP_IN_CHUNK temporary/JJ facility/NN that/CS 's/NN)
# (NP_IN_CHUNK but/CC it/PPS 's/NN)
# (NP_IN_CHUNK expo/NN line/NN)
# (NP_IN_CHUNK kind/NN)
# (NP_IN_CHUNK leadership/NN do/DO we/PPSS)
# (NP_IN_CHUNK metro/NN)
# (NP_IN_CHUNK measure/NN r/NN)
# (NP_IN_CHUNK billion/CD dollars/NNS)
# (NP_IN_CHUNK year/NN)
# (NP_IN_CHUNK it/PPS 's/NN)
# (NP_IN_CHUNK 750/CD million/CD)
# (NP_IN_CHUNK threshold/NN)
# (NP_IN_CHUNK 30/CD billion/CD)
# (NP_IN_CHUNK term/NN)
# (NP_IN_CHUNK project/NN reasonable/JJ)
# (NP_IN_CHUNK question/NN)
# (NP_IN_CHUNK you/PPSS)
# (NP_IN_CHUNK these/DTS tax/NN sites/NNS)
# (NP_IN_CHUNK 1980/CD and/CC 1990/NN)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK article/NN)
# (NP_IN_CHUNK l.a./NN times/NNS)
# (NP_IN_CHUNK october/NN)
# (NP_IN_CHUNK each/DT)
# (NP_IN_CHUNK those/DTS)
# (NP_IN_CHUNK $/NN 686/NN million/CD)
# (NP_IN_CHUNK 2007/NN)
# (NP_IN_CHUNK beginning/NN)
# (NP_IN_CHUNK those/DTS taxes/NNS)
# (NP_IN_CHUNK certain/JJ sum/NN)
# (NP_IN_CHUNK that/DT certain/JJ sum/NN)
# (NP_IN_CHUNK these/DTS taxes/NNS)
# (NP_IN_CHUNK and/CC)
# (NP_IN_CHUNK money/NN)
# (NP_IN_CHUNK 's/NN)
# (NP_IN_CHUNK show/NN)
# (NP_IN_CHUNK money/NN that/CS 's/NN)
# (NP_IN_CHUNK as/CS)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK your/PP$ time/NN)
# (NP_IN_CHUNK your/PP$ answers/NNS and/CC your/PP$ attention/NN)
# (NP_IN_CHUNK knabe/NN)
# (NP_IN_CHUNK chair/NN)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK arnold/NN sachs/NN)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK 2009/NN)
# (NP_IN_CHUNK knabe/NN)
# (NP_IN_CHUNK chair/NN)
# (NP_IN_CHUNK okay/JJ)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK session/NN)
# (NP_IN_CHUNK i/NN)
# (NP_IN_CHUNK behalf/NN)
# (NP_IN_CHUNK myself/PPL and/CC our/PP$ colleagues/NNS)
# (NP_IN_CHUNK our/PP$ county/NN family/NN)
# (NP_IN_CHUNK citizens/NNS)
# (NP_IN_CHUNK los/NN angeles/NN county/NN)
# (NP_IN_CHUNK you/PPSS)
# (NP_IN_CHUNK holidays/NNS)
# (NP_IN_CHUNK we/PPSS)
# (NP_IN_CHUNK it/PPO 's/NN joyful/JJ)
# (NP_IN_CHUNK healthy/JJ)
# (NP_IN_CHUNK peaceful/JJ)
# (NP_IN_CHUNK
#   you/PPO
#   and/CC
#   your/PP$
#   family/NN
#   and/CC
#   friends/NNS
#   and/CC
#   you/PPSS)
# (NP_IN_CHUNK great/JJ safe/JJ holiday/NN season/NN)
# (NP_IN_CHUNK us/PPO)
# (NP_IN_CHUNK our/PP$ county/NN families/NNS)
# (NP_IN_CHUNK citizens/NNS)
# (NP_IN_CHUNK los/NN angeles/NN county/NN)
# (NP_IN_CHUNK god/NN)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK clerk/NN sachi/NN hamai/NN)
# (NP_IN_CHUNK accordance/NN)
# (NP_IN_CHUNK brown/JJ act/NN requirements/NNS notice/NN)
# (NP_IN_CHUNK that/CS)
# (NP_IN_CHUNK board/NN)
# (NP_IN_CHUNK supervisors/NNS)
# (NP_IN_CHUNK convene/NN)
# (NP_IN_CHUNK session/NN)
# (NP_IN_CHUNK item/NN c.s.-1/NN and/CC c.s.-2/NN conferences/NNS)
# (NP_IN_CHUNK legal/JJ counsel/NN)
# (NP_IN_CHUNK litigation/NN)
# (NP_IN_CHUNK item/NN number/NN c.s.-3/NN)
# (NP_IN_CHUNK conference/NN)
# (NP_IN_CHUNK legal/JJ counsel/NN)
# (NP_IN_CHUNK significant/JJ exposure/NN)
# (NP_IN_CHUNK litigation/NN)
# (NP_IN_CHUNK one/CD case/NN)
# (NP_IN_CHUNK item/NN c.s.-4/NN)
# (NP_IN_CHUNK interview/NN and/CC consideration/NN)
# (NP_IN_CHUNK candidates/NNS)
# (NP_IN_CHUNK position/NN)
# (NP_IN_CHUNK auditor-controller/NN)
# (NP_IN_CHUNK item/NN number/NN c.s.-5/NN)
# (NP_IN_CHUNK conference/NN)
# (NP_IN_CHUNK legal/JJ counsel/NN)
# (NP_IN_CHUNK litigation/NN)
# (NP_IN_CHUNK and/CC item/NN 74-b/NN)
# (NP_IN_CHUNK consideration/NN)
# (NP_IN_CHUNK appointment/NN)
# (NP_IN_CHUNK emilio/NN salas/NN as/CS)
# (NP_IN_CHUNK executive/NN director/NN)
# (NP_IN_CHUNK
#   community/NN
#   development/NN
#   commission/NN
#   and/CC
#   housing/NN
#   authority/NN)
# (NP_IN_CHUNK government/NN code/NN section/NN 54957/NN as/CS)
# (NP_IN_CHUNK and/CC supplemental/JJ agenda/NN)
# (NP_IN_CHUNK you/PPO)
# (NP_IN_CHUNK report/NN)
# (NP_IN_CHUNK action/NN)
# (NP_IN_CHUNK session/NN tuesday/NN)
# (NP_IN_CHUNK december/NN 16/CD)
# (NP_IN_CHUNK 2008/NN agenda/NN item/NN cs-4/NN)
# (NP_IN_CHUNK monday/NN)
# (NP_IN_CHUNK december/NN 22/CD)
# (NP_IN_CHUNK 2008/NN)
# (NP_IN_CHUNK 9:00/CD a.m/NN)
# (NP_IN_CHUNK i/NN)
# (NP_IN_CHUNK jennifer/NN)

# %%
proper_nouns=[]
for sent in mybook_tags:
    NP_tree = NPchunker(sent)
    for subtree in NP_tree.subtrees():
        if subtree.label() == 'NP_CHUNK': 
            proper_nouns.append(subtree[0][0])

# %%
mp_freqdist = FreqDist(proper_nouns)  # compute the frequency distribution
mp_freqdist.most_common(50)  # show the top 20 (word, frequency) pairs
# Out:
# [('going', 52),
#  ('want', 48),
#  ('trying', 18),
#  ('wanted', 10),
#  ('like', 9),
#  ('need', 6),
#  ('tried', 4),
#  ('came', 4),
#  ('used', 3),
#  ('continue', 3),
#  ('afford', 2),
#  ('hope', 2),
#  ('got', 2),
#  ('try', 2),
#  ('voted', 2),
#  ('inclined', 2),
#  ('asked', 2),
#  ('allowed', 2),
#  ('starting', 2),
#  ('done', 2),
#  ('continued', 1),
#  ('failed', 1),
#  ('continues', 1),
#  ('wishing', 1),
#  ('sniffed', 1),
#  ('use', 1),
#  ('pledged', 1),
#  ('equipped', 1),
#  ('prepared', 1),
#  ('pleased', 1),
#  ('passed', 1),
#  ('forced', 1),
#  ('threatening', 1),
#  ('funding', 1),
#  ('affirm', 1),
#  ('revised', 1),
#  ('modified', 1),
#  ('proceed', 1),
#  ('leaves', 1),
#  ('obliged', 1),
#  ('get', 1),
#  ('begin', 1),
#  ('begun', 1),
#  ('protected', 1),
#  ('coming', 1),
#  ('refused', 1),
#  ('delighted', 1),
#  ('supposed', 1),
#  ('plan', 1),
#  ('search', 1)]
